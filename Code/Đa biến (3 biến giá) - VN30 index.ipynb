# %% [markdown]
# # Model 1: Multivariate-3-RNN

# %% [markdown]
# ## RNN

# %% [markdown]
# ### Import các thư viện cần thiết

# %%
import os
os.environ['PYTHONHASHSEED'] = '0' # đảm bảo rằng các giá trị băm của đối tượng bất biến (dict, set, chuỗi, tuple...) luôn giống nhau giữa các lần chạy

import random as rn
import numpy as np
np.random.seed(1)
rn.seed(3)
import tensorflow as tf
tf.random.set_seed(2)
# Out:
# 2025-06-01 14:04:00.047567: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748786640.421214      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748786640.537456      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# **Cấu hình Seed để đảm bảo tính tái lập trong mô hình LSTM**
#
# 1️⃣ `np.random.seed(1)`
# ✅ Đặt **seed** cho NumPy.
# ✅ Ảnh hưởng đến tất cả các hàm tạo số ngẫu nhiên của NumPy như:
#    - `np.random.rand()`
#    - `np.random.randn()`
#    - `np.random.randint()`
#    - ...
#
# 2️⃣ `rn.seed(3)`
# ✅ Đặt **seed** cho thư viện `random` của Python.
# ✅ Ảnh hưởng đến các hàm như:
#    - `random.random()`
#    - `random.randint()`
#    - `random.choice()`
#    - ...
#
# 3️⃣ `tf.random.set_seed(2)`
# ✅ Đặt **seed** cho TensorFlow.
# ✅ Ảnh hưởng đến:
#    - Việc khởi tạo trọng số ngẫu nhiên của mô hình **TensorFlow/Keras**, ví dụ:
#      - `tf.keras.layers.Dense`
#      - `tf.keras.layers.LSTM`
#    - Các phép toán sử dụng số ngẫu nhiên trong TensorFlow như:
#      - `tf.random.uniform()`
#      - `tf.random.normal()`
#      - ...
#
# 📌 **Ghi chú:**
# - Việc đặt **seed** giúp đảm bảo **tính tái lập** trong các lần chạy mô hình.
# - Điều này giúp so sánh kết quả giữa các lần thử nghiệm một cách chính xác hơn.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout
from tensorflow.keras import optimizers

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from math import sqrt
import datetime as dt
import time

from tensorflow.keras.optimizers import Adam

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### Hàm callback

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')  
checkpoint = ModelCheckpoint(
    filepath="best_model11.h5",   # Tên file lưu mô hình
    monitor="val_loss",         # Theo dõi val_loss
    save_best_only=True,        # Chỉ lưu khi tốt hơn mô hình trước đó
    mode="min",                 # Giảm min của val_loss là tốt nhất
    verbose=1
)
callbacks_list = [earlystop, checkpoint]

# %% [markdown]
# ### Đọc dữ liệu từ file csv

# %%
url = r"VN30 Index.csv"
df = pd.read_csv(url, parse_dates= True, index_col= 0)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                open     high      low    close       volume
# time
# 2009-01-05   311.23   311.23   311.23   311.23          NaN
# 2009-01-06   314.21   314.21   314.21   314.21          NaN
# 2009-01-07   320.53   320.53   320.53   320.53          NaN
# 2009-01-08   314.14   314.14   314.14   314.14          NaN
# 2009-01-09   312.90   312.90   312.90   312.90          NaN
# ...             ...      ...      ...      ...          ...
# 2025-03-14  1387.08  1394.39  1385.20  1387.03  374490000.0
# 2025-03-17  1392.75  1397.28  1389.42  1394.90  352180000.0
# 2025-03-18  1398.44  1400.38  1388.64  1388.64  291590000.0
# 2025-03-19  1385.92  1386.57  1374.83  1377.63  363360000.0
# 2025-03-20  1382.23  1388.37  1371.98  1378.95  359980000.0
#
# [4044 rows x 5 columns]>
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()

# %%
print(df.isnull().sum())
# Out:
# open        0
# high        0
# low         0
# close       0
# volume    859
# dtype: int64

# %% [markdown]
# ### Tiền xử lí dữ liệu

# %%
# Xóa các dòng có giá trị Volume bằng 0
df.drop(df[df['volume']==0].index, inplace=True)

# %%
# Ma trận tương quan (ở đây là Pearson tương quan tuyến tính)
df.corr()['close']
# Out:
# open      0.999562
# high      0.999783
# low       0.999789
# close     1.000000
# volume    0.169492
# Name: close, dtype: float64

# %% [markdown]
# **Phân tích tương quan giữa các biến trong dữ liệu chuỗi thời gian**
#
# 🔹 `df.corr()`
# - Tính **ma trận tương quan** giữa tất cả các cột số trong DataFrame.
#
# 🔹 `df.corr()['Close']`
# - Lấy **cột tương quan** giữa tất cả các biến với **giá đóng cửa** (`Close`).
# - Giúp xác định mức độ ảnh hưởng của các biến khác như:
#   - **Giá mở cửa** (`Open`)
#   - **Giá cao nhất** (`High`)
#   - **Giá thấp nhất** (`Low`)
#   - **Khối lượng giao dịch** (`Volume`)
#
# **Ý nghĩa của tương quan**
#
# - **Tương quan gần 1** → Biến có mối quan hệ **tỷ lệ thuận** mạnh với giá đóng cửa.
# - **Tương quan gần -1** → Biến có mối quan hệ **tỷ lệ nghịch** mạnh với giá đóng cửa.
# - **Tương quan gần 0** → Biến **ít hoặc không ảnh hưởng** đến giá đóng cửa.
#
# **Ứng dụng**
#
# - Chọn các biến có tương quan cao với `Close` để đưa vào mô hình dự đoán.
# - Loại bỏ các biến có tương quan thấp để tránh nhiễu dữ liệu.

# %%
#  Tính toán các thống kê mô tả như trung bình (mean), độ lệch chuẩn (std), min, max, phần trăm phân vị (25%, 50%, 75%).
print(df.describe().volume) # Giúp kiểm tra phân bố của Volume, phát hiện các giá trị bất thường (outliers).
# Out:
# count    3.185000e+03
# mean     3.279171e+06
# std      2.776577e+07
# min      4.540000e+03
# 25%      3.809000e+04
# 50%      6.036000e+04
# 75%      1.560100e+05
# max      3.744900e+08
# Name: volume, dtype: float64

# %%
# Vẽ biểu đồ tần suất của Volume
df['volume'].hist(bins=10)
# Out:
# <Axes: >

# %% [markdown]
# **Phân tích phân bố dữ liệu Volume bằng Histogram**
#
# 🔹 `.hist(bins=10)`
# - Vẽ **biểu đồ histogram** của cột `Volume` với **10 bins (nhóm dữ liệu)**.
# - Giúp trực quan hóa **phân bố dữ liệu**, phát hiện sự **lệch** (skewness) và **giá trị ngoại lai** (outliers).
#
# **Ý nghĩa của biểu đồ histogram**
#
# - **Nếu phân bố lệch phải (right-skewed)** → Dữ liệu có nhiều giá trị nhỏ, một số giá trị rất lớn.
# - **Nếu phân bố lệch trái (left-skewed)** → Dữ liệu có nhiều giá trị lớn, một số giá trị rất nhỏ.
# - **Nếu có outliers (điểm nằm xa tập trung chính)** → Có thể cần xử lý như **loại bỏ** hoặc **chuẩn hóa dữ liệu**.
#
# **Cách xử lý dữ liệu lệch/skewed**
#
# ✅ **Log Transformation** → Dùng `np.log1p(Volume)` để giảm độ lệch.
# ✅ **Scaling** → Dùng `MinMaxScaler()` hoặc `StandardScaler()` để chuẩn hóa.
# ✅ **Xử lý outliers** → Loại bỏ hoặc thay thế bằng **giá trị trung bình/median**.

# %% [markdown]
# ## Train model / Hàm **fit_model_2()**

# %%
def fit_model_2(train, val, timesteps, hl, lr, batch, epochs):
    np.random.seed(1)
    tf.random.set_seed(2)
    rn.seed(3)

    X_train = []
    Y_train = []
    X_val = []
    Y_val = []

    # Loop for training data
    for i in range(timesteps, train.shape[0]):
        X_train.append(train[i-timesteps:i])
        Y_train.append(train[i][0])
    X_train, Y_train = np.array(X_train), np.array(Y_train)

    # Loop for val data
    for i in range(timesteps, val.shape[0]):
        X_val.append(val[i-timesteps:i])
        Y_val.append(val[i][0])
    X_val, Y_val = np.array(X_val), np.array(Y_val)

    # Adding Layers to the model
    model = Sequential()
    model.add(SimpleRNN(X_train.shape[2], input_shape = (X_train.shape[1], X_train.shape[2]), activation = 'relu', return_sequences = True))
    for i in range(len(hl)-1):
        model.add(SimpleRNN(hl[i], activation = 'relu', return_sequences = True))
    model.add(SimpleRNN(hl[-1], activation = 'relu'))
    model.add(Dense(1))
    model.compile(optimizer = optimizers.Adam(learning_rate= lr), loss = 'mean_squared_error')

    # Training the data
    history = model.fit(X_train, Y_train, epochs = epochs, batch_size = batch, validation_data = (X_val, Y_val), verbose = 0, shuffle = False, callbacks=callbacks_list)
    for layer in model.layers:
        if isinstance(layer, SimpleRNN):
            layer.reset_states() #Đảm bảo mỗi lần huấn luyện không bị ảnh hưởng bởi trạng thái cũ của LSTM.
    return model, history.history['loss'], history.history['val_loss']

# %% [markdown]
# ###  Bước 1: Đặt Seed để đảm bảo tính tái lập

# %% [markdown]
# Giúp đảm bảo mỗi lần chạy chương trình, các giá trị ngẫu nhiên được tạo ra giống nhau, tránh kết quả huấn luyện thay đổi giữa các lần chạy.

# %%
"""
np.random.seed(1)
tf.random.set_seed(2)
rn.seed(3)
"""
# Out:
# '\nnp.random.seed(1)\ntf.random.set_seed(2)\nrn.seed(3)\n'

# %% [markdown]
# ### Bước 2: Chuẩn bị dữ liệu huấn luyện (train) và kiểm định (val)

# %%
"""
X_train = []
Y_train = []
X_val = []
Y_val = []

for i in range(timesteps, train.shape[0]):
    X_train.append(train[i-timesteps:i])
    Y_train.append(train[i][0])
X_train, Y_train = np.array(X_train, Y_train)

for i in range(timesteps, val.shape[0]):
    X_val.append(val[i-timesteps:i])
    Y_val.append(val[i][0])
X_val, Y_val = np.array(X_val, Y_val)  
"""
# Out:
# '\nX_train = []\nY_train = []\nX_val = []\nY_val = []\n\nfor i in range(timesteps, train.shape[0]):\n    X_train.append(train[i-timesteps:i])\n    Y_train.append(train[i][0])\nX_train, Y_train = np.array(X_train, Y_train)\n\nfor i in range(timesteps, val.shape[0]):\n    X_val.append(val[i-timesteps:i])\n    Y_val.append(val[i][0])\nX_val, Y_val = np.array(X_val, Y_val)  \n'

# %% [markdown]
# ### Bước 3: Xây dựng mô hình RNN

# %%
"""
# Xây dựng mô hình RNN
model = Sequential()
model.add(SimpleRNN(X_train.shape[2], input_shape= (X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences= True))
for i in range(len(hl)-1):
    model.add(SimpleRNN(hl[i], activation='relu', return_sequences= True))
model.add(SimpleRNN(hl[-1], activation='relu'))
model.add(Dense(1))
"""
# Out:
# "\n# Xây dựng mô hình RNN\nmodel = Sequential()\nmodel.add(SimpleRNN(X_train.shape[2], input_shape= (X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences= True))\nfor i in range(len(hl)-1):\n    model.add(SimpleRNN(hl[i], activation='relu', return_sequences= True))\nmodel.add(SimpleRNN(hl[-1], activation='relu'))\nmodel.add(Dense(1))\n"

# %% [markdown]
# Thêm một lớp **SimpleRNN đầu tiên**:
# -   `X_train.shape[2]`: Số đặc trưng (features).
# -   `input_shape = (X_train.shape[1], X_train.shape[2])`: Định dạng đầu vào (timesteps, số đặc trưng).
# -   `activation = 'relu'`: Hàm kích hoạt giúp mô hình học phi tuyến tính.
# -   `return_sequences = True`: Giữ lại toàn bộ chuỗi đầu ra để sử dụng trong các lớp tiếp theo.

# %% [markdown]
# ### Bước 4: Biên dịch mô hình

# %%
"""
# Biên dịch
model.compile(optimizer= optimizers.Adam(learning_rate= lr), loss= 'mean_squared_error')
"""
# Out:
# "\n# Biên dịch\nmodel.compile(optimizer= optimizers.Adam(learning_rate= lr), loss= 'mean_squared_error')\n"

# %% [markdown]
# ### Bước 5: Huấn luyện mô hình

# %%
"""
history = model.fit(X_train, Y_train, epochs = epochs, batch_size = batch, validation_data = (X_val, Y_val), verbose = 0, shuffle = False, callbacks=callbacks_list)
"""
# Out:
# '\nhistory = model.fit(X_train, Y_train, epochs = epochs, batch_size = batch, validation_data = (X_val, Y_val), verbose = 0, shuffle = False, callbacks=callbacks_list)\n'

# %% [markdown]
# **Cấu hình huấn luyện mô hình**
#
# 🔹 Tham số trong quá trình huấn luyện
#
# ✅ `epochs = epochs` → Số vòng huấn luyện
# ✅ `batch_size = batch` → Kích thước batch
# ✅ `validation_data = (X_val, Y_val)` → Dữ liệu kiểm định để theo dõi hiệu suất sau mỗi epoch
# ✅ `verbose = 0` → Không hiển thị log huấn luyện (có thể đặt `verbose = 1` để xem tiến trình)
# ✅ `shuffle = False` → Không xáo trộn dữ liệu (do chuỗi thời gian có tính thứ tự)
# ✅ `callbacks = callbacks_list` → Danh sách callback hỗ trợ huấn luyện

# %% [markdown]
# ### Bước 6: Đảm bảo trạng thái không bị ảnh hưởng khi huấn luyện nhiều lần

# %%
"""
for layer in model.layers:
    if isinstance(layer, SimpleRNN):
        layer.reset_states()
"""
# Out:
# '\nfor layer in model.layers:\n    if isinstance(layer, SimpleRNN):\n        layer.reset_states()\n'

# %% [markdown]
# ### Bước 7: Trả về kết quả

# %%
"""
return model, history.history['train_loss'], history.history['val_loss']
"""
# Out:
# "\nreturn model, history.history['train_loss'], history.history['val_loss']\n"

# %% [markdown]
# ## **Grid Search**: Tìm kiếm siêu tham số tối ưu

# %%
param_grid = {
    'timesteps': [30, 40, 50],
    'hl': [[40, 35]],
    'lr': [1e-3, 1e-4],
    'batch_size': [32, 64],
    'num_epochs': [200, 250]
}

# %%
from itertools import product # Tích đề-các
import pandas as pd

# Hàm Grid Search
def grid_search_rnn(train, val, test, param_grid):
# Khởi tạo danh sách lưu kết quả
    results = []
    best_score = float('inf') # Ban đầu được đặt là vô cùng lớn
    best_params = None # Lưu bộ siêu tham số có hiệu suất tốt nhất
# Tạo tất cả các tổ hợp tham số
    all_combinations = list(product(*param_grid.values()))
    param_names = list(param_grid.keys())
# Lặp qua từng tổ hợp tham số
    for combination in all_combinations:
        params = dict(zip(param_names, combination))
        timesteps = params['timesteps']
        hl = params['hl']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']

    print(f'Training with param: {params}')
# Huấn luyện với fit.model()
    model, train_loss, val_loss = fit_model_2(train, val, timesteps, hl, lr,  batch_size, num_epochs)
# Đánh giá mô hình với evaluate_model()
    mse, rmse, mape, r2, _, _ = evaluate_model_2(model, test, timesteps)
# Lưu kết quả
    results.append({
        'timesteps': timesteps,
        'hl': hl,
        'lr': lr,
        'batch_size': batch_size,
        'num_epochs': num_epochs,
        'MSE': mse,
        'RMSE': rmse,
        'MAPE': mape,
        'R²': r2
    })
# Cập nhật bộ siêu tham số tốt nhất nếu RMSE cải thiện
    if rmse < best_score:
        best_score = rmse
        best_params = params

# Trả về kết quả
    results_df = pd.DataFrame(results)
    return best_params, best_score, results_df

# %% [markdown]
# ## Hàm **Evaluate_model_2()**

# %%
"""
# Định nghĩa hàm mean_absolute_percentage_error() (MAPE)
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true))*100"
    """
# Out:
# '\n# Định nghĩa hàm mean_absolute_percentage_error() (MAPE)\ndef mean_absolute_percentage_error(y_true, y_pred):\n    y_true, y_pred = np.array(y_true), np.array(y_pred)\n    return np.mean(np.abs((y_true - y_pred) / y_true))*100"\n    '

# %%
def evaluate_model_2(model, test, timesteps):
    np.random.seed(1)
    tf.random.set_seed(2)
    rn.seed(3)

    X_test = []
    Y_test = []

    # Loop for testing data
    for i in range(timesteps, test.shape[0]):
        X_test.append(test[i-timesteps:i])
        Y_test.append(test[i][0])
    X_test, Y_test = np.array(X_test), np.array(Y_test)

    # Evaluate model
    Y_hat = model.predict(X_test)                         #chứa dự đoán của model dựa trên đầu vào x_test
    mse = mean_squared_error(Y_test, Y_hat)
    rmse = sqrt(mse)
    mape = mean_absolute_percentage_error(Y_test, Y_hat)
    r2 = r2_score(Y_test, Y_hat)
    return mse, rmse, mape, r2, Y_test, Y_hat

# %% [markdown]
# ## Plot chart (vẽ biểu đồ)

# %%
# Plotting the predictions
def plot_data_2(Y_test,Y_hat):
    plt.plot(Y_test, c = 'r')
    plt.plot(Y_hat, c = 'y')
    plt.xlabel('Day')
    plt.ylabel('Price')
    plt.title("Stock Price Prediction using Multivatiate-RNN")
    plt.legend(['Actual','Predicted'], loc = 'lower right')
    plt.show()

# %%
# Plotting the training errors: trực quan loss qua các epoch -> thấy qtr học mô hình, xem có overfitting ko
def plot_error(train_loss, val_loss):
    plt.plot(train_loss, c = 'r')
    plt.plot(val_loss, c = 'b')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.title('Train Loss and Validation Loss Curve')
    plt.legend(['train', 'val'], loc = 'upper right')
    plt.show()

# %% [markdown]
# ## **Model building**: Xây dựng mô hình

# %% [markdown]
# ### Bước 1: Trích xuất và trực quan hóa dữ liệu

# %%
# Extracting the series
series = df[['close', 'high', 'low']] # Picking the multivariate series
print(series.shape)
series
# Out:
# (4044, 3)
#               close     high      low
# time
# 2009-01-05   311.23   311.23   311.23
# 2009-01-06   314.21   314.21   314.21
# 2009-01-07   320.53   320.53   320.53
# 2009-01-08   314.14   314.14   314.14
# 2009-01-09   312.90   312.90   312.90
# ...             ...      ...      ...
# 2025-03-14  1387.03  1394.39  1385.20
# 2025-03-17  1394.90  1397.28  1389.42
# 2025-03-18  1388.64  1400.38  1388.64
# 2025-03-19  1377.63  1386.57  1374.83
# 2025-03-20  1378.95  1388.37  1371.98
#
# [4044 rows x 3 columns]

# %%
# Vẽ biểu đồ
plt.figure(figsize=(8, 5))
plt.plot(series.index, series['close'], label='close', color='blue')
plt.plot(series.index, series['high'], label='high', color='green')
plt.plot(series.index, series['low'], label='low', color='red')

# Định dạng biểu đồ
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Stock Price Time Series')
plt.legend()
plt.grid(True)

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# ### Bước 2: Chia dữ liệu thành các tập Train, Validation, Test

# %%
series.shape
# Out:
# (4044, 3)

# %%
n = series.shape[0]
val_size =  test_size = int(n * 0.15)
train_size = n - val_size - test_size # Để tránh sai số làm mất dữ liệu

# Chia tập dữ liệu theo thứ tự thời gian
train_data = series.iloc[:train_size].values
val_data = series.iloc[train_size:train_size + val_size].values
test_data = series.iloc[(train_size + val_size):].values
# Kiểm tra kích thước của từng tập
print(train_data.shape, val_data.shape, test_data.shape)
# Out:
# (2832, 3) (606, 3) (606, 3)

# %% [markdown]
# ### Bước 3: Chuẩn hóa dữ liệu bằng MinMaxScaler

# %%
# Chuẩn hóa
sc = MinMaxScaler() # Tạo bộ chuẩn hóa MinMaxScaler
train = sc.fit_transform(train_data)
val = sc.transform(val_data)
test = sc.transform(test_data)

print(train.shape, val.shape, test.shape)
# Out:
# (2832, 3) (606, 3) (606, 3)

# %% [markdown]
# ### Bước 4: Tìm siêu tham số tốt nhất bằng Grid Search

# %%
from keras.layers import GRU

# %%
best_params, best_score, results_df = grid_search_rnn(train, val, test, param_grid)

print("Best parameters:", best_params)
print("Best RMSE score:", best_score)
# Out:
# Training with param: {'timesteps': 50, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 64, 'num_epochs': 250}
# 2025-06-01 14:04:19.884174: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss improved from inf to 1.32578, saving model to best_model11.h5
#
# Epoch 2: val_loss improved from 1.32578 to 1.01687, saving model to best_model11.h5
#
# Epoch 3: val_loss improved from 1.01687 to 0.76183, saving model to best_model11.h5
#
# Epoch 4: val_loss improved from 0.76183 to 0.49359, saving model to best_model11.h5
#
# Epoch 5: val_loss improved from 0.49359 to 0.27626, saving model to best_model11.h5
#
# Epoch 6: val_loss improved from 0.27626 to 0.11895, saving model to best_model11.h5
#
# Epoch 7: val_loss improved from 0.11895 to 0.04777, saving model to best_model11.h5
#
# Epoch 8: val_loss improved from 0.04777 to 0.03019, saving model to best_model11.h5
#
# Epoch 9: val_loss improved from 0.03019 to 0.02762, saving model to best_model11.h5
#
# Epoch 10: val_loss improved from 0.02762 to 0.02616, saving model to best_model11.h5
#
# Epoch 11: val_loss improved from 0.02616 to 0.02415, saving model to best_model11.h5
#
# Epoch 12: val_loss improved from 0.02415 to 0.02090, saving model to best_model11.h5
#
# Epoch 13: val_loss improved from 0.02090 to 0.01600, saving model to best_model11.h5
#
# Epoch 14: val_loss improved from 0.01600 to 0.01289, saving model to best_model11.h5
#
# Epoch 15: val_loss improved from 0.01289 to 0.01065, saving model to best_model11.h5
#
# Epoch 16: val_loss improved from 0.01065 to 0.00884, saving model to best_model11.h5
#
# Epoch 17: val_loss improved from 0.00884 to 0.00721, saving model to best_model11.h5
#
# Epoch 18: val_loss improved from 0.00721 to 0.00601, saving model to best_model11.h5
#
# Epoch 19: val_loss improved from 0.00601 to 0.00475, saving model to best_model11.h5
#
# Epoch 20: val_loss improved from 0.00475 to 0.00397, saving model to best_model11.h5
#
# Epoch 21: val_loss improved from 0.00397 to 0.00348, saving model to best_model11.h5
#
# Epoch 22: val_loss improved from 0.00348 to 0.00321, saving model to best_model11.h5
#
# Epoch 23: val_loss improved from 0.00321 to 0.00302, saving model to best_model11.h5
#
# Epoch 24: val_loss improved from 0.00302 to 0.00290, saving model to best_model11.h5
#
# Epoch 25: val_loss improved from 0.00290 to 0.00279, saving model to best_model11.h5
#
# Epoch 26: val_loss improved from 0.00279 to 0.00270, saving model to best_model11.h5
#
# Epoch 27: val_loss improved from 0.00270 to 0.00262, saving model to best_model11.h5
#
# Epoch 28: val_loss improved from 0.00262 to 0.00255, saving model to best_model11.h5
#
# Epoch 29: val_loss improved from 0.00255 to 0.00248, saving model to best_model11.h5
#
# Epoch 30: val_loss improved from 0.00248 to 0.00243, saving model to best_model11.h5
#
# Epoch 31: val_loss improved from 0.00243 to 0.00239, saving model to best_model11.h5
#
# Epoch 32: val_loss improved from 0.00239 to 0.00235, saving model to best_model11.h5
#
# Epoch 33: val_loss improved from 0.00235 to 0.00233, saving model to best_model11.h5
#
# Epoch 34: val_loss improved from 0.00233 to 0.00230, saving model to best_model11.h5
#
# Epoch 35: val_loss improved from 0.00230 to 0.00227, saving model to best_model11.h5
#
# Epoch 36: val_loss improved from 0.00227 to 0.00225, saving model to best_model11.h5
#
# Epoch 37: val_loss improved from 0.00225 to 0.00223, saving model to best_model11.h5
#
# Epoch 38: val_loss improved from 0.00223 to 0.00220, saving model to best_model11.h5
#
# Epoch 39: val_loss improved from 0.00220 to 0.00217, saving model to best_model11.h5
#
# Epoch 40: val_loss improved from 0.00217 to 0.00215, saving model to best_model11.h5
#
# Epoch 41: val_loss improved from 0.00215 to 0.00213, saving model to best_model11.h5
#
# Epoch 42: val_loss improved from 0.00213 to 0.00211, saving model to best_model11.h5
#
# Epoch 43: val_loss improved from 0.00211 to 0.00209, saving model to best_model11.h5
#
# Epoch 44: val_loss improved from 0.00209 to 0.00208, saving model to best_model11.h5
#
# Epoch 45: val_loss improved from 0.00208 to 0.00208, saving model to best_model11.h5
#
# Epoch 46: val_loss improved from 0.00208 to 0.00205, saving model to best_model11.h5
#
# Epoch 47: val_loss improved from 0.00205 to 0.00203, saving model to best_model11.h5
#
# Epoch 48: val_loss improved from 0.00203 to 0.00201, saving model to best_model11.h5
#
# Epoch 49: val_loss improved from 0.00201 to 0.00200, saving model to best_model11.h5
#
# Epoch 50: val_loss improved from 0.00200 to 0.00198, saving model to best_model11.h5
#
# Epoch 51: val_loss improved from 0.00198 to 0.00198, saving model to best_model11.h5
#
# Epoch 52: val_loss improved from 0.00198 to 0.00197, saving model to best_model11.h5
#
# Epoch 53: val_loss improved from 0.00197 to 0.00196, saving model to best_model11.h5
#
# Epoch 54: val_loss improved from 0.00196 to 0.00195, saving model to best_model11.h5
#
# Epoch 55: val_loss improved from 0.00195 to 0.00193, saving model to best_model11.h5
#
# Epoch 56: val_loss improved from 0.00193 to 0.00191, saving model to best_model11.h5
#
# Epoch 57: val_loss improved from 0.00191 to 0.00190, saving model to best_model11.h5
#
# Epoch 58: val_loss improved from 0.00190 to 0.00188, saving model to best_model11.h5
#
# Epoch 59: val_loss improved from 0.00188 to 0.00186, saving model to best_model11.h5
#
# Epoch 60: val_loss improved from 0.00186 to 0.00185, saving model to best_model11.h5
#
# Epoch 61: val_loss improved from 0.00185 to 0.00184, saving model to best_model11.h5
#
# Epoch 62: val_loss improved from 0.00184 to 0.00184, saving model to best_model11.h5
#
# Epoch 63: val_loss did not improve from 0.00184
#
# Epoch 64: val_loss improved from 0.00184 to 0.00183, saving model to best_model11.h5
#
# Epoch 65: val_loss improved from 0.00183 to 0.00182, saving model to best_model11.h5
#
# Epoch 66: val_loss improved from 0.00182 to 0.00181, saving model to best_model11.h5
#
# Epoch 67: val_loss did not improve from 0.00181
#
# Epoch 68: val_loss did not improve from 0.00181
#
# Epoch 69: val_loss did not improve from 0.00181
#
# Epoch 70: val_loss did not improve from 0.00181
#
# Epoch 71: val_loss did not improve from 0.00181
#
# Epoch 72: val_loss did not improve from 0.00181
#
# Epoch 73: val_loss did not improve from 0.00181
#
# Epoch 74: val_loss did not improve from 0.00181
#
# Epoch 75: val_loss did not improve from 0.00181
#
# Epoch 76: val_loss did not improve from 0.00181
#
# Epoch 77: val_loss did not improve from 0.00181
#
# Epoch 78: val_loss did not improve from 0.00181
#
# Epoch 79: val_loss improved from 0.00181 to 0.00178, saving model to best_model11.h5
#
# Epoch 80: val_loss did not improve from 0.00178
#
# Epoch 81: val_loss improved from 0.00178 to 0.00174, saving model to best_model11.h5
#
# Epoch 82: val_loss improved from 0.00174 to 0.00173, saving model to best_model11.h5
#
# Epoch 83: val_loss improved from 0.00173 to 0.00171, saving model to best_model11.h5
#
# Epoch 84: val_loss improved from 0.00171 to 0.00168, saving model to best_model11.h5
#
# Epoch 85: val_loss improved from 0.00168 to 0.00164, saving model to best_model11.h5
#
# Epoch 86: val_loss improved from 0.00164 to 0.00160, saving model to best_model11.h5
#
# Epoch 87: val_loss improved from 0.00160 to 0.00150, saving model to best_model11.h5
#
# Epoch 88: val_loss improved from 0.00150 to 0.00147, saving model to best_model11.h5
#
# Epoch 89: val_loss improved from 0.00147 to 0.00145, saving model to best_model11.h5
#
# Epoch 90: val_loss did not improve from 0.00145
#
# Epoch 91: val_loss did not improve from 0.00145
#
# Epoch 92: val_loss did not improve from 0.00145
#
# Epoch 93: val_loss did not improve from 0.00145
#
# Epoch 94: val_loss did not improve from 0.00145
#
# Epoch 95: val_loss did not improve from 0.00145
#
# Epoch 96: val_loss did not improve from 0.00145
#
# Epoch 97: val_loss did not improve from 0.00145
#
# Epoch 98: val_loss did not improve from 0.00145
#
# Epoch 99: val_loss did not improve from 0.00145
#
# Epoch 100: val_loss did not improve from 0.00145
#
# Epoch 101: val_loss did not improve from 0.00145
#
# Epoch 102: val_loss did not improve from 0.00145
#
# Epoch 103: val_loss did not improve from 0.00145
#
# Epoch 104: val_loss did not improve from 0.00145
#
# Epoch 105: val_loss did not improve from 0.00145
#
# Epoch 106: val_loss did not improve from 0.00145
#
# Epoch 107: val_loss did not improve from 0.00145
#
# Epoch 108: val_loss did not improve from 0.00145
#
# Epoch 109: val_loss did not improve from 0.00145
#
# Epoch 110: val_loss did not improve from 0.00145
#
# Epoch 111: val_loss did not improve from 0.00145
#
# Epoch 112: val_loss did not improve from 0.00145
#
# Epoch 113: val_loss did not improve from 0.00145
#
# Epoch 114: val_loss did not improve from 0.00145
#
# Epoch 115: val_loss did not improve from 0.00145
#
# Epoch 116: val_loss did not improve from 0.00145
#
# Epoch 117: val_loss did not improve from 0.00145
#
# Epoch 118: val_loss did not improve from 0.00145
#
# Epoch 119: val_loss did not improve from 0.00145
#
# Epoch 120: val_loss did not improve from 0.00145
#
# Epoch 121: val_loss did not improve from 0.00145
#
# Epoch 122: val_loss did not improve from 0.00145
#
# Epoch 123: val_loss did not improve from 0.00145
#
# Epoch 124: val_loss did not improve from 0.00145
#
# Epoch 125: val_loss did not improve from 0.00145
#
# Epoch 126: val_loss did not improve from 0.00145
#
# Epoch 127: val_loss did not improve from 0.00145
#
# Epoch 128: val_loss did not improve from 0.00145
#
# Epoch 129: val_loss did not improve from 0.00145
#
# Epoch 130: val_loss did not improve from 0.00145
#
# Epoch 131: val_loss did not improve from 0.00145
#
# Epoch 132: val_loss did not improve from 0.00145
#
# Epoch 133: val_loss did not improve from 0.00145
#
# Epoch 134: val_loss did not improve from 0.00145
#
# Epoch 135: val_loss did not improve from 0.00145
#
# Epoch 136: val_loss did not improve from 0.00145
#
# Epoch 137: val_loss did not improve from 0.00145
#
# Epoch 138: val_loss did not improve from 0.00145
#
# Epoch 139: val_loss did not improve from 0.00145
#
# Epoch 140: val_loss did not improve from 0.00145
#
# Epoch 141: val_loss improved from 0.00145 to 0.00143, saving model to best_model11.h5
#
# Epoch 142: val_loss improved from 0.00143 to 0.00141, saving model to best_model11.h5
#
# Epoch 143: val_loss improved from 0.00141 to 0.00139, saving model to best_model11.h5
#
# Epoch 144: val_loss improved from 0.00139 to 0.00137, saving model to best_model11.h5
#
# Epoch 145: val_loss improved from 0.00137 to 0.00134, saving model to best_model11.h5
#
# Epoch 146: val_loss improved from 0.00134 to 0.00132, saving model to best_model11.h5
#
# Epoch 147: val_loss improved from 0.00132 to 0.00130, saving model to best_model11.h5
#
# Epoch 148: val_loss improved from 0.00130 to 0.00128, saving model to best_model11.h5
#
# Epoch 149: val_loss improved from 0.00128 to 0.00128, saving model to best_model11.h5
#
# Epoch 150: val_loss improved from 0.00128 to 0.00125, saving model to best_model11.h5
#
# Epoch 151: val_loss improved from 0.00125 to 0.00121, saving model to best_model11.h5
#
# Epoch 152: val_loss improved from 0.00121 to 0.00118, saving model to best_model11.h5
#
# Epoch 153: val_loss improved from 0.00118 to 0.00114, saving model to best_model11.h5
#
# Epoch 154: val_loss did not improve from 0.00114
#
# Epoch 155: val_loss did not improve from 0.00114
#
# Epoch 156: val_loss improved from 0.00114 to 0.00112, saving model to best_model11.h5
#
# Epoch 157: val_loss improved from 0.00112 to 0.00111, saving model to best_model11.h5
#
# Epoch 158: val_loss improved from 0.00111 to 0.00109, saving model to best_model11.h5
#
# Epoch 159: val_loss improved from 0.00109 to 0.00108, saving model to best_model11.h5
#
# Epoch 160: val_loss did not improve from 0.00108
#
# Epoch 161: val_loss improved from 0.00108 to 0.00107, saving model to best_model11.h5
#
# Epoch 162: val_loss improved from 0.00107 to 0.00107, saving model to best_model11.h5
#
# Epoch 163: val_loss did not improve from 0.00107
#
# Epoch 164: val_loss did not improve from 0.00107
#
# Epoch 165: val_loss improved from 0.00107 to 0.00106, saving model to best_model11.h5
#
# Epoch 166: val_loss did not improve from 0.00106
#
# Epoch 167: val_loss improved from 0.00106 to 0.00106, saving model to best_model11.h5
#
# Epoch 168: val_loss did not improve from 0.00106
#
# Epoch 169: val_loss did not improve from 0.00106
#
# Epoch 170: val_loss did not improve from 0.00106
#
# Epoch 171: val_loss did not improve from 0.00106
#
# Epoch 172: val_loss did not improve from 0.00106
#
# Epoch 173: val_loss did not improve from 0.00106
#
# Epoch 174: val_loss did not improve from 0.00106
#
# Epoch 175: val_loss did not improve from 0.00106
#
# Epoch 176: val_loss did not improve from 0.00106
#
# Epoch 177: val_loss did not improve from 0.00106
#
# Epoch 178: val_loss did not improve from 0.00106
#
# Epoch 179: val_loss did not improve from 0.00106
#
# Epoch 180: val_loss did not improve from 0.00106
#
# Epoch 181: val_loss did not improve from 0.00106
#
# Epoch 182: val_loss did not improve from 0.00106
#
# Epoch 183: val_loss improved from 0.00106 to 0.00103, saving model to best_model11.h5
#
# Epoch 184: val_loss did not improve from 0.00103
#
# Epoch 185: val_loss did not improve from 0.00103
#
# Epoch 186: val_loss did not improve from 0.00103
#
# Epoch 187: val_loss did not improve from 0.00103
#
# Epoch 188: val_loss did not improve from 0.00103
#
# Epoch 189: val_loss did not improve from 0.00103
#
# Epoch 190: val_loss did not improve from 0.00103
#
# Epoch 191: val_loss did not improve from 0.00103
#
# Epoch 192: val_loss did not improve from 0.00103
#
# Epoch 193: val_loss did not improve from 0.00103
#
# Epoch 194: val_loss improved from 0.00103 to 0.00101, saving model to best_model11.h5
#
# Epoch 195: val_loss did not improve from 0.00101
#
# Epoch 196: val_loss improved from 0.00101 to 0.00099, saving model to best_model11.h5
#
# Epoch 197: val_loss did not improve from 0.00099
#
# Epoch 198: val_loss did not improve from 0.00099
#
# Epoch 199: val_loss did not improve from 0.00099
#
# Epoch 200: val_loss did not improve from 0.00099
#
# Epoch 201: val_loss did not improve from 0.00099
#
# Epoch 202: val_loss did not improve from 0.00099
#
# Epoch 203: val_loss did not improve from 0.00099
#
# Epoch 204: val_loss did not improve from 0.00099
#
# Epoch 205: val_loss did not improve from 0.00099
#
# Epoch 206: val_loss improved from 0.00099 to 0.00098, saving model to best_model11.h5
#
# Epoch 207: val_loss improved from 0.00098 to 0.00094, saving model to best_model11.h5
#
# Epoch 208: val_loss did not improve from 0.00094
#
# Epoch 209: val_loss did not improve from 0.00094
#
# Epoch 210: val_loss did not improve from 0.00094
#
# Epoch 211: val_loss did not improve from 0.00094
#
# Epoch 212: val_loss did not improve from 0.00094
#
# Epoch 213: val_loss did not improve from 0.00094
#
# Epoch 214: val_loss did not improve from 0.00094
#
# Epoch 215: val_loss did not improve from 0.00094
#
# Epoch 216: val_loss did not improve from 0.00094
#
# Epoch 217: val_loss did not improve from 0.00094
#
# Epoch 218: val_loss did not improve from 0.00094
#
# Epoch 219: val_loss improved from 0.00094 to 0.00090, saving model to best_model11.h5
#
# Epoch 220: val_loss improved from 0.00090 to 0.00090, saving model to best_model11.h5
#
# Epoch 221: val_loss did not improve from 0.00090
#
# Epoch 222: val_loss did not improve from 0.00090
#
# Epoch 223: val_loss improved from 0.00090 to 0.00088, saving model to best_model11.h5
#
# Epoch 224: val_loss improved from 0.00088 to 0.00086, saving model to best_model11.h5
#
# Epoch 225: val_loss did not improve from 0.00086
#
# Epoch 226: val_loss did not improve from 0.00086
#
# Epoch 227: val_loss did not improve from 0.00086
#
# Epoch 228: val_loss did not improve from 0.00086
#
# Epoch 229: val_loss did not improve from 0.00086
#
# Epoch 230: val_loss did not improve from 0.00086
#
# Epoch 231: val_loss improved from 0.00086 to 0.00084, saving model to best_model11.h5
#
# Epoch 232: val_loss improved from 0.00084 to 0.00079, saving model to best_model11.h5
#
# Epoch 233: val_loss did not improve from 0.00079
#
# Epoch 234: val_loss did not improve from 0.00079
#
# Epoch 235: val_loss did not improve from 0.00079
#
# Epoch 236: val_loss did not improve from 0.00079
#
# Epoch 237: val_loss did not improve from 0.00079
#
# Epoch 238: val_loss did not improve from 0.00079
#
# Epoch 239: val_loss did not improve from 0.00079
#
# Epoch 240: val_loss did not improve from 0.00079
#
# Epoch 241: val_loss did not improve from 0.00079
#
# Epoch 242: val_loss did not improve from 0.00079
#
# Epoch 243: val_loss did not improve from 0.00079
#
# Epoch 244: val_loss did not improve from 0.00079
#
# Epoch 245: val_loss did not improve from 0.00079
#
# Epoch 246: val_loss did not improve from 0.00079
#
# Epoch 247: val_loss did not improve from 0.00079
#
# Epoch 248: val_loss did not improve from 0.00079
#
# Epoch 249: val_loss did not improve from 0.00079
#
# Epoch 250: val_loss did not improve from 0.00079
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# Best parameters: {'timesteps': 50, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 64, 'num_epochs': 250}
# Best RMSE score: 0.015964560299771977

# %% [markdown]
# ### Bước 5: Huấn luyện mô hình với bộ tham số tối ưu

# %%
timesteps = 50
hl = [40, 35]
lr = 0.0001
batch_size = 64
num_epochs = 250

model, train_error, val_error = fit_model_2(train, val, timesteps, hl, lr, batch_size, num_epochs)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00079
#
# Epoch 2: val_loss did not improve from 0.00079
#
# Epoch 3: val_loss did not improve from 0.00079
#
# Epoch 4: val_loss did not improve from 0.00079
#
# Epoch 5: val_loss did not improve from 0.00079
#
# Epoch 6: val_loss did not improve from 0.00079
#
# Epoch 7: val_loss did not improve from 0.00079
#
# Epoch 8: val_loss did not improve from 0.00079
#
# Epoch 9: val_loss did not improve from 0.00079
#
# Epoch 10: val_loss did not improve from 0.00079
#
# Epoch 11: val_loss did not improve from 0.00079
#
# Epoch 12: val_loss did not improve from 0.00079
#
# Epoch 13: val_loss did not improve from 0.00079
#
# Epoch 14: val_loss did not improve from 0.00079
#
# Epoch 15: val_loss did not improve from 0.00079
#
# Epoch 16: val_loss did not improve from 0.00079
#
# Epoch 17: val_loss did not improve from 0.00079
#
# Epoch 18: val_loss did not improve from 0.00079
#
# Epoch 19: val_loss did not improve from 0.00079
#
# Epoch 20: val_loss did not improve from 0.00079
#
# Epoch 21: val_loss did not improve from 0.00079
#
# Epoch 22: val_loss did not improve from 0.00079
#
# Epoch 23: val_loss did not improve from 0.00079
#
# Epoch 24: val_loss did not improve from 0.00079
#
# Epoch 25: val_loss did not improve from 0.00079
#
# Epoch 26: val_loss did not improve from 0.00079
#
# Epoch 27: val_loss did not improve from 0.00079
#
# Epoch 28: val_loss did not improve from 0.00079
#
# Epoch 29: val_loss did not improve from 0.00079
#
# Epoch 30: val_loss did not improve from 0.00079
#
# Epoch 31: val_loss did not improve from 0.00079
#
# Epoch 32: val_loss did not improve from 0.00079
#
# Epoch 33: val_loss did not improve from 0.00079
#
# Epoch 34: val_loss did not improve from 0.00079
#
# Epoch 35: val_loss did not improve from 0.00079
#
# Epoch 36: val_loss did not improve from 0.00079
#
# Epoch 37: val_loss did not improve from 0.00079
#
# Epoch 38: val_loss did not improve from 0.00079
#
# Epoch 39: val_loss did not improve from 0.00079
#
# Epoch 40: val_loss did not improve from 0.00079
#
# Epoch 41: val_loss did not improve from 0.00079
#
# Epoch 42: val_loss did not improve from 0.00079
#
# Epoch 43: val_loss did not improve from 0.00079
#
# Epoch 44: val_loss did not improve from 0.00079
#
# Epoch 45: val_loss did not improve from 0.00079
#
# Epoch 46: val_loss did not improve from 0.00079
#
# Epoch 47: val_loss did not improve from 0.00079
#
# Epoch 48: val_loss did not improve from 0.00079
#
# Epoch 49: val_loss did not improve from 0.00079
#
# Epoch 50: val_loss did not improve from 0.00079
#
# Epoch 51: val_loss did not improve from 0.00079
#
# Epoch 52: val_loss did not improve from 0.00079
#
# Epoch 53: val_loss did not improve from 0.00079
#
# Epoch 54: val_loss did not improve from 0.00079
#
# Epoch 55: val_loss did not improve from 0.00079
#
# Epoch 56: val_loss did not improve from 0.00079
#
# Epoch 57: val_loss did not improve from 0.00079
#
# Epoch 58: val_loss did not improve from 0.00079
#
# Epoch 59: val_loss did not improve from 0.00079
#
# Epoch 60: val_loss did not improve from 0.00079
#
# Epoch 61: val_loss did not improve from 0.00079
#
# Epoch 62: val_loss did not improve from 0.00079
#
# Epoch 63: val_loss did not improve from 0.00079
#
# Epoch 64: val_loss did not improve from 0.00079
#
# Epoch 65: val_loss did not improve from 0.00079
#
# Epoch 66: val_loss did not improve from 0.00079
#
# Epoch 67: val_loss did not improve from 0.00079
#
# Epoch 68: val_loss did not improve from 0.00079
#
# Epoch 69: val_loss did not improve from 0.00079
#
# Epoch 70: val_loss did not improve from 0.00079
#
# Epoch 71: val_loss did not improve from 0.00079
#
# Epoch 72: val_loss did not improve from 0.00079
#
# Epoch 73: val_loss did not improve from 0.00079
#
# Epoch 74: val_loss did not improve from 0.00079
#
# Epoch 75: val_loss did not improve from 0.00079
#
# Epoch 76: val_loss did not improve from 0.00079
#
# Epoch 77: val_loss did not improve from 0.00079
#
# Epoch 78: val_loss did not improve from 0.00079
#
# Epoch 79: val_loss did not improve from 0.00079
#
# Epoch 80: val_loss did not improve from 0.00079
#
# Epoch 81: val_loss did not improve from 0.00079
#
# Epoch 82: val_loss did not improve from 0.00079
#
# Epoch 83: val_loss did not improve from 0.00079
#
# Epoch 84: val_loss did not improve from 0.00079
#
# Epoch 85: val_loss did not improve from 0.00079
#
# Epoch 86: val_loss did not improve from 0.00079
#
# Epoch 87: val_loss did not improve from 0.00079
#
# Epoch 88: val_loss did not improve from 0.00079
#
# Epoch 89: val_loss did not improve from 0.00079
#
# Epoch 90: val_loss did not improve from 0.00079
#
# Epoch 91: val_loss did not improve from 0.00079
#
# Epoch 92: val_loss did not improve from 0.00079
#
# Epoch 93: val_loss did not improve from 0.00079
#
# Epoch 94: val_loss did not improve from 0.00079
#
# Epoch 95: val_loss did not improve from 0.00079
#
# Epoch 96: val_loss did not improve from 0.00079
#
# Epoch 97: val_loss did not improve from 0.00079
#
# Epoch 98: val_loss did not improve from 0.00079
#
# Epoch 99: val_loss did not improve from 0.00079
#
# Epoch 100: val_loss did not improve from 0.00079
#
# Epoch 101: val_loss did not improve from 0.00079
#
# Epoch 102: val_loss did not improve from 0.00079
#
# Epoch 103: val_loss did not improve from 0.00079
#
# Epoch 104: val_loss did not improve from 0.00079
#
# Epoch 105: val_loss did not improve from 0.00079
#
# Epoch 106: val_loss did not improve from 0.00079
#
# Epoch 107: val_loss did not improve from 0.00079
#
# Epoch 108: val_loss did not improve from 0.00079
#
# Epoch 109: val_loss did not improve from 0.00079
#
# Epoch 110: val_loss did not improve from 0.00079
#
# Epoch 111: val_loss did not improve from 0.00079
#
# Epoch 112: val_loss did not improve from 0.00079
#
# Epoch 113: val_loss did not improve from 0.00079
#
# Epoch 114: val_loss did not improve from 0.00079
#
# Epoch 115: val_loss did not improve from 0.00079
#
# Epoch 116: val_loss did not improve from 0.00079
#
# Epoch 117: val_loss did not improve from 0.00079
#
# Epoch 118: val_loss did not improve from 0.00079
#
# Epoch 119: val_loss did not improve from 0.00079
#
# Epoch 120: val_loss did not improve from 0.00079
#
# Epoch 121: val_loss did not improve from 0.00079
#
# Epoch 122: val_loss did not improve from 0.00079
#
# Epoch 123: val_loss did not improve from 0.00079
#
# Epoch 124: val_loss did not improve from 0.00079
#
# Epoch 125: val_loss did not improve from 0.00079
#
# Epoch 126: val_loss did not improve from 0.00079
#
# Epoch 127: val_loss did not improve from 0.00079
#
# Epoch 128: val_loss did not improve from 0.00079
#
# Epoch 129: val_loss did not improve from 0.00079
#
# Epoch 130: val_loss did not improve from 0.00079
#
# Epoch 131: val_loss did not improve from 0.00079
#
# Epoch 132: val_loss did not improve from 0.00079
#
# Epoch 133: val_loss did not improve from 0.00079
#
# Epoch 134: val_loss did not improve from 0.00079
#
# Epoch 135: val_loss did not improve from 0.00079
#
# Epoch 136: val_loss did not improve from 0.00079
#
# Epoch 137: val_loss did not improve from 0.00079
#
# Epoch 138: val_loss did not improve from 0.00079
#
# Epoch 139: val_loss did not improve from 0.00079
#
# Epoch 140: val_loss did not improve from 0.00079
#
# Epoch 141: val_loss did not improve from 0.00079
#
# Epoch 142: val_loss did not improve from 0.00079
#
# Epoch 143: val_loss did not improve from 0.00079
#
# Epoch 144: val_loss did not improve from 0.00079
#
# Epoch 145: val_loss did not improve from 0.00079
#
# Epoch 146: val_loss did not improve from 0.00079
#
# Epoch 147: val_loss did not improve from 0.00079
#
# Epoch 148: val_loss did not improve from 0.00079
#
# Epoch 149: val_loss did not improve from 0.00079
#
# Epoch 150: val_loss did not improve from 0.00079
#
# Epoch 151: val_loss did not improve from 0.00079
#
# Epoch 152: val_loss did not improve from 0.00079
#
# Epoch 153: val_loss did not improve from 0.00079
#
# Epoch 154: val_loss did not improve from 0.00079
#
# Epoch 155: val_loss did not improve from 0.00079
#
# Epoch 156: val_loss did not improve from 0.00079
#
# Epoch 157: val_loss did not improve from 0.00079
#
# Epoch 158: val_loss did not improve from 0.00079
#
# Epoch 159: val_loss did not improve from 0.00079
#
# Epoch 160: val_loss did not improve from 0.00079
#
# Epoch 161: val_loss did not improve from 0.00079
#
# Epoch 162: val_loss did not improve from 0.00079
#
# Epoch 163: val_loss did not improve from 0.00079
#
# Epoch 164: val_loss did not improve from 0.00079
#
# Epoch 165: val_loss did not improve from 0.00079
#
# Epoch 166: val_loss did not improve from 0.00079
#
# Epoch 167: val_loss did not improve from 0.00079
#
# Epoch 168: val_loss did not improve from 0.00079
#
# Epoch 169: val_loss did not improve from 0.00079
#
# Epoch 170: val_loss did not improve from 0.00079
#
# Epoch 171: val_loss did not improve from 0.00079
#
# Epoch 172: val_loss did not improve from 0.00079
#
# Epoch 173: val_loss did not improve from 0.00079
#
# Epoch 174: val_loss did not improve from 0.00079
#
# Epoch 175: val_loss did not improve from 0.00079
#
# Epoch 176: val_loss did not improve from 0.00079
#
# Epoch 177: val_loss did not improve from 0.00079
#
# Epoch 178: val_loss did not improve from 0.00079
#
# Epoch 179: val_loss did not improve from 0.00079
#
# Epoch 180: val_loss did not improve from 0.00079
#
# Epoch 181: val_loss did not improve from 0.00079
#
# Epoch 182: val_loss did not improve from 0.00079
#
# Epoch 183: val_loss did not improve from 0.00079
#
# Epoch 184: val_loss did not improve from 0.00079
#
# Epoch 185: val_loss did not improve from 0.00079
#
# Epoch 186: val_loss did not improve from 0.00079
#
# Epoch 187: val_loss did not improve from 0.00079
#
# Epoch 188: val_loss did not improve from 0.00079
#
# Epoch 189: val_loss did not improve from 0.00079
#
# Epoch 190: val_loss did not improve from 0.00079
#
# Epoch 191: val_loss did not improve from 0.00079
#
# Epoch 192: val_loss did not improve from 0.00079
#
# Epoch 193: val_loss did not improve from 0.00079
#
# Epoch 194: val_loss did not improve from 0.00079
#
# Epoch 195: val_loss did not improve from 0.00079
#
# Epoch 196: val_loss did not improve from 0.00079
#
# Epoch 197: val_loss did not improve from 0.00079
#
# Epoch 198: val_loss did not improve from 0.00079
#
# Epoch 199: val_loss did not improve from 0.00079
#
# Epoch 200: val_loss did not improve from 0.00079
#
# Epoch 201: val_loss did not improve from 0.00079
#
# Epoch 202: val_loss did not improve from 0.00079
#
# Epoch 203: val_loss did not improve from 0.00079
#
# Epoch 204: val_loss did not improve from 0.00079
#
# Epoch 205: val_loss did not improve from 0.00079
#
# Epoch 206: val_loss did not improve from 0.00079
#
# Epoch 207: val_loss did not improve from 0.00079
#
# Epoch 208: val_loss did not improve from 0.00079
#
# Epoch 209: val_loss did not improve from 0.00079
#
# Epoch 210: val_loss did not improve from 0.00079
#
# Epoch 211: val_loss did not improve from 0.00079
#
# Epoch 212: val_loss did not improve from 0.00079
#
# Epoch 213: val_loss did not improve from 0.00079
#
# Epoch 214: val_loss did not improve from 0.00079
#
# Epoch 215: val_loss did not improve from 0.00079
#
# Epoch 216: val_loss did not improve from 0.00079
#
# Epoch 217: val_loss did not improve from 0.00079
#
# Epoch 218: val_loss did not improve from 0.00079
#
# Epoch 219: val_loss did not improve from 0.00079
#
# Epoch 220: val_loss did not improve from 0.00079
#
# Epoch 221: val_loss did not improve from 0.00079
#
# Epoch 222: val_loss did not improve from 0.00079
#
# Epoch 223: val_loss did not improve from 0.00079
#
# Epoch 224: val_loss did not improve from 0.00079
#
# Epoch 225: val_loss did not improve from 0.00079
#
# Epoch 226: val_loss did not improve from 0.00079
#
# Epoch 227: val_loss did not improve from 0.00079
#
# Epoch 228: val_loss did not improve from 0.00079
#
# Epoch 229: val_loss did not improve from 0.00079
#
# Epoch 230: val_loss did not improve from 0.00079
#
# Epoch 231: val_loss did not improve from 0.00079
#
# Epoch 232: val_loss did not improve from 0.00079
#
# Epoch 233: val_loss did not improve from 0.00079
#
# Epoch 234: val_loss did not improve from 0.00079
#
# Epoch 235: val_loss did not improve from 0.00079
#
# Epoch 236: val_loss did not improve from 0.00079
#
# Epoch 237: val_loss did not improve from 0.00079
#
# Epoch 238: val_loss did not improve from 0.00079
#
# Epoch 239: val_loss did not improve from 0.00079
#
# Epoch 240: val_loss did not improve from 0.00079
#
# Epoch 241: val_loss did not improve from 0.00079
#
# Epoch 242: val_loss did not improve from 0.00079
#
# Epoch 243: val_loss did not improve from 0.00079
#
# Epoch 244: val_loss did not improve from 0.00079
#
# Epoch 245: val_loss did not improve from 0.00079
#
# Epoch 246: val_loss did not improve from 0.00079
#
# Epoch 247: val_loss did not improve from 0.00079
#
# Epoch 248: val_loss did not improve from 0.00079
#
# Epoch 249: val_loss did not improve from 0.00079
#
# Epoch 250: val_loss did not improve from 0.00079

# %% [markdown]
# ### Bước 6: Đánh giá mô hình và trực quan hóa kết quả

# %% [markdown]
# #### 6.1. Vẽ biểu đồ train_loss và val_loss

# %%
plot_error(train_error, val_error)

# %% [markdown]
# #### 6.2. Đánh giá mô hình trên tập test

# %%
mse, rmse, mape, r2, true, predicted = evaluate_model_2(model, test, timesteps) #được tính dựa trên bộ dữ liệu đã chuẩn hoá
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step

# %%
print('MSE = {}'.format(mse))
print('RMSE = {}'.format(rmse))
print('MAPE = {}'.format(mape))
print('R-Squared Score = {}'.format(r2))
# Out:
# MSE = 0.0002548671855650555
# RMSE = 0.015964560299771977
# MAPE = 0.012352491620391736
# R-Squared Score = 0.9803574524457459

# %% [markdown]
# #### 6.3. Vẽ đồ thị dự đoán vs thực tế

# %%
plot_data_2(true, predicted)

# %%
# Save a model
model.save('3VAR-VN30index-rnn.keras')

# %%
del model

# %% [markdown]
# # Model 2: Multivariate-3-GRU

# %% [markdown]
# ## GRU

# %% [markdown]
# ### Import các thư viện cần thiết

# %%
import os
os.environ['PYTHONHASHSEED'] = '0' # đảm bảo rằng các giá trị băm của đối tượng bất biến (dict, set, chuỗi, tuple...) luôn giống nhau giữa các lần chạy

import random as rn
import numpy as np
np.random.seed(1)
rn.seed(3)
import tensorflow as tf
tf.random.set_seed(2)

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, GRU, Dropout
from tensorflow.keras import optimizers

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from math import sqrt
import datetime as dt
import time

from tensorflow.keras.optimizers import Adam

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### Hàm callback

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')  
checkpoint = ModelCheckpoint(
    filepath="3Var-Vn30-gru.h5",   # Tên file lưu mô hình
    monitor="val_loss",         # Theo dõi val_loss
    save_best_only=True,        # Chỉ lưu khi tốt hơn mô hình trước đó
    mode="min",                 # Giảm min của val_loss là tốt nhất
    verbose=1
)
callbacks_list = [earlystop, checkpoint]

# %% [markdown]
# ### Đọc dữ liệu từ file csv

# %%
url = r"VN30 Index.csv"
df = pd.read_csv(url, parse_dates= True, index_col= 0)

# %%
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#               open    high     low   close  volume
# time
# 2009-01-05  311.23  311.23  311.23  311.23     NaN
# 2009-01-06  314.21  314.21  314.21  314.21     NaN
# 2009-01-07  320.53  320.53  320.53  320.53     NaN
# 2009-01-08  314.14  314.14  314.14  314.14     NaN
# 2009-01-09  312.90  312.90  312.90  312.90     NaN

# %%
df.isnull().sum()
# Out:
# open        0
# high        0
# low         0
# close       0
# volume    859
# dtype: int64

# %% [markdown]
# ### Tiền xử lí dữ liệu

# %%
# Xóa các dòng có giá trị Volume bằng 0
df.drop(df[df['volume']==0].index, inplace=True)

# %%
# Ma trận tương quan (ở đây là Pearson tương quan tuyến tính)
df.corr()['close']
# Out:
# open      0.999562
# high      0.999783
# low       0.999789
# close     1.000000
# volume    0.169492
# Name: close, dtype: float64

# %%
print(df.describe().volume)
# Out:
# count    3.185000e+03
# mean     3.279171e+06
# std      2.776577e+07
# min      4.540000e+03
# 25%      3.809000e+04
# 50%      6.036000e+04
# 75%      1.560100e+05
# max      3.744900e+08
# Name: volume, dtype: float64

# %%
df['volume'].hist(bins= 10)
# Out:
# <Axes: >

# %% [markdown]
# ## Train model / Hàm **fit_model_3()**

# %%
def fit_model_3(train, val, timesteps, hl, lr, batch, epochs):
    """
    np.random.seed(1)
    tf.random.set_seed(2)
    rn.seed(3)
    """
    X_train = []
    Y_train = []
    X_val = []
    Y_val = []

    for i in range(timesteps, train.shape[0]):
        X_train.append(train[i-timesteps:i])
        Y_train.append(train[i][0])
    X_train, Y_train = np.array(X_train), np.array(Y_train)

    for i in range(timesteps, val.shape[0]):
        X_val.append(val[i-timesteps:i])
        Y_val.append(val[i][0])
    X_val, Y_val = np.array(X_val), np.array(Y_val)

    # Thêm các lớp vào mô hình
    model = Sequential()
    model.add(GRU(X_train.shape[2], input_shape= (X_train.shape[1], X_train.shape[2]), activation= 'relu', return_sequences= True))
    for i in range(len(hl)-1):
        model.add(GRU(hl[i], activation='relu', return_sequences= True))
    model.add(GRU(hl[-1], activation='relu'))
    model.add(Dense(1))

    # Biên dịch
    model.compile(optimizer= optimizers.Adam(learning_rate= lr), loss= 'mean_squared_error')

    # Huấn luyện dữ liệu
    history = model.fit(X_train, Y_train, epochs= epochs, batch_size= batch, validation_data= (X_val, Y_val), verbose= 0, shuffle= False, callbacks= callbacks_list)
    
    # Đặt lại trạng thái
    for layer in model.layers:
        if isinstance(layer, GRU):
            layer.reset_states()
    
    return model, history.history['loss'], history.history['val_loss']

# %% [markdown]
# ## Hàm **Evaluate_model_3()**

# %%
def evaluate_model_3(model, test, timesteps):
    """
    np.random.seed(1)
    tf.random.set_seed(2)
    """
    X_test = []
    Y_test = []

    for i in range(timesteps, test.shape[0]):
        X_test.append(test[i-timesteps:i])
        Y_test.append(test[i][0])
    X_test, Y_test= np.array(X_test), np.array(Y_test)

    # Các chỉ số đánh giá
    Y_hat = model.predict(X_test)
    mse = mean_squared_error(Y_test, Y_hat)
    rmse = sqrt(mse)
    mape = mean_absolute_percentage_error(Y_test, Y_hat)
    r2 = r2_score(Y_test, Y_hat)

    return mse, rmse, mape, r2, Y_test, Y_hat

# %% [markdown]
# ## **Grid Search**: Tìm kiếm siêu tham số tối ưu

# %%
param_grid = {
    'timesteps': [30, 40, 50],
    'hl': [[40, 35]],
    'lr': [1e-4, 1e-3],
    'batch_size': [32, 64],
    'num_epochs': [200, 250]
}

# %%
# Hàm grid search
def grid_search_rnn(train, val, test, param_grid):
    results = []
    best_score = float('inf')
    best_params = None

    # Tạo tất cả các tổ hợp tham số
    all_combinations = list(product(*(param_grid.values())))
    param_names = param_grid.keys()

    for combination in all_combinations:
        # Gán giá trị tham số hiện tại
        params = dict(zip(param_names, combination))
        hl = params['hl']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']

        print(f'Training with params: {params}')

        # Huấn luyện mô hình
        model, train_loss, val_loss = fit_model_3(train, val, timesteps, hl, lr, batch_size, num_epochs)

        # Đánh giá mô hình
        mse, rmse, mape, r2, _, _ = evaluate_model_3(model, test, timesteps)

        # Lưu kết quả
        results.append({
            'timesteps': timesteps,
            'hl': hl,
            'lr': lr,
            'batch_size': batch_size,
            'num_epochs': num_epochs,
            'mse': mse,
            'rmse': rmse,
            'mape': mape,
            'r2': r2
        })

        # Cập nhật tham số tốt nhất nếu RMSE cải thiện
        if rmse < best_score:
            best_score = rmse
            best_params = params

        # Trả về kết quả
        results_df = pd.DataFrame(results)
        return best_params, best_score, results_df

# %% [markdown]
# ## Plot chart (vẽ biểu đồ)

# %%
# Plotting the predictions
def plot_data_3(Y_test, Y_hat):
    plt.plot(Y_test, c = 'r')
    plt.plot(Y_hat, c = 'y')
    plt.xlabel('Day')
    plt.ylabel('Price')
    plt.title("Stock Price Prediction using Multivariate-GRU")
    plt.legend(['Actual','Predicted'], loc = 'lower right')
    plt.show()

# %%
# Plotting the training errors: trực quan loss qua các epoch -> thấy qtr học mô hình, xem có overfitting ko
def plot_error(train_loss, val_loss):
    plt.plot(train_loss, c = 'r')
    plt.plot(val_loss, c = 'b')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.title('Train Loss and Validation Loss Curve')
    plt.legend(['train', 'val'], loc = 'upper right')
    plt.show()

# %% [markdown]
# ## **Model building**: Xây dựng mô hình

# %% [markdown]
# ### Bước 1: Trích xuất và trực quan hóa dữ liệu

# %%
# Extracting the series
series = df[['close', 'high', 'low']] # Picking the multivariate series
print(series.shape)
series
# Out:
# (4044, 3)
#               close     high      low
# time
# 2009-01-05   311.23   311.23   311.23
# 2009-01-06   314.21   314.21   314.21
# 2009-01-07   320.53   320.53   320.53
# 2009-01-08   314.14   314.14   314.14
# 2009-01-09   312.90   312.90   312.90
# ...             ...      ...      ...
# 2025-03-14  1387.03  1394.39  1385.20
# 2025-03-17  1394.90  1397.28  1389.42
# 2025-03-18  1388.64  1400.38  1388.64
# 2025-03-19  1377.63  1386.57  1374.83
# 2025-03-20  1378.95  1388.37  1371.98
#
# [4044 rows x 3 columns]

# %%
# Vẽ biểu đồ
plt.figure(figsize=(8, 5))
plt.plot(series.index, series['close'], label='close', color='blue')
plt.plot(series.index, series['high'], label='high', color='green')
plt.plot(series.index, series['low'], label='low', color='red')

# Định dạng biểu đồ
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Stock Price Time Series')
plt.legend()
plt.grid(True)

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# ### Bước 2: Chia dữ liệu thành các tập Train, Validation, Test

# %%
series.shape
# Out:
# (4044, 3)

# %%
n = series.shape[0]
val_size =  test_size = int(n * 0.15)
train_size = n - val_size - test_size # Để tránh sai số làm mất dữ liệu

# Chia tập dữ liệu theo thứ tự thời gian
train_data = series.iloc[:train_size].values
val_data = series.iloc[train_size:train_size + val_size].values
test_data = series.iloc[(train_size + val_size):].values
# Kiểm tra kích thước của từng tập
print(train_data.shape, val_data.shape, test_data.shape)
# Out:
# (2832, 3) (606, 3) (606, 3)

# %% [markdown]
# ### Bước 3: Chuẩn hóa dữ liệu bằng MinMaxScaler

# %%
sc = MinMaxScaler()
train = sc.fit_transform(train_data)
val = sc.transform(val_data)
test = sc.transform(test_data)

print(train.shape, val.shape, test.shape)
# Out:
# (2832, 3) (606, 3) (606, 3)

# %% [markdown]
# ### Bước 4: Tìm siêu tham số tốt nhất bằng Grid Search

# %%
best_params, best_score, results_df = grid_search_rnn(train, val, test, param_grid)

print("Best parameters:", best_params)
print("Best RMSE score:", best_score)
# Out:
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 32, 'num_epochs': 200}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss improved from inf to 1.18807, saving model to 3Var-Vn30-gru.h5
#
# Epoch 2: val_loss improved from 1.18807 to 0.86750, saving model to 3Var-Vn30-gru.h5
#
# Epoch 3: val_loss improved from 0.86750 to 0.47045, saving model to 3Var-Vn30-gru.h5
#
# Epoch 4: val_loss improved from 0.47045 to 0.19656, saving model to 3Var-Vn30-gru.h5
#
# Epoch 5: val_loss improved from 0.19656 to 0.08343, saving model to 3Var-Vn30-gru.h5
#
# Epoch 6: val_loss improved from 0.08343 to 0.05183, saving model to 3Var-Vn30-gru.h5
#
# Epoch 7: val_loss improved from 0.05183 to 0.03951, saving model to 3Var-Vn30-gru.h5
#
# Epoch 8: val_loss improved from 0.03951 to 0.03109, saving model to 3Var-Vn30-gru.h5
#
# Epoch 9: val_loss improved from 0.03109 to 0.02326, saving model to 3Var-Vn30-gru.h5
#
# Epoch 10: val_loss improved from 0.02326 to 0.01488, saving model to 3Var-Vn30-gru.h5
#
# Epoch 11: val_loss improved from 0.01488 to 0.00915, saving model to 3Var-Vn30-gru.h5
#
# Epoch 12: val_loss improved from 0.00915 to 0.00589, saving model to 3Var-Vn30-gru.h5
#
# Epoch 13: val_loss improved from 0.00589 to 0.00398, saving model to 3Var-Vn30-gru.h5
#
# Epoch 14: val_loss improved from 0.00398 to 0.00294, saving model to 3Var-Vn30-gru.h5
#
# Epoch 15: val_loss improved from 0.00294 to 0.00240, saving model to 3Var-Vn30-gru.h5
#
# Epoch 16: val_loss improved from 0.00240 to 0.00212, saving model to 3Var-Vn30-gru.h5
#
# Epoch 17: val_loss improved from 0.00212 to 0.00196, saving model to 3Var-Vn30-gru.h5
#
# Epoch 18: val_loss improved from 0.00196 to 0.00186, saving model to 3Var-Vn30-gru.h5
#
# Epoch 19: val_loss improved from 0.00186 to 0.00178, saving model to 3Var-Vn30-gru.h5
#
# Epoch 20: val_loss improved from 0.00178 to 0.00169, saving model to 3Var-Vn30-gru.h5
#
# Epoch 21: val_loss improved from 0.00169 to 0.00161, saving model to 3Var-Vn30-gru.h5
#
# Epoch 22: val_loss improved from 0.00161 to 0.00154, saving model to 3Var-Vn30-gru.h5
#
# Epoch 23: val_loss improved from 0.00154 to 0.00148, saving model to 3Var-Vn30-gru.h5
#
# Epoch 24: val_loss improved from 0.00148 to 0.00142, saving model to 3Var-Vn30-gru.h5
#
# Epoch 25: val_loss improved from 0.00142 to 0.00137, saving model to 3Var-Vn30-gru.h5
#
# Epoch 26: val_loss improved from 0.00137 to 0.00133, saving model to 3Var-Vn30-gru.h5
#
# Epoch 27: val_loss improved from 0.00133 to 0.00129, saving model to 3Var-Vn30-gru.h5
#
# Epoch 28: val_loss improved from 0.00129 to 0.00126, saving model to 3Var-Vn30-gru.h5
#
# Epoch 29: val_loss improved from 0.00126 to 0.00123, saving model to 3Var-Vn30-gru.h5
#
# Epoch 30: val_loss improved from 0.00123 to 0.00120, saving model to 3Var-Vn30-gru.h5
#
# Epoch 31: val_loss improved from 0.00120 to 0.00118, saving model to 3Var-Vn30-gru.h5
#
# Epoch 32: val_loss improved from 0.00118 to 0.00115, saving model to 3Var-Vn30-gru.h5
#
# Epoch 33: val_loss improved from 0.00115 to 0.00114, saving model to 3Var-Vn30-gru.h5
#
# Epoch 34: val_loss improved from 0.00114 to 0.00113, saving model to 3Var-Vn30-gru.h5
#
# Epoch 35: val_loss improved from 0.00113 to 0.00112, saving model to 3Var-Vn30-gru.h5
#
# Epoch 36: val_loss improved from 0.00112 to 0.00112, saving model to 3Var-Vn30-gru.h5
#
# Epoch 37: val_loss did not improve from 0.00112
#
# Epoch 38: val_loss did not improve from 0.00112
#
# Epoch 39: val_loss did not improve from 0.00112
#
# Epoch 40: val_loss did not improve from 0.00112
#
# Epoch 41: val_loss did not improve from 0.00112
#
# Epoch 42: val_loss did not improve from 0.00112
#
# Epoch 43: val_loss did not improve from 0.00112
#
# Epoch 44: val_loss did not improve from 0.00112
#
# Epoch 45: val_loss did not improve from 0.00112
#
# Epoch 46: val_loss did not improve from 0.00112
#
# Epoch 47: val_loss did not improve from 0.00112
#
# Epoch 48: val_loss did not improve from 0.00112
#
# Epoch 49: val_loss did not improve from 0.00112
#
# Epoch 50: val_loss did not improve from 0.00112
#
# Epoch 51: val_loss did not improve from 0.00112
#
# Epoch 52: val_loss did not improve from 0.00112
#
# Epoch 53: val_loss did not improve from 0.00112
#
# Epoch 54: val_loss did not improve from 0.00112
#
# Epoch 55: val_loss did not improve from 0.00112
#
# Epoch 56: val_loss did not improve from 0.00112
#
# Epoch 57: val_loss did not improve from 0.00112
#
# Epoch 58: val_loss did not improve from 0.00112
#
# Epoch 59: val_loss did not improve from 0.00112
#
# Epoch 60: val_loss did not improve from 0.00112
#
# Epoch 61: val_loss did not improve from 0.00112
#
# Epoch 62: val_loss did not improve from 0.00112
#
# Epoch 63: val_loss did not improve from 0.00112
#
# Epoch 64: val_loss did not improve from 0.00112
#
# Epoch 65: val_loss did not improve from 0.00112
#
# Epoch 66: val_loss did not improve from 0.00112
#
# Epoch 67: val_loss did not improve from 0.00112
#
# Epoch 68: val_loss did not improve from 0.00112
#
# Epoch 69: val_loss did not improve from 0.00112
#
# Epoch 70: val_loss did not improve from 0.00112
#
# Epoch 71: val_loss did not improve from 0.00112
#
# Epoch 72: val_loss did not improve from 0.00112
#
# Epoch 73: val_loss did not improve from 0.00112
#
# Epoch 74: val_loss did not improve from 0.00112
#
# Epoch 75: val_loss did not improve from 0.00112
#
# Epoch 76: val_loss did not improve from 0.00112
#
# Epoch 77: val_loss did not improve from 0.00112
#
# Epoch 78: val_loss did not improve from 0.00112
#
# Epoch 79: val_loss did not improve from 0.00112
#
# Epoch 80: val_loss did not improve from 0.00112
#
# Epoch 81: val_loss did not improve from 0.00112
#
# Epoch 82: val_loss did not improve from 0.00112
#
# Epoch 83: val_loss did not improve from 0.00112
#
# Epoch 84: val_loss did not improve from 0.00112
#
# Epoch 85: val_loss did not improve from 0.00112
#
# Epoch 86: val_loss did not improve from 0.00112
#
# Epoch 87: val_loss did not improve from 0.00112
#
# Epoch 88: val_loss did not improve from 0.00112
#
# Epoch 89: val_loss did not improve from 0.00112
#
# Epoch 90: val_loss did not improve from 0.00112
#
# Epoch 91: val_loss did not improve from 0.00112
#
# Epoch 92: val_loss did not improve from 0.00112
#
# Epoch 93: val_loss did not improve from 0.00112
#
# Epoch 94: val_loss did not improve from 0.00112
#
# Epoch 95: val_loss did not improve from 0.00112
#
# Epoch 96: val_loss did not improve from 0.00112
#
# Epoch 97: val_loss did not improve from 0.00112
#
# Epoch 98: val_loss did not improve from 0.00112
#
# Epoch 99: val_loss did not improve from 0.00112
#
# Epoch 100: val_loss did not improve from 0.00112
#
# Epoch 101: val_loss did not improve from 0.00112
#
# Epoch 102: val_loss did not improve from 0.00112
#
# Epoch 103: val_loss did not improve from 0.00112
#
# Epoch 104: val_loss did not improve from 0.00112
#
# Epoch 105: val_loss did not improve from 0.00112
#
# Epoch 106: val_loss did not improve from 0.00112
#
# Epoch 107: val_loss did not improve from 0.00112
#
# Epoch 108: val_loss did not improve from 0.00112
#
# Epoch 109: val_loss did not improve from 0.00112
#
# Epoch 110: val_loss did not improve from 0.00112
#
# Epoch 111: val_loss did not improve from 0.00112
#
# Epoch 112: val_loss did not improve from 0.00112
# Epoch 112: early stopping
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step
# Best parameters: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 32, 'num_epochs': 200}
# Best RMSE score: 0.027356520960291196

# %% [markdown]
# ### Bước 5: Huấn luyện mô hình với bộ tham số tối ưu

# %%
timesteps = 30
hl = [40, 35]
lr = 1e-4
batch_size = 32
num_epochs = 200

model, train_loss, val_loss = fit_model_3(train, val, timesteps, hl, lr, batch_size, num_epochs)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00112
#
# Epoch 2: val_loss did not improve from 0.00112
#
# Epoch 3: val_loss did not improve from 0.00112
#
# Epoch 4: val_loss did not improve from 0.00112
#
# Epoch 5: val_loss did not improve from 0.00112
#
# Epoch 6: val_loss did not improve from 0.00112
#
# Epoch 7: val_loss did not improve from 0.00112
#
# Epoch 8: val_loss did not improve from 0.00112
#
# Epoch 9: val_loss did not improve from 0.00112
#
# Epoch 10: val_loss did not improve from 0.00112
#
# Epoch 11: val_loss did not improve from 0.00112
#
# Epoch 12: val_loss did not improve from 0.00112
#
# Epoch 13: val_loss did not improve from 0.00112
#
# Epoch 14: val_loss did not improve from 0.00112
#
# Epoch 15: val_loss did not improve from 0.00112
#
# Epoch 16: val_loss did not improve from 0.00112
#
# Epoch 17: val_loss did not improve from 0.00112
#
# Epoch 18: val_loss did not improve from 0.00112
#
# Epoch 19: val_loss did not improve from 0.00112
#
# Epoch 20: val_loss did not improve from 0.00112
#
# Epoch 21: val_loss did not improve from 0.00112
#
# Epoch 22: val_loss did not improve from 0.00112
#
# Epoch 23: val_loss did not improve from 0.00112
#
# Epoch 24: val_loss did not improve from 0.00112
#
# Epoch 25: val_loss did not improve from 0.00112
#
# Epoch 26: val_loss did not improve from 0.00112
#
# Epoch 27: val_loss did not improve from 0.00112
#
# Epoch 28: val_loss did not improve from 0.00112
#
# Epoch 29: val_loss did not improve from 0.00112
#
# Epoch 30: val_loss did not improve from 0.00112
#
# Epoch 31: val_loss improved from 0.00112 to 0.00111, saving model to 3Var-Vn30-gru.h5
#
# Epoch 32: val_loss improved from 0.00111 to 0.00106, saving model to 3Var-Vn30-gru.h5
#
# Epoch 33: val_loss improved from 0.00106 to 0.00100, saving model to 3Var-Vn30-gru.h5
#
# Epoch 34: val_loss improved from 0.00100 to 0.00095, saving model to 3Var-Vn30-gru.h5
#
# Epoch 35: val_loss improved from 0.00095 to 0.00091, saving model to 3Var-Vn30-gru.h5
#
# Epoch 36: val_loss improved from 0.00091 to 0.00087, saving model to 3Var-Vn30-gru.h5
#
# Epoch 37: val_loss improved from 0.00087 to 0.00085, saving model to 3Var-Vn30-gru.h5
#
# Epoch 38: val_loss improved from 0.00085 to 0.00083, saving model to 3Var-Vn30-gru.h5
#
# Epoch 39: val_loss improved from 0.00083 to 0.00082, saving model to 3Var-Vn30-gru.h5
#
# Epoch 40: val_loss did not improve from 0.00082
#
# Epoch 41: val_loss did not improve from 0.00082
#
# Epoch 42: val_loss did not improve from 0.00082
#
# Epoch 43: val_loss did not improve from 0.00082
#
# Epoch 44: val_loss did not improve from 0.00082
#
# Epoch 45: val_loss did not improve from 0.00082
#
# Epoch 46: val_loss did not improve from 0.00082
#
# Epoch 47: val_loss did not improve from 0.00082
#
# Epoch 48: val_loss did not improve from 0.00082
#
# Epoch 49: val_loss did not improve from 0.00082
#
# Epoch 50: val_loss did not improve from 0.00082
#
# Epoch 51: val_loss did not improve from 0.00082
#
# Epoch 52: val_loss did not improve from 0.00082
#
# Epoch 53: val_loss did not improve from 0.00082
#
# Epoch 54: val_loss did not improve from 0.00082
#
# Epoch 55: val_loss did not improve from 0.00082
#
# Epoch 56: val_loss did not improve from 0.00082
#
# Epoch 57: val_loss did not improve from 0.00082
#
# Epoch 58: val_loss did not improve from 0.00082
#
# Epoch 59: val_loss did not improve from 0.00082
#
# Epoch 60: val_loss did not improve from 0.00082
#
# Epoch 61: val_loss did not improve from 0.00082
#
# Epoch 62: val_loss did not improve from 0.00082
#
# Epoch 63: val_loss did not improve from 0.00082
#
# Epoch 64: val_loss did not improve from 0.00082
#
# Epoch 65: val_loss did not improve from 0.00082
#
# Epoch 66: val_loss did not improve from 0.00082
#
# Epoch 67: val_loss did not improve from 0.00082
#
# Epoch 68: val_loss did not improve from 0.00082
#
# Epoch 69: val_loss did not improve from 0.00082
#
# Epoch 70: val_loss did not improve from 0.00082
#
# Epoch 71: val_loss did not improve from 0.00082
#
# Epoch 72: val_loss did not improve from 0.00082
#
# Epoch 73: val_loss did not improve from 0.00082
#
# Epoch 74: val_loss did not improve from 0.00082
#
# Epoch 75: val_loss did not improve from 0.00082
#
# Epoch 76: val_loss did not improve from 0.00082
#
# Epoch 77: val_loss did not improve from 0.00082
#
# Epoch 78: val_loss did not improve from 0.00082
#
# Epoch 79: val_loss did not improve from 0.00082
#
# Epoch 80: val_loss did not improve from 0.00082
#
# Epoch 81: val_loss did not improve from 0.00082
#
# Epoch 82: val_loss did not improve from 0.00082
#
# Epoch 83: val_loss improved from 0.00082 to 0.00082, saving model to 3Var-Vn30-gru.h5
#
# Epoch 84: val_loss improved from 0.00082 to 0.00082, saving model to 3Var-Vn30-gru.h5
#
# Epoch 85: val_loss improved from 0.00082 to 0.00079, saving model to 3Var-Vn30-gru.h5
#
# Epoch 86: val_loss improved from 0.00079 to 0.00079, saving model to 3Var-Vn30-gru.h5
#
# Epoch 87: val_loss did not improve from 0.00079
#
# Epoch 88: val_loss did not improve from 0.00079
#
# Epoch 89: val_loss did not improve from 0.00079
#
# Epoch 90: val_loss did not improve from 0.00079
#
# Epoch 91: val_loss improved from 0.00079 to 0.00078, saving model to 3Var-Vn30-gru.h5
#
# Epoch 92: val_loss improved from 0.00078 to 0.00077, saving model to 3Var-Vn30-gru.h5
#
# Epoch 93: val_loss improved from 0.00077 to 0.00077, saving model to 3Var-Vn30-gru.h5
#
# Epoch 94: val_loss improved from 0.00077 to 0.00076, saving model to 3Var-Vn30-gru.h5
#
# Epoch 95: val_loss improved from 0.00076 to 0.00076, saving model to 3Var-Vn30-gru.h5
#
# Epoch 96: val_loss improved from 0.00076 to 0.00075, saving model to 3Var-Vn30-gru.h5
#
# Epoch 97: val_loss improved from 0.00075 to 0.00075, saving model to 3Var-Vn30-gru.h5
#
# Epoch 98: val_loss improved from 0.00075 to 0.00075, saving model to 3Var-Vn30-gru.h5
#
# Epoch 99: val_loss improved from 0.00075 to 0.00074, saving model to 3Var-Vn30-gru.h5
#
# Epoch 100: val_loss improved from 0.00074 to 0.00074, saving model to 3Var-Vn30-gru.h5
#
# Epoch 101: val_loss improved from 0.00074 to 0.00073, saving model to 3Var-Vn30-gru.h5
#
# Epoch 102: val_loss improved from 0.00073 to 0.00073, saving model to 3Var-Vn30-gru.h5
#
# Epoch 103: val_loss improved from 0.00073 to 0.00072, saving model to 3Var-Vn30-gru.h5
#
# Epoch 104: val_loss improved from 0.00072 to 0.00071, saving model to 3Var-Vn30-gru.h5
#
# Epoch 105: val_loss improved from 0.00071 to 0.00071, saving model to 3Var-Vn30-gru.h5
#
# Epoch 106: val_loss improved from 0.00071 to 0.00070, saving model to 3Var-Vn30-gru.h5
#
# Epoch 107: val_loss improved from 0.00070 to 0.00070, saving model to 3Var-Vn30-gru.h5
#
# Epoch 108: val_loss did not improve from 0.00070
#
# Epoch 109: val_loss improved from 0.00070 to 0.00069, saving model to 3Var-Vn30-gru.h5
#
# Epoch 110: val_loss improved from 0.00069 to 0.00069, saving model to 3Var-Vn30-gru.h5
#
# Epoch 111: val_loss improved from 0.00069 to 0.00068, saving model to 3Var-Vn30-gru.h5
#
# Epoch 112: val_loss did not improve from 0.00068
#
# Epoch 113: val_loss improved from 0.00068 to 0.00068, saving model to 3Var-Vn30-gru.h5
#
# Epoch 114: val_loss improved from 0.00068 to 0.00068, saving model to 3Var-Vn30-gru.h5
#
# Epoch 115: val_loss did not improve from 0.00068
#
# Epoch 116: val_loss improved from 0.00068 to 0.00067, saving model to 3Var-Vn30-gru.h5
#
# Epoch 117: val_loss improved from 0.00067 to 0.00067, saving model to 3Var-Vn30-gru.h5
#
# Epoch 118: val_loss improved from 0.00067 to 0.00067, saving model to 3Var-Vn30-gru.h5
#
# Epoch 119: val_loss improved from 0.00067 to 0.00067, saving model to 3Var-Vn30-gru.h5
#
# Epoch 120: val_loss improved from 0.00067 to 0.00066, saving model to 3Var-Vn30-gru.h5
#
# Epoch 121: val_loss improved from 0.00066 to 0.00066, saving model to 3Var-Vn30-gru.h5
#
# Epoch 122: val_loss improved from 0.00066 to 0.00066, saving model to 3Var-Vn30-gru.h5
#
# Epoch 123: val_loss improved from 0.00066 to 0.00066, saving model to 3Var-Vn30-gru.h5
#
# Epoch 124: val_loss improved from 0.00066 to 0.00065, saving model to 3Var-Vn30-gru.h5
#
# Epoch 125: val_loss did not improve from 0.00065
#
# Epoch 126: val_loss improved from 0.00065 to 0.00065, saving model to 3Var-Vn30-gru.h5
#
# Epoch 127: val_loss did not improve from 0.00065
#
# Epoch 128: val_loss improved from 0.00065 to 0.00064, saving model to 3Var-Vn30-gru.h5
#
# Epoch 129: val_loss did not improve from 0.00064
#
# Epoch 130: val_loss improved from 0.00064 to 0.00064, saving model to 3Var-Vn30-gru.h5
#
# Epoch 131: val_loss did not improve from 0.00064
#
# Epoch 132: val_loss improved from 0.00064 to 0.00063, saving model to 3Var-Vn30-gru.h5
#
# Epoch 133: val_loss did not improve from 0.00063
#
# Epoch 134: val_loss improved from 0.00063 to 0.00063, saving model to 3Var-Vn30-gru.h5
#
# Epoch 135: val_loss improved from 0.00063 to 0.00062, saving model to 3Var-Vn30-gru.h5
#
# Epoch 136: val_loss improved from 0.00062 to 0.00062, saving model to 3Var-Vn30-gru.h5
#
# Epoch 137: val_loss did not improve from 0.00062
#
# Epoch 138: val_loss improved from 0.00062 to 0.00061, saving model to 3Var-Vn30-gru.h5
#
# Epoch 139: val_loss improved from 0.00061 to 0.00061, saving model to 3Var-Vn30-gru.h5
#
# Epoch 140: val_loss improved from 0.00061 to 0.00060, saving model to 3Var-Vn30-gru.h5
#
# Epoch 141: val_loss improved from 0.00060 to 0.00060, saving model to 3Var-Vn30-gru.h5
#
# Epoch 142: val_loss improved from 0.00060 to 0.00059, saving model to 3Var-Vn30-gru.h5
#
# Epoch 143: val_loss improved from 0.00059 to 0.00059, saving model to 3Var-Vn30-gru.h5
#
# Epoch 144: val_loss improved from 0.00059 to 0.00059, saving model to 3Var-Vn30-gru.h5
#
# Epoch 145: val_loss improved from 0.00059 to 0.00058, saving model to 3Var-Vn30-gru.h5
#
# Epoch 146: val_loss did not improve from 0.00058
#
# Epoch 147: val_loss improved from 0.00058 to 0.00057, saving model to 3Var-Vn30-gru.h5
#
# Epoch 148: val_loss improved from 0.00057 to 0.00056, saving model to 3Var-Vn30-gru.h5
#
# Epoch 149: val_loss improved from 0.00056 to 0.00055, saving model to 3Var-Vn30-gru.h5
#
# Epoch 150: val_loss improved from 0.00055 to 0.00055, saving model to 3Var-Vn30-gru.h5
#
# Epoch 151: val_loss improved from 0.00055 to 0.00055, saving model to 3Var-Vn30-gru.h5
#
# Epoch 152: val_loss improved from 0.00055 to 0.00054, saving model to 3Var-Vn30-gru.h5
#
# Epoch 153: val_loss improved from 0.00054 to 0.00054, saving model to 3Var-Vn30-gru.h5
#
# Epoch 154: val_loss improved from 0.00054 to 0.00053, saving model to 3Var-Vn30-gru.h5
#
# Epoch 155: val_loss did not improve from 0.00053
#
# Epoch 156: val_loss improved from 0.00053 to 0.00052, saving model to 3Var-Vn30-gru.h5
#
# Epoch 157: val_loss did not improve from 0.00052
#
# Epoch 158: val_loss improved from 0.00052 to 0.00052, saving model to 3Var-Vn30-gru.h5
#
# Epoch 159: val_loss improved from 0.00052 to 0.00052, saving model to 3Var-Vn30-gru.h5
#
# Epoch 160: val_loss improved from 0.00052 to 0.00051, saving model to 3Var-Vn30-gru.h5
#
# Epoch 161: val_loss did not improve from 0.00051
#
# Epoch 162: val_loss improved from 0.00051 to 0.00051, saving model to 3Var-Vn30-gru.h5
#
# Epoch 163: val_loss improved from 0.00051 to 0.00051, saving model to 3Var-Vn30-gru.h5
#
# Epoch 164: val_loss did not improve from 0.00051
#
# Epoch 165: val_loss did not improve from 0.00051
#
# Epoch 166: val_loss did not improve from 0.00051
#
# Epoch 167: val_loss did not improve from 0.00051
#
# Epoch 168: val_loss did not improve from 0.00051
#
# Epoch 169: val_loss did not improve from 0.00051
#
# Epoch 170: val_loss did not improve from 0.00051
#
# Epoch 171: val_loss did not improve from 0.00051
#
# Epoch 172: val_loss did not improve from 0.00051
#
# Epoch 173: val_loss did not improve from 0.00051
#
# Epoch 174: val_loss did not improve from 0.00051
#
# Epoch 175: val_loss did not improve from 0.00051
#
# Epoch 176: val_loss did not improve from 0.00051
#
# Epoch 177: val_loss did not improve from 0.00051
#
# Epoch 178: val_loss did not improve from 0.00051
#
# Epoch 179: val_loss did not improve from 0.00051
#
# Epoch 180: val_loss did not improve from 0.00051
#
# Epoch 181: val_loss did not improve from 0.00051
#
# Epoch 182: val_loss did not improve from 0.00051
#
# Epoch 183: val_loss did not improve from 0.00051
#
# Epoch 184: val_loss did not improve from 0.00051
#
# Epoch 185: val_loss did not improve from 0.00051
#
# Epoch 186: val_loss did not improve from 0.00051
#
# Epoch 187: val_loss did not improve from 0.00051
#
# Epoch 188: val_loss did not improve from 0.00051
#
# Epoch 189: val_loss did not improve from 0.00051
#
# Epoch 190: val_loss did not improve from 0.00051
#
# Epoch 191: val_loss did not improve from 0.00051
#
# Epoch 192: val_loss did not improve from 0.00051
#
# Epoch 193: val_loss did not improve from 0.00051
#
# Epoch 194: val_loss did not improve from 0.00051
#
# Epoch 195: val_loss did not improve from 0.00051
#
# Epoch 196: val_loss did not improve from 0.00051
#
# Epoch 197: val_loss did not improve from 0.00051
#
# Epoch 198: val_loss did not improve from 0.00051
#
# Epoch 199: val_loss did not improve from 0.00051
#
# Epoch 200: val_loss did not improve from 0.00051

# %% [markdown]
# ### Bước 6: Đánh giá mô hình và trực quan hóa kết quả

# %% [markdown]
# #### 6.1. Vẽ biểu đồ train_loss và val_loss

# %%
plot_error(train_error, val_error)

# %% [markdown]
# #### 6.2. Đánh giá mô hình trên tập test

# %%
mse, rmse, mape, r2, true, predicted = evaluate_model_3(model, test, timesteps)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step

# %%
print('MSE = {}'.format(mse))
print('RMSE = {}'.format(rmse))
print('MAPE = {}'.format(mape))
print('R-Squared Score = {}'.format(r2))
# Out:
# MSE = 0.0002739016141088817
# RMSE = 0.016549973235896236
# MAPE = 0.012732693692764457
# R-Squared Score = 0.9797689542543845

# %% [markdown]
# #### 6.3. Vẽ đồ thị dự đoán vs thực tế

# %%
plot_data_3(true, predicted)

# %%
# Save a model
model.save('3VAR-VN30index-gru.keras')

# %%
del model

# %% [markdown]
# # Model 3: Multivariate-3-LSTM

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Import các thư viện cần thiết

# %%
import os
os.environ['PYTHONHASHSEED'] = '0' # đảm bảo rằng các giá trị băm của đối tượng bất biến (dict, set, chuỗi, tuple...) luôn giống nhau giữa các lần chạy

import random as rn
import numpy as np
np.random.seed(1)
rn.seed(3)
import tensorflow as tf
tf.random.set_seed(2)
# Out:
# 2025-06-02 16:07:42.774729: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748880462.974525      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748880463.036873      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras import optimizers

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from math import sqrt
import datetime as dt
import time

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### Hàm callback

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')  
checkpoint = ModelCheckpoint(
    filepath="3Var_vn30_lstm.h5",   # Tên file lưu mô hình
    monitor="val_loss",         # Theo dõi val_loss
    save_best_only=True,        # Chỉ lưu khi tốt hơn mô hình trước đó
    mode="min",                 # Giảm min của val_loss là tốt nhất
    verbose=1
)
callbacks_list = [earlystop, checkpoint]

# %% [markdown]
# ### Đọc dữ liệu từ file csv

# %%
url = r"VN30 Index.csv"
df = pd.read_csv(url, parse_dates= True, index_col= 0)

# %%
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#               open    high     low   close  volume
# time
# 2009-01-05  311.23  311.23  311.23  311.23     NaN
# 2009-01-06  314.21  314.21  314.21  314.21     NaN
# 2009-01-07  320.53  320.53  320.53  320.53     NaN
# 2009-01-08  314.14  314.14  314.14  314.14     NaN
# 2009-01-09  312.90  312.90  312.90  312.90     NaN

# %%
df.isnull().sum()
# Out:
# open        0
# high        0
# low         0
# close       0
# volume    859
# dtype: int64

# %% [markdown]
# ### Tiền xử lí dữ liệu

# %%
# Xóa các dòng có giá trị Volume bằng 0
df.drop(df[df['volume']==0].index, inplace=True)

# %%
# Ma trận tương quan (ở đây là Pearson tương quan tuyến tính)
df.corr()['close']
# Out:
# open      0.999562
# high      0.999783
# low       0.999789
# close     1.000000
# volume    0.169492
# Name: close, dtype: float64

# %%
print(df.describe().volume) 
df['volume'].hist(bins= 10)
# Out:
# count    3.185000e+03
# mean     3.279171e+06
# std      2.776577e+07
# min      4.540000e+03
# 25%      3.809000e+04
# 50%      6.036000e+04
# 75%      1.560100e+05
# max      3.744900e+08
# Name: volume, dtype: float64
# <Axes: >

# %% [markdown]
# ## Train model / Hàm **fit_model_4()**

# %%
def fit_model_4(train, val, timesteps, hl, lr, batch, epochs):
    X_train = []
    Y_train = []
    X_val = []
    Y_val = []

    for i in range(timesteps, train.shape[0]):
        X_train.append(train[i-timesteps:i])
        Y_train.append(train[i][0])
    X_train, Y_train = np.array(X_train), np.array(Y_train)

    for i in range(timesteps, val.shape[0]):
        X_val.append(val[i-timesteps:i])
        Y_val.append(val[i][0])
    X_val, Y_val = np.array(X_val), np.array(Y_val)

    # Xây dựng mô hình
    model = Sequential()
    model.add(LSTM(X_train.shape[2], input_shape= (X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences= True))
    for i in range(len(hl)-1):
        model.add(LSTM(hl[i], activation='relu', return_sequences= True))
    model.add(LSTM(hl[-1], activation='relu'))
    model.add(Dense(1))

    # Biên dịch
    model.compile(optimizer= optimizers.Adam(learning_rate= lr), loss= 'mean_squared_error')

    # Huấn luyện mô hình
    history = model.fit(X_train, Y_train, batch_size= batch, epochs= epochs, validation_data= (X_val, Y_val), verbose= 0, shuffle= False, callbacks= callbacks_list)

    # Đặt lại trạng thái
    for layer in model.layers:
        if isinstance(layer, LSTM):
            layer.reset_state()

    return model, history.history['loss'], history.history['val_loss']

# %% [markdown]
# ## Hàm **Evaluate_model_4()**

# %%
def evaluate_model_4(model, test, timesteps):
    X_test = []
    Y_test = []

    for i in range(timesteps, test.shape[0]):
        X_test.append(test[i-timesteps:i])
        Y_test.append(test[i][0])
    X_test, Y_test = np.array(X_test), np.array(Y_test)

    # Các chỉ số
    Y_hat = model.predict(X_test)
    mse = mean_squared_error(Y_test, Y_hat)
    rmse = sqrt(mse)
    mape = mean_absolute_percentage_error(Y_test, Y_hat)
    r2 = r2_score(Y_test, Y_hat)

    return mse, rmse, mape, r2, Y_test, Y_hat

# %% [markdown]
# ## **Grid Search**: Tìm kiếm siêu tham số tối ưu

# %%
param_grid = {
    'timesteps': [30, 40, 50],  # Số giá trị trước đó để dự đoán
    'hl': [ [40, 35]], # Cấu trúc lớp ẩn
    'lr': [1e-3, 1e-4],  # Tốc độ học
    'batch_size': [32, 64],  # Kích thước batch
    'num_epochs': [200, 250],  # Số epoch
}

# %%
from itertools import product
import pandas as pd

# Hàm Grid Search
def grid_search_rnn(train, val, test, param_grid):
    results = []  # Lưu kết quả của từng tổ hợp tham số
    best_score = float('inf')  # Lưu RMSE tốt nhất
    best_params = None  # Lưu bộ tham số tốt nhất

    # Tạo tất cả các tổ hợp tham số
    all_combinations = list(product(*param_grid.values()))
    param_names = list(param_grid.keys())

    for combination in all_combinations:
        # Gán giá trị tham số hiện tại
        params = dict(zip(param_names, combination))
        timesteps = params['timesteps']
        hl = params['hl']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']

        print(f"Training with params: {params}")

        # Huấn luyện mô hình
        model, train_loss, val_loss = fit_model_4(
            train, val, timesteps, hl, lr, batch_size, num_epochs
        )

        # Đánh giá mô hình
        mse, rmse, mape, r2, _, _ = evaluate_model_4(model, test, timesteps)

        # Lưu kết quả
        results.append({
            'timesteps': timesteps,
            'hl': hl,
            'lr': lr,
            'batch_size': batch_size,
            'num_epochs': num_epochs,
            'MSE': mse,
            'RMSE': rmse,
            'MAPE': mape,
            'R²': r2
        })

        # Cập nhật tham số tốt nhất nếu RMSE cải thiện
        if rmse < best_score:
            best_score = rmse
            best_params = params

    # Trả về kết quả
    results_df = pd.DataFrame(results)
    return best_params, best_score, results_df

# %% [markdown]
# ## Plot chart (vẽ biểu đồ)

# %%
# Plotting the predictions
def plot_data_4(Y_test, Y_hat):
    plt.plot(Y_test, c = 'r')
    plt.plot(Y_hat, c = 'y')
    plt.xlabel('Day')
    plt.ylabel('Price')
    plt.title('Stock Prediction Graph using Multivariate-LSTM model')
    plt.legend(['Actual', 'Predicted'], loc = 'lower right')
    plt.show()

# %%
# Plotting the training errors: trực quan loss qua các epoch -> thấy qtr học mô hình, xem có overfitting ko
def plot_error(train_loss, val_loss):
    plt.plot(train_loss, c = 'r')
    plt.plot(val_loss, c = 'b')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.title('Train Loss and Validation Loss Curve')
    plt.legend(['train', 'val'], loc = 'upper right')
    plt.show()

# %% [markdown]
# ## **Model building**: Xây dựng mô hình

# %% [markdown]
# ### Bước 1: Trích xuất và trực quan hóa dữ liệu

# %%
# Extracting the series
series = df[['close', 'high', 'low']] # Picking the multivariate series
print(series.shape)
series
# Out:
# (4044, 3)
#               close     high      low
# time
# 2009-01-05   311.23   311.23   311.23
# 2009-01-06   314.21   314.21   314.21
# 2009-01-07   320.53   320.53   320.53
# 2009-01-08   314.14   314.14   314.14
# 2009-01-09   312.90   312.90   312.90
# ...             ...      ...      ...
# 2025-03-14  1387.03  1394.39  1385.20
# 2025-03-17  1394.90  1397.28  1389.42
# 2025-03-18  1388.64  1400.38  1388.64
# 2025-03-19  1377.63  1386.57  1374.83
# 2025-03-20  1378.95  1388.37  1371.98
#
# [4044 rows x 3 columns]

# %%
# Vẽ biểu đồ
plt.figure(figsize=(8, 5))
plt.plot(series.index, series['close'], label='close', color='blue')
plt.plot(series.index, series['high'], label='high', color='green')
plt.plot(series.index, series['low'], label='low', color='red')

# Định dạng biểu đồ
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Stock Price Time Series')
plt.legend()
plt.grid(True)

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# ### Bước 2: Chia dữ liệu thành các tập Train, Validation, Test

# %%
series.shape
# Out:
# (4044, 3)

# %%
n = series.shape[0]
val_size =  test_size = int(n * 0.15)
train_size = n - val_size - test_size # Để tránh sai số làm mất dữ liệu

# Chia tập dữ liệu theo thứ tự thời gian
train_data = series.iloc[:train_size].values
val_data = series.iloc[train_size:train_size + val_size].values
test_data = series.iloc[(train_size + val_size):].values
# Kiểm tra kích thước của từng tập
print(train_data.shape, val_data.shape, test_data.shape)
# Out:
# (2832, 3) (606, 3) (606, 3)

# %% [markdown]
# ### Bước 3: Chuẩn hóa dữ liệu bằng MinMaxScaler

# %%
sc = MinMaxScaler()
train = sc.fit_transform(train_data)
val = sc.transform(val_data)
test = sc.transform(test_data)

print(train.shape, val.shape, test.shape)
# Out:
# (2832, 3) (606, 3) (606, 3)

# %% [markdown]
# ### Bước 4: Tìm siêu tham số tốt nhất bằng Grid Search

# %%
best_params, best_score, results_df = grid_search_rnn(train, val, test, param_grid)

print("Best parameters:", best_params)
print("Best RMSE score:", best_score)
# Out:
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.001, 'batch_size': 32, 'num_epochs': 200}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss improved from inf to 0.00880, saving model to 3Var_vn30_lstm.h5
#
# Epoch 2: val_loss improved from 0.00880 to 0.00833, saving model to 3Var_vn30_lstm.h5
#
# Epoch 3: val_loss did not improve from 0.00833
#
# Epoch 4: val_loss did not improve from 0.00833
#
# Epoch 5: val_loss did not improve from 0.00833
#
# Epoch 6: val_loss did not improve from 0.00833
#
# Epoch 7: val_loss did not improve from 0.00833
#
# Epoch 8: val_loss did not improve from 0.00833
#
# Epoch 9: val_loss did not improve from 0.00833
#
# Epoch 10: val_loss did not improve from 0.00833
#
# Epoch 11: val_loss did not improve from 0.00833
#
# Epoch 12: val_loss did not improve from 0.00833
#
# Epoch 13: val_loss did not improve from 0.00833
#
# Epoch 14: val_loss did not improve from 0.00833
#
# Epoch 15: val_loss did not improve from 0.00833
#
# Epoch 16: val_loss did not improve from 0.00833
#
# Epoch 17: val_loss did not improve from 0.00833
#
# Epoch 18: val_loss did not improve from 0.00833
#
# Epoch 19: val_loss did not improve from 0.00833
#
# Epoch 20: val_loss did not improve from 0.00833
#
# Epoch 21: val_loss did not improve from 0.00833
#
# Epoch 22: val_loss did not improve from 0.00833
#
# Epoch 23: val_loss did not improve from 0.00833
#
# Epoch 24: val_loss did not improve from 0.00833
#
# Epoch 25: val_loss did not improve from 0.00833
#
# Epoch 26: val_loss did not improve from 0.00833
#
# Epoch 27: val_loss did not improve from 0.00833
#
# Epoch 28: val_loss did not improve from 0.00833
#
# Epoch 29: val_loss did not improve from 0.00833
#
# Epoch 30: val_loss did not improve from 0.00833
#
# Epoch 31: val_loss did not improve from 0.00833
#
# Epoch 32: val_loss did not improve from 0.00833
#
# Epoch 33: val_loss did not improve from 0.00833
#
# Epoch 34: val_loss did not improve from 0.00833
#
# Epoch 35: val_loss did not improve from 0.00833
#
# Epoch 36: val_loss did not improve from 0.00833
#
# Epoch 37: val_loss did not improve from 0.00833
#
# Epoch 38: val_loss did not improve from 0.00833
#
# Epoch 39: val_loss did not improve from 0.00833
#
# Epoch 40: val_loss did not improve from 0.00833
#
# Epoch 41: val_loss did not improve from 0.00833
#
# Epoch 42: val_loss did not improve from 0.00833
#
# Epoch 43: val_loss did not improve from 0.00833
#
# Epoch 44: val_loss did not improve from 0.00833
#
# Epoch 45: val_loss did not improve from 0.00833
#
# Epoch 46: val_loss did not improve from 0.00833
#
# Epoch 47: val_loss did not improve from 0.00833
#
# Epoch 48: val_loss did not improve from 0.00833
#
# Epoch 49: val_loss did not improve from 0.00833
#
# Epoch 50: val_loss did not improve from 0.00833
#
# Epoch 51: val_loss did not improve from 0.00833
#
# Epoch 52: val_loss did not improve from 0.00833
#
# Epoch 53: val_loss improved from 0.00833 to 0.00827, saving model to 3Var_vn30_lstm.h5
#
# Epoch 54: val_loss improved from 0.00827 to 0.00781, saving model to 3Var_vn30_lstm.h5
#
# Epoch 55: val_loss improved from 0.00781 to 0.00738, saving model to 3Var_vn30_lstm.h5
#
# Epoch 56: val_loss improved from 0.00738 to 0.00687, saving model to 3Var_vn30_lstm.h5
#
# Epoch 57: val_loss improved from 0.00687 to 0.00635, saving model to 3Var_vn30_lstm.h5
#
# Epoch 58: val_loss improved from 0.00635 to 0.00537, saving model to 3Var_vn30_lstm.h5
#
# Epoch 59: val_loss improved from 0.00537 to 0.00480, saving model to 3Var_vn30_lstm.h5
#
# Epoch 60: val_loss improved from 0.00480 to 0.00422, saving model to 3Var_vn30_lstm.h5
#
# Epoch 61: val_loss improved from 0.00422 to 0.00365, saving model to 3Var_vn30_lstm.h5
#
# Epoch 62: val_loss improved from 0.00365 to 0.00312, saving model to 3Var_vn30_lstm.h5
#
# Epoch 63: val_loss improved from 0.00312 to 0.00261, saving model to 3Var_vn30_lstm.h5
#
# Epoch 64: val_loss improved from 0.00261 to 0.00218, saving model to 3Var_vn30_lstm.h5
#
# Epoch 65: val_loss improved from 0.00218 to 0.00181, saving model to 3Var_vn30_lstm.h5
#
# Epoch 66: val_loss improved from 0.00181 to 0.00159, saving model to 3Var_vn30_lstm.h5
#
# Epoch 67: val_loss improved from 0.00159 to 0.00142, saving model to 3Var_vn30_lstm.h5
#
# Epoch 68: val_loss improved from 0.00142 to 0.00134, saving model to 3Var_vn30_lstm.h5
#
# Epoch 69: val_loss improved from 0.00134 to 0.00126, saving model to 3Var_vn30_lstm.h5
#
# Epoch 70: val_loss did not improve from 0.00126
#
# Epoch 71: val_loss did not improve from 0.00126
#
# Epoch 72: val_loss did not improve from 0.00126
#
# Epoch 73: val_loss did not improve from 0.00126
#
# Epoch 74: val_loss did not improve from 0.00126
#
# Epoch 75: val_loss did not improve from 0.00126
#
# Epoch 76: val_loss did not improve from 0.00126
#
# Epoch 77: val_loss did not improve from 0.00126
#
# Epoch 78: val_loss did not improve from 0.00126
#
# Epoch 79: val_loss did not improve from 0.00126
#
# Epoch 80: val_loss did not improve from 0.00126
#
# Epoch 81: val_loss did not improve from 0.00126
#
# Epoch 82: val_loss did not improve from 0.00126
#
# Epoch 83: val_loss did not improve from 0.00126
#
# Epoch 84: val_loss did not improve from 0.00126
#
# Epoch 85: val_loss did not improve from 0.00126
#
# Epoch 86: val_loss did not improve from 0.00126
#
# Epoch 87: val_loss did not improve from 0.00126
#
# Epoch 88: val_loss did not improve from 0.00126
#
# Epoch 89: val_loss did not improve from 0.00126
#
# Epoch 90: val_loss did not improve from 0.00126
#
# Epoch 91: val_loss did not improve from 0.00126
#
# Epoch 92: val_loss did not improve from 0.00126
#
# Epoch 93: val_loss did not improve from 0.00126
#
# Epoch 94: val_loss did not improve from 0.00126
#
# Epoch 95: val_loss did not improve from 0.00126
#
# Epoch 96: val_loss did not improve from 0.00126
#
# Epoch 97: val_loss did not improve from 0.00126
#
# Epoch 98: val_loss did not improve from 0.00126
#
# Epoch 99: val_loss did not improve from 0.00126
#
# Epoch 100: val_loss did not improve from 0.00126
#
# Epoch 101: val_loss did not improve from 0.00126
#
# Epoch 102: val_loss did not improve from 0.00126
#
# Epoch 103: val_loss did not improve from 0.00126
#
# Epoch 104: val_loss did not improve from 0.00126
#
# Epoch 105: val_loss did not improve from 0.00126
#
# Epoch 106: val_loss did not improve from 0.00126
#
# Epoch 107: val_loss did not improve from 0.00126
#
# Epoch 108: val_loss did not improve from 0.00126
#
# Epoch 109: val_loss did not improve from 0.00126
#
# Epoch 110: val_loss did not improve from 0.00126
#
# Epoch 111: val_loss did not improve from 0.00126
#
# Epoch 112: val_loss did not improve from 0.00126
#
# Epoch 113: val_loss did not improve from 0.00126
#
# Epoch 114: val_loss did not improve from 0.00126
#
# Epoch 115: val_loss did not improve from 0.00126
#
# Epoch 116: val_loss did not improve from 0.00126
#
# Epoch 117: val_loss did not improve from 0.00126
#
# Epoch 118: val_loss did not improve from 0.00126
#
# Epoch 119: val_loss did not improve from 0.00126
#
# Epoch 120: val_loss did not improve from 0.00126
#
# Epoch 121: val_loss did not improve from 0.00126
#
# Epoch 122: val_loss did not improve from 0.00126
#
# Epoch 123: val_loss did not improve from 0.00126
#
# Epoch 124: val_loss did not improve from 0.00126
#
# Epoch 125: val_loss did not improve from 0.00126
#
# Epoch 126: val_loss did not improve from 0.00126
#
# Epoch 127: val_loss did not improve from 0.00126
#
# Epoch 128: val_loss did not improve from 0.00126
#
# Epoch 129: val_loss did not improve from 0.00126
#
# Epoch 130: val_loss did not improve from 0.00126
#
# Epoch 131: val_loss did not improve from 0.00126
#
# Epoch 132: val_loss did not improve from 0.00126
#
# Epoch 133: val_loss did not improve from 0.00126
#
# Epoch 134: val_loss did not improve from 0.00126
#
# Epoch 135: val_loss did not improve from 0.00126
#
# Epoch 136: val_loss did not improve from 0.00126
#
# Epoch 137: val_loss did not improve from 0.00126
#
# Epoch 138: val_loss did not improve from 0.00126
#
# Epoch 139: val_loss did not improve from 0.00126
#
# Epoch 140: val_loss did not improve from 0.00126
#
# Epoch 141: val_loss did not improve from 0.00126
#
# Epoch 142: val_loss did not improve from 0.00126
#
# Epoch 143: val_loss did not improve from 0.00126
#
# Epoch 144: val_loss did not improve from 0.00126
#
# Epoch 145: val_loss did not improve from 0.00126
#
# Epoch 146: val_loss did not improve from 0.00126
#
# Epoch 147: val_loss did not improve from 0.00126
#
# Epoch 148: val_loss did not improve from 0.00126
#
# Epoch 149: val_loss did not improve from 0.00126
# Epoch 149: early stopping
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.001, 'batch_size': 32, 'num_epochs': 250}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00126
#
# Epoch 2: val_loss did not improve from 0.00126
#
# Epoch 3: val_loss did not improve from 0.00126
#
# Epoch 4: val_loss did not improve from 0.00126
#
# Epoch 5: val_loss did not improve from 0.00126
#
# Epoch 6: val_loss did not improve from 0.00126
#
# Epoch 7: val_loss did not improve from 0.00126
#
# Epoch 8: val_loss did not improve from 0.00126
#
# Epoch 9: val_loss did not improve from 0.00126
#
# Epoch 10: val_loss did not improve from 0.00126
#
# Epoch 11: val_loss did not improve from 0.00126
#
# Epoch 12: val_loss did not improve from 0.00126
#
# Epoch 13: val_loss did not improve from 0.00126
#
# Epoch 14: val_loss did not improve from 0.00126
#
# Epoch 15: val_loss did not improve from 0.00126
#
# Epoch 16: val_loss did not improve from 0.00126
#
# Epoch 17: val_loss did not improve from 0.00126
#
# Epoch 18: val_loss did not improve from 0.00126
#
# Epoch 19: val_loss did not improve from 0.00126
#
# Epoch 20: val_loss did not improve from 0.00126
#
# Epoch 21: val_loss did not improve from 0.00126
#
# Epoch 22: val_loss did not improve from 0.00126
#
# Epoch 23: val_loss did not improve from 0.00126
#
# Epoch 24: val_loss did not improve from 0.00126
#
# Epoch 25: val_loss did not improve from 0.00126
#
# Epoch 26: val_loss did not improve from 0.00126
#
# Epoch 27: val_loss did not improve from 0.00126
#
# Epoch 28: val_loss did not improve from 0.00126
#
# Epoch 29: val_loss did not improve from 0.00126
#
# Epoch 30: val_loss did not improve from 0.00126
#
# Epoch 31: val_loss did not improve from 0.00126
#
# Epoch 32: val_loss did not improve from 0.00126
#
# Epoch 33: val_loss did not improve from 0.00126
#
# Epoch 34: val_loss did not improve from 0.00126
#
# Epoch 35: val_loss did not improve from 0.00126
#
# Epoch 36: val_loss did not improve from 0.00126
#
# Epoch 37: val_loss did not improve from 0.00126
#
# Epoch 38: val_loss did not improve from 0.00126
#
# Epoch 39: val_loss did not improve from 0.00126
#
# Epoch 40: val_loss did not improve from 0.00126
#
# Epoch 41: val_loss did not improve from 0.00126
#
# Epoch 42: val_loss did not improve from 0.00126
#
# Epoch 43: val_loss did not improve from 0.00126
#
# Epoch 44: val_loss did not improve from 0.00126
#
# Epoch 45: val_loss did not improve from 0.00126
#
# Epoch 46: val_loss did not improve from 0.00126
#
# Epoch 47: val_loss did not improve from 0.00126
#
# Epoch 48: val_loss did not improve from 0.00126
#
# Epoch 49: val_loss did not improve from 0.00126
#
# Epoch 50: val_loss did not improve from 0.00126
#
# Epoch 51: val_loss did not improve from 0.00126
#
# Epoch 52: val_loss did not improve from 0.00126
#
# Epoch 53: val_loss did not improve from 0.00126
#
# Epoch 54: val_loss did not improve from 0.00126
#
# Epoch 55: val_loss did not improve from 0.00126
#
# Epoch 56: val_loss did not improve from 0.00126
#
# Epoch 57: val_loss did not improve from 0.00126
#
# Epoch 58: val_loss did not improve from 0.00126
#
# Epoch 59: val_loss did not improve from 0.00126
#
# Epoch 60: val_loss did not improve from 0.00126
#
# Epoch 61: val_loss did not improve from 0.00126
#
# Epoch 62: val_loss did not improve from 0.00126
#
# Epoch 63: val_loss did not improve from 0.00126
#
# Epoch 64: val_loss did not improve from 0.00126
#
# Epoch 65: val_loss did not improve from 0.00126
#
# Epoch 66: val_loss did not improve from 0.00126
#
# Epoch 67: val_loss did not improve from 0.00126
#
# Epoch 68: val_loss did not improve from 0.00126
#
# Epoch 69: val_loss did not improve from 0.00126
#
# Epoch 70: val_loss did not improve from 0.00126
#
# Epoch 71: val_loss did not improve from 0.00126
#
# Epoch 72: val_loss did not improve from 0.00126
#
# Epoch 73: val_loss did not improve from 0.00126
#
# Epoch 74: val_loss did not improve from 0.00126
#
# Epoch 75: val_loss did not improve from 0.00126
#
# Epoch 76: val_loss did not improve from 0.00126
#
# Epoch 77: val_loss did not improve from 0.00126
#
# Epoch 78: val_loss did not improve from 0.00126
#
# Epoch 79: val_loss did not improve from 0.00126
#
# Epoch 80: val_loss did not improve from 0.00126
#
# Epoch 81: val_loss did not improve from 0.00126
#
# Epoch 82: val_loss did not improve from 0.00126
#
# Epoch 83: val_loss did not improve from 0.00126
#
# Epoch 84: val_loss did not improve from 0.00126
#
# Epoch 85: val_loss did not improve from 0.00126
#
# Epoch 86: val_loss did not improve from 0.00126
#
# Epoch 87: val_loss did not improve from 0.00126
#
# Epoch 88: val_loss did not improve from 0.00126
#
# Epoch 89: val_loss did not improve from 0.00126
#
# Epoch 90: val_loss did not improve from 0.00126
#
# Epoch 91: val_loss did not improve from 0.00126
#
# Epoch 92: val_loss did not improve from 0.00126
#
# Epoch 93: val_loss did not improve from 0.00126
#
# Epoch 94: val_loss did not improve from 0.00126
#
# Epoch 95: val_loss did not improve from 0.00126
#
# Epoch 96: val_loss did not improve from 0.00126
#
# Epoch 97: val_loss did not improve from 0.00126
#
# Epoch 98: val_loss did not improve from 0.00126
#
# Epoch 99: val_loss did not improve from 0.00126
#
# Epoch 100: val_loss did not improve from 0.00126
#
# Epoch 101: val_loss did not improve from 0.00126
#
# Epoch 102: val_loss did not improve from 0.00126
#
# Epoch 103: val_loss did not improve from 0.00126
#
# Epoch 104: val_loss did not improve from 0.00126
#
# Epoch 105: val_loss did not improve from 0.00126
#
# Epoch 106: val_loss did not improve from 0.00126
#
# Epoch 107: val_loss did not improve from 0.00126
#
# Epoch 108: val_loss did not improve from 0.00126
#
# Epoch 109: val_loss did not improve from 0.00126
#
# Epoch 110: val_loss did not improve from 0.00126
#
# Epoch 111: val_loss did not improve from 0.00126
#
# Epoch 112: val_loss did not improve from 0.00126
#
# Epoch 113: val_loss did not improve from 0.00126
#
# Epoch 114: val_loss did not improve from 0.00126
#
# Epoch 115: val_loss did not improve from 0.00126
#
# Epoch 116: val_loss did not improve from 0.00126
#
# Epoch 117: val_loss did not improve from 0.00126
#
# Epoch 118: val_loss did not improve from 0.00126
#
# Epoch 119: val_loss did not improve from 0.00126
#
# Epoch 120: val_loss did not improve from 0.00126
#
# Epoch 121: val_loss did not improve from 0.00126
#
# Epoch 122: val_loss did not improve from 0.00126
#
# Epoch 123: val_loss did not improve from 0.00126
#
# Epoch 124: val_loss did not improve from 0.00126
#
# Epoch 125: val_loss did not improve from 0.00126
#
# Epoch 126: val_loss did not improve from 0.00126
#
# Epoch 127: val_loss did not improve from 0.00126
#
# Epoch 128: val_loss did not improve from 0.00126
#
# Epoch 129: val_loss did not improve from 0.00126
#
# Epoch 130: val_loss did not improve from 0.00126
#
# Epoch 131: val_loss did not improve from 0.00126
#
# Epoch 132: val_loss did not improve from 0.00126
#
# Epoch 133: val_loss did not improve from 0.00126
#
# Epoch 134: val_loss did not improve from 0.00126
#
# Epoch 135: val_loss did not improve from 0.00126
#
# Epoch 136: val_loss did not improve from 0.00126
#
# Epoch 137: val_loss did not improve from 0.00126
#
# Epoch 138: val_loss did not improve from 0.00126
#
# Epoch 139: val_loss did not improve from 0.00126
#
# Epoch 140: val_loss did not improve from 0.00126
#
# Epoch 141: val_loss did not improve from 0.00126
#
# Epoch 142: val_loss did not improve from 0.00126
#
# Epoch 143: val_loss did not improve from 0.00126
#
# Epoch 144: val_loss did not improve from 0.00126
#
# Epoch 145: val_loss did not improve from 0.00126
#
# Epoch 146: val_loss did not improve from 0.00126
#
# Epoch 147: val_loss did not improve from 0.00126
#
# Epoch 148: val_loss did not improve from 0.00126
#
# Epoch 149: val_loss did not improve from 0.00126
#
# Epoch 150: val_loss did not improve from 0.00126
#
# Epoch 151: val_loss did not improve from 0.00126
#
# Epoch 152: val_loss did not improve from 0.00126
#
# Epoch 153: val_loss did not improve from 0.00126
#
# Epoch 154: val_loss did not improve from 0.00126
#
# Epoch 155: val_loss did not improve from 0.00126
#
# Epoch 156: val_loss did not improve from 0.00126
#
# Epoch 157: val_loss did not improve from 0.00126
#
# Epoch 158: val_loss did not improve from 0.00126
#
# Epoch 159: val_loss did not improve from 0.00126
#
# Epoch 160: val_loss did not improve from 0.00126
#
# Epoch 161: val_loss did not improve from 0.00126
#
# Epoch 162: val_loss did not improve from 0.00126
#
# Epoch 163: val_loss did not improve from 0.00126
#
# Epoch 164: val_loss did not improve from 0.00126
#
# Epoch 165: val_loss did not improve from 0.00126
#
# Epoch 166: val_loss did not improve from 0.00126
#
# Epoch 167: val_loss did not improve from 0.00126
#
# Epoch 168: val_loss did not improve from 0.00126
#
# Epoch 169: val_loss did not improve from 0.00126
#
# Epoch 170: val_loss did not improve from 0.00126
#
# Epoch 171: val_loss did not improve from 0.00126
#
# Epoch 172: val_loss improved from 0.00126 to 0.00092, saving model to 3Var_vn30_lstm.h5
#
# Epoch 173: val_loss did not improve from 0.00092
#
# Epoch 174: val_loss did not improve from 0.00092
#
# Epoch 175: val_loss did not improve from 0.00092
#
# Epoch 176: val_loss did not improve from 0.00092
#
# Epoch 177: val_loss did not improve from 0.00092
#
# Epoch 178: val_loss did not improve from 0.00092
#
# Epoch 179: val_loss improved from 0.00092 to 0.00091, saving model to 3Var_vn30_lstm.h5
#
# Epoch 180: val_loss did not improve from 0.00091
#
# Epoch 181: val_loss did not improve from 0.00091
#
# Epoch 182: val_loss did not improve from 0.00091
#
# Epoch 183: val_loss did not improve from 0.00091
#
# Epoch 184: val_loss did not improve from 0.00091
#
# Epoch 185: val_loss did not improve from 0.00091
#
# Epoch 186: val_loss did not improve from 0.00091
#
# Epoch 187: val_loss did not improve from 0.00091
#
# Epoch 188: val_loss did not improve from 0.00091
#
# Epoch 189: val_loss did not improve from 0.00091
#
# Epoch 190: val_loss did not improve from 0.00091
#
# Epoch 191: val_loss did not improve from 0.00091
#
# Epoch 192: val_loss did not improve from 0.00091
#
# Epoch 193: val_loss did not improve from 0.00091
#
# Epoch 194: val_loss did not improve from 0.00091
#
# Epoch 195: val_loss did not improve from 0.00091
#
# Epoch 196: val_loss did not improve from 0.00091
#
# Epoch 197: val_loss did not improve from 0.00091
#
# Epoch 198: val_loss did not improve from 0.00091
#
# Epoch 199: val_loss did not improve from 0.00091
#
# Epoch 200: val_loss did not improve from 0.00091
#
# Epoch 201: val_loss improved from 0.00091 to 0.00084, saving model to 3Var_vn30_lstm.h5
#
# Epoch 202: val_loss did not improve from 0.00084
#
# Epoch 203: val_loss did not improve from 0.00084
#
# Epoch 204: val_loss did not improve from 0.00084
#
# Epoch 205: val_loss did not improve from 0.00084
#
# Epoch 206: val_loss did not improve from 0.00084
#
# Epoch 207: val_loss did not improve from 0.00084
#
# Epoch 208: val_loss did not improve from 0.00084
#
# Epoch 209: val_loss did not improve from 0.00084
#
# Epoch 210: val_loss did not improve from 0.00084
#
# Epoch 211: val_loss did not improve from 0.00084
#
# Epoch 212: val_loss did not improve from 0.00084
#
# Epoch 213: val_loss did not improve from 0.00084
#
# Epoch 214: val_loss did not improve from 0.00084
#
# Epoch 215: val_loss improved from 0.00084 to 0.00083, saving model to 3Var_vn30_lstm.h5
#
# Epoch 216: val_loss did not improve from 0.00083
#
# Epoch 217: val_loss did not improve from 0.00083
#
# Epoch 218: val_loss did not improve from 0.00083
#
# Epoch 219: val_loss did not improve from 0.00083
#
# Epoch 220: val_loss did not improve from 0.00083
#
# Epoch 221: val_loss did not improve from 0.00083
#
# Epoch 222: val_loss did not improve from 0.00083
#
# Epoch 223: val_loss did not improve from 0.00083
#
# Epoch 224: val_loss did not improve from 0.00083
#
# Epoch 225: val_loss did not improve from 0.00083
#
# Epoch 226: val_loss did not improve from 0.00083
#
# Epoch 227: val_loss did not improve from 0.00083
#
# Epoch 228: val_loss did not improve from 0.00083
#
# Epoch 229: val_loss did not improve from 0.00083
#
# Epoch 230: val_loss did not improve from 0.00083
#
# Epoch 231: val_loss did not improve from 0.00083
#
# Epoch 232: val_loss did not improve from 0.00083
#
# Epoch 233: val_loss did not improve from 0.00083
#
# Epoch 234: val_loss did not improve from 0.00083
#
# Epoch 235: val_loss did not improve from 0.00083
#
# Epoch 236: val_loss did not improve from 0.00083
#
# Epoch 237: val_loss did not improve from 0.00083
#
# Epoch 238: val_loss did not improve from 0.00083
#
# Epoch 239: val_loss did not improve from 0.00083
#
# Epoch 240: val_loss did not improve from 0.00083
#
# Epoch 241: val_loss did not improve from 0.00083
#
# Epoch 242: val_loss did not improve from 0.00083
#
# Epoch 243: val_loss did not improve from 0.00083
#
# Epoch 244: val_loss did not improve from 0.00083
#
# Epoch 245: val_loss did not improve from 0.00083
#
# Epoch 246: val_loss did not improve from 0.00083
#
# Epoch 247: val_loss did not improve from 0.00083
#
# Epoch 248: val_loss did not improve from 0.00083
#
# Epoch 249: val_loss did not improve from 0.00083
#
# Epoch 250: val_loss did not improve from 0.00083
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.001, 'batch_size': 64, 'num_epochs': 200}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00083
#
# Epoch 2: val_loss did not improve from 0.00083
#
# Epoch 3: val_loss did not improve from 0.00083
#
# Epoch 4: val_loss did not improve from 0.00083
#
# Epoch 5: val_loss did not improve from 0.00083
#
# Epoch 6: val_loss did not improve from 0.00083
#
# Epoch 7: val_loss did not improve from 0.00083
#
# Epoch 8: val_loss did not improve from 0.00083
#
# Epoch 9: val_loss did not improve from 0.00083
#
# Epoch 10: val_loss did not improve from 0.00083
#
# Epoch 11: val_loss did not improve from 0.00083
#
# Epoch 12: val_loss did not improve from 0.00083
#
# Epoch 13: val_loss did not improve from 0.00083
#
# Epoch 14: val_loss did not improve from 0.00083
#
# Epoch 15: val_loss did not improve from 0.00083
#
# Epoch 16: val_loss did not improve from 0.00083
#
# Epoch 17: val_loss did not improve from 0.00083
#
# Epoch 18: val_loss did not improve from 0.00083
#
# Epoch 19: val_loss did not improve from 0.00083
#
# Epoch 20: val_loss did not improve from 0.00083
#
# Epoch 21: val_loss did not improve from 0.00083
#
# Epoch 22: val_loss did not improve from 0.00083
#
# Epoch 23: val_loss did not improve from 0.00083
#
# Epoch 24: val_loss did not improve from 0.00083
#
# Epoch 25: val_loss did not improve from 0.00083
#
# Epoch 26: val_loss did not improve from 0.00083
#
# Epoch 27: val_loss did not improve from 0.00083
#
# Epoch 28: val_loss did not improve from 0.00083
#
# Epoch 29: val_loss did not improve from 0.00083
#
# Epoch 30: val_loss did not improve from 0.00083
#
# Epoch 31: val_loss did not improve from 0.00083
#
# Epoch 32: val_loss did not improve from 0.00083
#
# Epoch 33: val_loss did not improve from 0.00083
#
# Epoch 34: val_loss did not improve from 0.00083
#
# Epoch 35: val_loss did not improve from 0.00083
#
# Epoch 36: val_loss did not improve from 0.00083
#
# Epoch 37: val_loss did not improve from 0.00083
#
# Epoch 38: val_loss did not improve from 0.00083
#
# Epoch 39: val_loss did not improve from 0.00083
#
# Epoch 40: val_loss did not improve from 0.00083
#
# Epoch 41: val_loss did not improve from 0.00083
#
# Epoch 42: val_loss did not improve from 0.00083
#
# Epoch 43: val_loss did not improve from 0.00083
#
# Epoch 44: val_loss did not improve from 0.00083
#
# Epoch 45: val_loss did not improve from 0.00083
#
# Epoch 46: val_loss did not improve from 0.00083
#
# Epoch 47: val_loss did not improve from 0.00083
#
# Epoch 48: val_loss did not improve from 0.00083
#
# Epoch 49: val_loss did not improve from 0.00083
#
# Epoch 50: val_loss did not improve from 0.00083
#
# Epoch 51: val_loss did not improve from 0.00083
#
# Epoch 52: val_loss did not improve from 0.00083
#
# Epoch 53: val_loss did not improve from 0.00083
#
# Epoch 54: val_loss did not improve from 0.00083
#
# Epoch 55: val_loss did not improve from 0.00083
#
# Epoch 56: val_loss did not improve from 0.00083
#
# Epoch 57: val_loss did not improve from 0.00083
#
# Epoch 58: val_loss did not improve from 0.00083
#
# Epoch 59: val_loss did not improve from 0.00083
#
# Epoch 60: val_loss did not improve from 0.00083
#
# Epoch 61: val_loss did not improve from 0.00083
#
# Epoch 62: val_loss did not improve from 0.00083
#
# Epoch 63: val_loss did not improve from 0.00083
#
# Epoch 64: val_loss did not improve from 0.00083
#
# Epoch 65: val_loss did not improve from 0.00083
#
# Epoch 66: val_loss did not improve from 0.00083
#
# Epoch 67: val_loss did not improve from 0.00083
#
# Epoch 68: val_loss did not improve from 0.00083
#
# Epoch 69: val_loss did not improve from 0.00083
#
# Epoch 70: val_loss did not improve from 0.00083
#
# Epoch 71: val_loss did not improve from 0.00083
#
# Epoch 72: val_loss did not improve from 0.00083
#
# Epoch 73: val_loss did not improve from 0.00083
#
# Epoch 74: val_loss did not improve from 0.00083
#
# Epoch 75: val_loss did not improve from 0.00083
#
# Epoch 76: val_loss did not improve from 0.00083
#
# Epoch 77: val_loss did not improve from 0.00083
#
# Epoch 78: val_loss did not improve from 0.00083
#
# Epoch 79: val_loss did not improve from 0.00083
#
# Epoch 80: val_loss did not improve from 0.00083
#
# Epoch 81: val_loss did not improve from 0.00083
#
# Epoch 82: val_loss did not improve from 0.00083
#
# Epoch 83: val_loss did not improve from 0.00083
#
# Epoch 84: val_loss did not improve from 0.00083
#
# Epoch 85: val_loss did not improve from 0.00083
#
# Epoch 86: val_loss did not improve from 0.00083
#
# Epoch 87: val_loss did not improve from 0.00083
#
# Epoch 88: val_loss did not improve from 0.00083
#
# Epoch 89: val_loss did not improve from 0.00083
#
# Epoch 90: val_loss did not improve from 0.00083
#
# Epoch 91: val_loss did not improve from 0.00083
#
# Epoch 92: val_loss did not improve from 0.00083
#
# Epoch 93: val_loss did not improve from 0.00083
#
# Epoch 94: val_loss did not improve from 0.00083
#
# Epoch 95: val_loss did not improve from 0.00083
#
# Epoch 96: val_loss did not improve from 0.00083
#
# Epoch 97: val_loss did not improve from 0.00083
#
# Epoch 98: val_loss did not improve from 0.00083
#
# Epoch 99: val_loss did not improve from 0.00083
#
# Epoch 100: val_loss did not improve from 0.00083
#
# Epoch 101: val_loss did not improve from 0.00083
#
# Epoch 102: val_loss did not improve from 0.00083
#
# Epoch 103: val_loss did not improve from 0.00083
#
# Epoch 104: val_loss did not improve from 0.00083
#
# Epoch 105: val_loss did not improve from 0.00083
#
# Epoch 106: val_loss did not improve from 0.00083
#
# Epoch 107: val_loss did not improve from 0.00083
#
# Epoch 108: val_loss did not improve from 0.00083
#
# Epoch 109: val_loss did not improve from 0.00083
#
# Epoch 110: val_loss did not improve from 0.00083
#
# Epoch 111: val_loss did not improve from 0.00083
#
# Epoch 112: val_loss did not improve from 0.00083
#
# Epoch 113: val_loss did not improve from 0.00083
#
# Epoch 114: val_loss did not improve from 0.00083
#
# Epoch 115: val_loss did not improve from 0.00083
#
# Epoch 116: val_loss did not improve from 0.00083
#
# Epoch 117: val_loss did not improve from 0.00083
#
# Epoch 118: val_loss did not improve from 0.00083
#
# Epoch 119: val_loss did not improve from 0.00083
#
# Epoch 120: val_loss did not improve from 0.00083
#
# Epoch 121: val_loss did not improve from 0.00083
#
# Epoch 122: val_loss did not improve from 0.00083
#
# Epoch 123: val_loss did not improve from 0.00083
#
# Epoch 124: val_loss did not improve from 0.00083
#
# Epoch 125: val_loss did not improve from 0.00083
#
# Epoch 126: val_loss did not improve from 0.00083
#
# Epoch 127: val_loss did not improve from 0.00083
#
# Epoch 128: val_loss did not improve from 0.00083
#
# Epoch 129: val_loss did not improve from 0.00083
#
# Epoch 130: val_loss did not improve from 0.00083
#
# Epoch 131: val_loss did not improve from 0.00083
# Epoch 131: early stopping
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.001, 'batch_size': 64, 'num_epochs': 250}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00083
#
# Epoch 2: val_loss did not improve from 0.00083
#
# Epoch 3: val_loss did not improve from 0.00083
#
# Epoch 4: val_loss did not improve from 0.00083
#
# Epoch 5: val_loss did not improve from 0.00083
#
# Epoch 6: val_loss did not improve from 0.00083
#
# Epoch 7: val_loss did not improve from 0.00083
#
# Epoch 8: val_loss did not improve from 0.00083
#
# Epoch 9: val_loss did not improve from 0.00083
#
# Epoch 10: val_loss did not improve from 0.00083
#
# Epoch 11: val_loss did not improve from 0.00083
#
# Epoch 12: val_loss did not improve from 0.00083
#
# Epoch 13: val_loss did not improve from 0.00083
#
# Epoch 14: val_loss did not improve from 0.00083
#
# Epoch 15: val_loss did not improve from 0.00083
#
# Epoch 16: val_loss did not improve from 0.00083
#
# Epoch 17: val_loss did not improve from 0.00083
#
# Epoch 18: val_loss did not improve from 0.00083
#
# Epoch 19: val_loss did not improve from 0.00083
#
# Epoch 20: val_loss did not improve from 0.00083
#
# Epoch 21: val_loss did not improve from 0.00083
#
# Epoch 22: val_loss did not improve from 0.00083
#
# Epoch 23: val_loss did not improve from 0.00083
#
# Epoch 24: val_loss did not improve from 0.00083
#
# Epoch 25: val_loss did not improve from 0.00083
#
# Epoch 26: val_loss did not improve from 0.00083
#
# Epoch 27: val_loss did not improve from 0.00083
#
# Epoch 28: val_loss did not improve from 0.00083
#
# Epoch 29: val_loss did not improve from 0.00083
#
# Epoch 30: val_loss did not improve from 0.00083
#
# Epoch 31: val_loss did not improve from 0.00083
#
# Epoch 32: val_loss did not improve from 0.00083
#
# Epoch 33: val_loss did not improve from 0.00083
#
# Epoch 34: val_loss did not improve from 0.00083
#
# Epoch 35: val_loss did not improve from 0.00083
#
# Epoch 36: val_loss did not improve from 0.00083
#
# Epoch 37: val_loss did not improve from 0.00083
#
# Epoch 38: val_loss did not improve from 0.00083
#
# Epoch 39: val_loss did not improve from 0.00083
#
# Epoch 40: val_loss did not improve from 0.00083
#
# Epoch 41: val_loss did not improve from 0.00083
#
# Epoch 42: val_loss did not improve from 0.00083
#
# Epoch 43: val_loss did not improve from 0.00083
#
# Epoch 44: val_loss did not improve from 0.00083
#
# Epoch 45: val_loss did not improve from 0.00083
#
# Epoch 46: val_loss did not improve from 0.00083
#
# Epoch 47: val_loss did not improve from 0.00083
#
# Epoch 48: val_loss did not improve from 0.00083
#
# Epoch 49: val_loss did not improve from 0.00083
#
# Epoch 50: val_loss did not improve from 0.00083
#
# Epoch 51: val_loss did not improve from 0.00083
#
# Epoch 52: val_loss did not improve from 0.00083
#
# Epoch 53: val_loss did not improve from 0.00083
#
# Epoch 54: val_loss did not improve from 0.00083
#
# Epoch 55: val_loss did not improve from 0.00083
#
# Epoch 56: val_loss did not improve from 0.00083
#
# Epoch 57: val_loss did not improve from 0.00083
#
# Epoch 58: val_loss did not improve from 0.00083
#
# Epoch 59: val_loss did not improve from 0.00083
#
# Epoch 60: val_loss did not improve from 0.00083
#
# Epoch 61: val_loss did not improve from 0.00083
#
# Epoch 62: val_loss did not improve from 0.00083
#
# Epoch 63: val_loss did not improve from 0.00083
#
# Epoch 64: val_loss did not improve from 0.00083
#
# Epoch 65: val_loss did not improve from 0.00083
#
# Epoch 66: val_loss did not improve from 0.00083
#
# Epoch 67: val_loss did not improve from 0.00083
#
# Epoch 68: val_loss did not improve from 0.00083
#
# Epoch 69: val_loss did not improve from 0.00083
#
# Epoch 70: val_loss did not improve from 0.00083
#
# Epoch 71: val_loss did not improve from 0.00083
#
# Epoch 72: val_loss did not improve from 0.00083
#
# Epoch 73: val_loss did not improve from 0.00083
#
# Epoch 74: val_loss did not improve from 0.00083
#
# Epoch 75: val_loss did not improve from 0.00083
#
# Epoch 76: val_loss did not improve from 0.00083
#
# Epoch 77: val_loss did not improve from 0.00083
#
# Epoch 78: val_loss did not improve from 0.00083
#
# Epoch 79: val_loss did not improve from 0.00083
#
# Epoch 80: val_loss did not improve from 0.00083
#
# Epoch 81: val_loss did not improve from 0.00083
#
# Epoch 82: val_loss did not improve from 0.00083
#
# Epoch 83: val_loss did not improve from 0.00083
#
# Epoch 84: val_loss did not improve from 0.00083
#
# Epoch 85: val_loss did not improve from 0.00083
#
# Epoch 86: val_loss did not improve from 0.00083
#
# Epoch 87: val_loss did not improve from 0.00083
#
# Epoch 88: val_loss did not improve from 0.00083
#
# Epoch 89: val_loss did not improve from 0.00083
#
# Epoch 90: val_loss did not improve from 0.00083
#
# Epoch 91: val_loss did not improve from 0.00083
#
# Epoch 92: val_loss did not improve from 0.00083
#
# Epoch 93: val_loss did not improve from 0.00083
#
# Epoch 94: val_loss did not improve from 0.00083
#
# Epoch 95: val_loss did not improve from 0.00083
#
# Epoch 96: val_loss did not improve from 0.00083
#
# Epoch 97: val_loss did not improve from 0.00083
#
# Epoch 98: val_loss did not improve from 0.00083
#
# Epoch 99: val_loss did not improve from 0.00083
#
# Epoch 100: val_loss did not improve from 0.00083
#
# Epoch 101: val_loss did not improve from 0.00083
#
# Epoch 102: val_loss did not improve from 0.00083
#
# Epoch 103: val_loss did not improve from 0.00083
#
# Epoch 104: val_loss did not improve from 0.00083
#
# Epoch 105: val_loss did not improve from 0.00083
#
# Epoch 106: val_loss did not improve from 0.00083
#
# Epoch 107: val_loss did not improve from 0.00083
#
# Epoch 108: val_loss did not improve from 0.00083
#
# Epoch 109: val_loss did not improve from 0.00083
#
# Epoch 110: val_loss did not improve from 0.00083
#
# Epoch 111: val_loss did not improve from 0.00083
#
# Epoch 112: val_loss did not improve from 0.00083
#
# Epoch 113: val_loss did not improve from 0.00083
#
# Epoch 114: val_loss did not improve from 0.00083
#
# Epoch 115: val_loss did not improve from 0.00083
#
# Epoch 116: val_loss did not improve from 0.00083
#
# Epoch 117: val_loss did not improve from 0.00083
#
# Epoch 118: val_loss did not improve from 0.00083
#
# Epoch 119: val_loss did not improve from 0.00083
#
# Epoch 120: val_loss did not improve from 0.00083
#
# Epoch 121: val_loss did not improve from 0.00083
#
# Epoch 122: val_loss did not improve from 0.00083
#
# Epoch 123: val_loss did not improve from 0.00083
#
# Epoch 124: val_loss did not improve from 0.00083
#
# Epoch 125: val_loss did not improve from 0.00083
#
# Epoch 126: val_loss did not improve from 0.00083
#
# Epoch 127: val_loss did not improve from 0.00083
#
# Epoch 128: val_loss did not improve from 0.00083
#
# Epoch 129: val_loss did not improve from 0.00083
#
# Epoch 130: val_loss did not improve from 0.00083
#
# Epoch 131: val_loss did not improve from 0.00083
#
# Epoch 132: val_loss did not improve from 0.00083
#
# Epoch 133: val_loss did not improve from 0.00083
#
# Epoch 134: val_loss did not improve from 0.00083
#
# Epoch 135: val_loss did not improve from 0.00083
#
# Epoch 136: val_loss did not improve from 0.00083
#
# Epoch 137: val_loss did not improve from 0.00083
#
# Epoch 138: val_loss did not improve from 0.00083
#
# Epoch 139: val_loss did not improve from 0.00083
#
# Epoch 140: val_loss did not improve from 0.00083
#
# Epoch 141: val_loss did not improve from 0.00083
#
# Epoch 142: val_loss did not improve from 0.00083
#
# Epoch 143: val_loss did not improve from 0.00083
#
# Epoch 144: val_loss did not improve from 0.00083
#
# Epoch 145: val_loss did not improve from 0.00083
#
# Epoch 146: val_loss did not improve from 0.00083
#
# Epoch 147: val_loss did not improve from 0.00083
#
# Epoch 148: val_loss did not improve from 0.00083
#
# Epoch 149: val_loss did not improve from 0.00083
#
# Epoch 150: val_loss did not improve from 0.00083
#
# Epoch 151: val_loss did not improve from 0.00083
#
# Epoch 152: val_loss did not improve from 0.00083
#
# Epoch 153: val_loss did not improve from 0.00083
#
# Epoch 154: val_loss did not improve from 0.00083
#
# Epoch 155: val_loss did not improve from 0.00083
#
# Epoch 156: val_loss did not improve from 0.00083
#
# Epoch 157: val_loss did not improve from 0.00083
#
# Epoch 158: val_loss did not improve from 0.00083
#
# Epoch 159: val_loss did not improve from 0.00083
#
# Epoch 160: val_loss did not improve from 0.00083
#
# Epoch 161: val_loss did not improve from 0.00083
#
# Epoch 162: val_loss did not improve from 0.00083
#
# Epoch 163: val_loss did not improve from 0.00083
#
# Epoch 164: val_loss did not improve from 0.00083
#
# Epoch 165: val_loss did not improve from 0.00083
#
# Epoch 166: val_loss did not improve from 0.00083
#
# Epoch 167: val_loss did not improve from 0.00083
#
# Epoch 168: val_loss did not improve from 0.00083
#
# Epoch 169: val_loss did not improve from 0.00083
#
# Epoch 170: val_loss did not improve from 0.00083
#
# Epoch 171: val_loss did not improve from 0.00083
#
# Epoch 172: val_loss did not improve from 0.00083
#
# Epoch 173: val_loss did not improve from 0.00083
#
# Epoch 174: val_loss did not improve from 0.00083
#
# Epoch 175: val_loss did not improve from 0.00083
#
# Epoch 176: val_loss did not improve from 0.00083
#
# Epoch 177: val_loss did not improve from 0.00083
#
# Epoch 178: val_loss did not improve from 0.00083
#
# Epoch 179: val_loss did not improve from 0.00083
#
# Epoch 180: val_loss did not improve from 0.00083
#
# Epoch 181: val_loss did not improve from 0.00083
#
# Epoch 182: val_loss did not improve from 0.00083
#
# Epoch 183: val_loss did not improve from 0.00083
#
# Epoch 184: val_loss did not improve from 0.00083
#
# Epoch 185: val_loss did not improve from 0.00083
#
# Epoch 186: val_loss did not improve from 0.00083
#
# Epoch 187: val_loss did not improve from 0.00083
#
# Epoch 188: val_loss did not improve from 0.00083
#
# Epoch 189: val_loss did not improve from 0.00083
#
# Epoch 190: val_loss did not improve from 0.00083
#
# Epoch 191: val_loss did not improve from 0.00083
#
# Epoch 192: val_loss did not improve from 0.00083
#
# Epoch 193: val_loss did not improve from 0.00083
#
# Epoch 194: val_loss did not improve from 0.00083
#
# Epoch 195: val_loss did not improve from 0.00083
#
# Epoch 196: val_loss did not improve from 0.00083
#
# Epoch 197: val_loss did not improve from 0.00083
#
# Epoch 198: val_loss did not improve from 0.00083
#
# Epoch 199: val_loss did not improve from 0.00083
#
# Epoch 200: val_loss did not improve from 0.00083
#
# Epoch 201: val_loss did not improve from 0.00083
#
# Epoch 202: val_loss did not improve from 0.00083
#
# Epoch 203: val_loss did not improve from 0.00083
#
# Epoch 204: val_loss did not improve from 0.00083
#
# Epoch 205: val_loss did not improve from 0.00083
#
# Epoch 206: val_loss did not improve from 0.00083
#
# Epoch 207: val_loss did not improve from 0.00083
#
# Epoch 208: val_loss did not improve from 0.00083
#
# Epoch 209: val_loss did not improve from 0.00083
#
# Epoch 210: val_loss did not improve from 0.00083
#
# Epoch 211: val_loss did not improve from 0.00083
#
# Epoch 212: val_loss did not improve from 0.00083
#
# Epoch 213: val_loss did not improve from 0.00083
#
# Epoch 214: val_loss did not improve from 0.00083
#
# Epoch 215: val_loss did not improve from 0.00083
#
# Epoch 216: val_loss did not improve from 0.00083
#
# Epoch 217: val_loss did not improve from 0.00083
#
# Epoch 218: val_loss did not improve from 0.00083
#
# Epoch 219: val_loss did not improve from 0.00083
#
# Epoch 220: val_loss did not improve from 0.00083
#
# Epoch 221: val_loss did not improve from 0.00083
#
# Epoch 222: val_loss did not improve from 0.00083
#
# Epoch 223: val_loss did not improve from 0.00083
#
# Epoch 224: val_loss did not improve from 0.00083
#
# Epoch 225: val_loss did not improve from 0.00083
#
# Epoch 226: val_loss did not improve from 0.00083
#
# Epoch 227: val_loss improved from 0.00083 to 0.00076, saving model to 3Var_vn30_lstm.h5
#
# Epoch 228: val_loss did not improve from 0.00076
#
# Epoch 229: val_loss did not improve from 0.00076
#
# Epoch 230: val_loss did not improve from 0.00076
#
# Epoch 231: val_loss did not improve from 0.00076
#
# Epoch 232: val_loss did not improve from 0.00076
#
# Epoch 233: val_loss did not improve from 0.00076
#
# Epoch 234: val_loss did not improve from 0.00076
#
# Epoch 235: val_loss did not improve from 0.00076
#
# Epoch 236: val_loss did not improve from 0.00076
#
# Epoch 237: val_loss did not improve from 0.00076
#
# Epoch 238: val_loss did not improve from 0.00076
#
# Epoch 239: val_loss did not improve from 0.00076
#
# Epoch 240: val_loss did not improve from 0.00076
#
# Epoch 241: val_loss did not improve from 0.00076
#
# Epoch 242: val_loss did not improve from 0.00076
#
# Epoch 243: val_loss did not improve from 0.00076
#
# Epoch 244: val_loss did not improve from 0.00076
#
# Epoch 245: val_loss did not improve from 0.00076
#
# Epoch 246: val_loss did not improve from 0.00076
#
# Epoch 247: val_loss did not improve from 0.00076
#
# Epoch 248: val_loss did not improve from 0.00076
#
# Epoch 249: val_loss did not improve from 0.00076
#
# Epoch 250: val_loss did not improve from 0.00076
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 32, 'num_epochs': 200}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00076
#
# Epoch 2: val_loss did not improve from 0.00076
#
# Epoch 3: val_loss did not improve from 0.00076
#
# Epoch 4: val_loss did not improve from 0.00076
#
# Epoch 5: val_loss did not improve from 0.00076
#
# Epoch 6: val_loss did not improve from 0.00076
#
# Epoch 7: val_loss did not improve from 0.00076
#
# Epoch 8: val_loss did not improve from 0.00076
#
# Epoch 9: val_loss did not improve from 0.00076
#
# Epoch 10: val_loss did not improve from 0.00076
#
# Epoch 11: val_loss did not improve from 0.00076
#
# Epoch 12: val_loss did not improve from 0.00076
#
# Epoch 13: val_loss did not improve from 0.00076
#
# Epoch 14: val_loss did not improve from 0.00076
#
# Epoch 15: val_loss did not improve from 0.00076
#
# Epoch 16: val_loss did not improve from 0.00076
#
# Epoch 17: val_loss did not improve from 0.00076
#
# Epoch 18: val_loss did not improve from 0.00076
#
# Epoch 19: val_loss did not improve from 0.00076
#
# Epoch 20: val_loss did not improve from 0.00076
#
# Epoch 21: val_loss did not improve from 0.00076
#
# Epoch 22: val_loss did not improve from 0.00076
#
# Epoch 23: val_loss did not improve from 0.00076
#
# Epoch 24: val_loss did not improve from 0.00076
#
# Epoch 25: val_loss did not improve from 0.00076
#
# Epoch 26: val_loss did not improve from 0.00076
#
# Epoch 27: val_loss did not improve from 0.00076
#
# Epoch 28: val_loss did not improve from 0.00076
#
# Epoch 29: val_loss did not improve from 0.00076
#
# Epoch 30: val_loss did not improve from 0.00076
#
# Epoch 31: val_loss did not improve from 0.00076
#
# Epoch 32: val_loss did not improve from 0.00076
#
# Epoch 33: val_loss did not improve from 0.00076
#
# Epoch 34: val_loss did not improve from 0.00076
#
# Epoch 35: val_loss did not improve from 0.00076
#
# Epoch 36: val_loss did not improve from 0.00076
#
# Epoch 37: val_loss did not improve from 0.00076
#
# Epoch 38: val_loss did not improve from 0.00076
#
# Epoch 39: val_loss did not improve from 0.00076
#
# Epoch 40: val_loss did not improve from 0.00076
#
# Epoch 41: val_loss did not improve from 0.00076
#
# Epoch 42: val_loss did not improve from 0.00076
#
# Epoch 43: val_loss did not improve from 0.00076
#
# Epoch 44: val_loss did not improve from 0.00076
#
# Epoch 45: val_loss did not improve from 0.00076
#
# Epoch 46: val_loss did not improve from 0.00076
#
# Epoch 47: val_loss did not improve from 0.00076
#
# Epoch 48: val_loss did not improve from 0.00076
#
# Epoch 49: val_loss did not improve from 0.00076
#
# Epoch 50: val_loss did not improve from 0.00076
#
# Epoch 51: val_loss did not improve from 0.00076
#
# Epoch 52: val_loss did not improve from 0.00076
#
# Epoch 53: val_loss did not improve from 0.00076
#
# Epoch 54: val_loss did not improve from 0.00076
#
# Epoch 55: val_loss did not improve from 0.00076
#
# Epoch 56: val_loss did not improve from 0.00076
#
# Epoch 57: val_loss did not improve from 0.00076
#
# Epoch 58: val_loss did not improve from 0.00076
#
# Epoch 59: val_loss did not improve from 0.00076
#
# Epoch 60: val_loss did not improve from 0.00076
#
# Epoch 61: val_loss did not improve from 0.00076
#
# Epoch 62: val_loss did not improve from 0.00076
#
# Epoch 63: val_loss did not improve from 0.00076
#
# Epoch 64: val_loss did not improve from 0.00076
#
# Epoch 65: val_loss did not improve from 0.00076
#
# Epoch 66: val_loss did not improve from 0.00076
#
# Epoch 67: val_loss did not improve from 0.00076
#
# Epoch 68: val_loss did not improve from 0.00076
#
# Epoch 69: val_loss did not improve from 0.00076
#
# Epoch 70: val_loss did not improve from 0.00076
#
# Epoch 71: val_loss did not improve from 0.00076
#
# Epoch 72: val_loss did not improve from 0.00076
#
# Epoch 73: val_loss did not improve from 0.00076
#
# Epoch 74: val_loss did not improve from 0.00076
#
# Epoch 75: val_loss did not improve from 0.00076
#
# Epoch 76: val_loss did not improve from 0.00076
#
# Epoch 77: val_loss did not improve from 0.00076
#
# Epoch 78: val_loss did not improve from 0.00076
#
# Epoch 79: val_loss did not improve from 0.00076
#
# Epoch 80: val_loss did not improve from 0.00076
#
# Epoch 81: val_loss did not improve from 0.00076
#
# Epoch 82: val_loss did not improve from 0.00076
#
# Epoch 83: val_loss did not improve from 0.00076
#
# Epoch 84: val_loss did not improve from 0.00076
#
# Epoch 85: val_loss did not improve from 0.00076
#
# Epoch 86: val_loss did not improve from 0.00076
#
# Epoch 87: val_loss did not improve from 0.00076
#
# Epoch 88: val_loss did not improve from 0.00076
#
# Epoch 89: val_loss did not improve from 0.00076
#
# Epoch 90: val_loss did not improve from 0.00076
#
# Epoch 91: val_loss did not improve from 0.00076
# Epoch 91: early stopping
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 32, 'num_epochs': 250}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00076
#
# Epoch 2: val_loss did not improve from 0.00076
#
# Epoch 3: val_loss did not improve from 0.00076
#
# Epoch 4: val_loss did not improve from 0.00076
#
# Epoch 5: val_loss did not improve from 0.00076
#
# Epoch 6: val_loss did not improve from 0.00076
#
# Epoch 7: val_loss did not improve from 0.00076
#
# Epoch 8: val_loss did not improve from 0.00076
#
# Epoch 9: val_loss did not improve from 0.00076
#
# Epoch 10: val_loss did not improve from 0.00076
#
# Epoch 11: val_loss did not improve from 0.00076
#
# Epoch 12: val_loss did not improve from 0.00076
#
# Epoch 13: val_loss did not improve from 0.00076
#
# Epoch 14: val_loss did not improve from 0.00076
#
# Epoch 15: val_loss did not improve from 0.00076
#
# Epoch 16: val_loss did not improve from 0.00076
#
# Epoch 17: val_loss did not improve from 0.00076
#
# Epoch 18: val_loss did not improve from 0.00076
#
# Epoch 19: val_loss did not improve from 0.00076
#
# Epoch 20: val_loss did not improve from 0.00076
#
# Epoch 21: val_loss did not improve from 0.00076
#
# Epoch 22: val_loss did not improve from 0.00076
#
# Epoch 23: val_loss did not improve from 0.00076
#
# Epoch 24: val_loss did not improve from 0.00076
#
# Epoch 25: val_loss did not improve from 0.00076
#
# Epoch 26: val_loss did not improve from 0.00076
#
# Epoch 27: val_loss did not improve from 0.00076
#
# Epoch 28: val_loss did not improve from 0.00076
#
# Epoch 29: val_loss did not improve from 0.00076
#
# ...
#
# Epoch 60: val_loss did not improve from 0.00074
#
# Epoch 61: val_loss did not improve from 0.00074
#
# Epoch 62: val_loss did not improve from 0.00074
#
# Epoch 63: val_loss did not improve from 0.00074
#
# Epoch 64: val_loss did not improve from 0.00074
#
# Epoch 65: val_loss did not improve from 0.00074
#
# Epoch 66: val_loss did not improve from 0.00074
#
# Epoch 67: val_loss did not improve from 0.00074
#
# Epoch 68: val_loss did not improve from 0.00074
#
# Epoch 69: val_loss did not improve from 0.00074
#
# Epoch 70: val_loss did not improve from 0.00074
#
# Epoch 71: val_loss did not improve from 0.00074
#
# Epoch 72: val_loss did not improve from 0.00074
#
# Epoch 73: val_loss did not improve from 0.00074
#
# Epoch 74: val_loss did not improve from 0.00074
#
# Epoch 75: val_loss did not improve from 0.00074
#
# Epoch 76: val_loss did not improve from 0.00074
#
# Epoch 77: val_loss did not improve from 0.00074
#
# Epoch 78: val_loss did not improve from 0.00074
#
# Epoch 79: val_loss did not improve from 0.00074
#
# Epoch 80: val_loss did not improve from 0.00074
#
# Epoch 81: val_loss did not improve from 0.00074
#
# Epoch 82: val_loss did not improve from 0.00074
#
# Epoch 83: val_loss did not improve from 0.00074
#
# Epoch 84: val_loss did not improve from 0.00074
#
# Epoch 85: val_loss did not improve from 0.00074
#
# Epoch 86: val_loss did not improve from 0.00074
#
# Epoch 87: val_loss did not improve from 0.00074
#
# Epoch 88: val_loss did not improve from 0.00074
#
# Epoch 89: val_loss did not improve from 0.00074
#
# Epoch 90: val_loss did not improve from 0.00074
#
# Epoch 91: val_loss did not improve from 0.00074
#
# Epoch 92: val_loss did not improve from 0.00074
#
# Epoch 93: val_loss did not improve from 0.00074
#
# Epoch 94: val_loss did not improve from 0.00074
#
# Epoch 95: val_loss did not improve from 0.00074
#
# Epoch 96: val_loss did not improve from 0.00074
#
# Epoch 97: val_loss did not improve from 0.00074
#
# Epoch 98: val_loss did not improve from 0.00074
#
# Epoch 99: val_loss did not improve from 0.00074
#
# Epoch 100: val_loss did not improve from 0.00074
#
# Epoch 101: val_loss did not improve from 0.00074
#
# Epoch 102: val_loss did not improve from 0.00074
#
# Epoch 103: val_loss did not improve from 0.00074
#
# Epoch 104: val_loss did not improve from 0.00074
#
# Epoch 105: val_loss did not improve from 0.00074
#
# Epoch 106: val_loss did not improve from 0.00074
#
# Epoch 107: val_loss did not improve from 0.00074
#
# Epoch 108: val_loss did not improve from 0.00074
#
# Epoch 109: val_loss did not improve from 0.00074
#
# Epoch 110: val_loss did not improve from 0.00074
#
# Epoch 111: val_loss did not improve from 0.00074
#
# Epoch 112: val_loss did not improve from 0.00074
#
# Epoch 113: val_loss did not improve from 0.00074
#
# Epoch 114: val_loss did not improve from 0.00074
#
# Epoch 115: val_loss did not improve from 0.00074
#
# Epoch 116: val_loss did not improve from 0.00074
#
# Epoch 117: val_loss did not improve from 0.00074
#
# Epoch 118: val_loss did not improve from 0.00074
#
# Epoch 119: val_loss did not improve from 0.00074
# Epoch 119: early stopping
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step
# Training with params: {'timesteps': 50, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 64, 'num_epochs': 250}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00074
#
# Epoch 2: val_loss did not improve from 0.00074
#
# Epoch 3: val_loss did not improve from 0.00074
#
# Epoch 4: val_loss did not improve from 0.00074
#
# Epoch 5: val_loss did not improve from 0.00074
#
# Epoch 6: val_loss did not improve from 0.00074
#
# Epoch 7: val_loss did not improve from 0.00074
#
# Epoch 8: val_loss did not improve from 0.00074
#
# Epoch 9: val_loss did not improve from 0.00074
#
# Epoch 10: val_loss did not improve from 0.00074
#
# Epoch 11: val_loss did not improve from 0.00074
#
# Epoch 12: val_loss did not improve from 0.00074
#
# Epoch 13: val_loss did not improve from 0.00074
#
# Epoch 14: val_loss did not improve from 0.00074
#
# Epoch 15: val_loss did not improve from 0.00074
#
# Epoch 16: val_loss did not improve from 0.00074
#
# Epoch 17: val_loss did not improve from 0.00074
#
# Epoch 18: val_loss did not improve from 0.00074
#
# Epoch 19: val_loss did not improve from 0.00074
#
# Epoch 20: val_loss did not improve from 0.00074
#
# Epoch 21: val_loss did not improve from 0.00074
#
# Epoch 22: val_loss did not improve from 0.00074
#
# Epoch 23: val_loss did not improve from 0.00074
#
# Epoch 24: val_loss did not improve from 0.00074
#
# Epoch 25: val_loss did not improve from 0.00074
#
# Epoch 26: val_loss did not improve from 0.00074
#
# Epoch 27: val_loss did not improve from 0.00074
#
# Epoch 28: val_loss did not improve from 0.00074
#
# Epoch 29: val_loss did not improve from 0.00074
#
# Epoch 30: val_loss did not improve from 0.00074
#
# Epoch 31: val_loss did not improve from 0.00074
#
# Epoch 32: val_loss did not improve from 0.00074
#
# Epoch 33: val_loss did not improve from 0.00074
#
# Epoch 34: val_loss did not improve from 0.00074
#
# Epoch 35: val_loss did not improve from 0.00074
#
# Epoch 36: val_loss did not improve from 0.00074
#
# Epoch 37: val_loss did not improve from 0.00074
#
# Epoch 38: val_loss did not improve from 0.00074
#
# Epoch 39: val_loss did not improve from 0.00074
#
# Epoch 40: val_loss did not improve from 0.00074
#
# Epoch 41: val_loss did not improve from 0.00074
#
# Epoch 42: val_loss did not improve from 0.00074
#
# Epoch 43: val_loss did not improve from 0.00074
#
# Epoch 44: val_loss did not improve from 0.00074
#
# Epoch 45: val_loss did not improve from 0.00074
#
# Epoch 46: val_loss did not improve from 0.00074
#
# Epoch 47: val_loss did not improve from 0.00074
#
# Epoch 48: val_loss did not improve from 0.00074
#
# Epoch 49: val_loss did not improve from 0.00074
#
# Epoch 50: val_loss did not improve from 0.00074
#
# Epoch 51: val_loss did not improve from 0.00074
#
# Epoch 52: val_loss did not improve from 0.00074
#
# Epoch 53: val_loss did not improve from 0.00074
#
# Epoch 54: val_loss did not improve from 0.00074
#
# Epoch 55: val_loss did not improve from 0.00074
#
# Epoch 56: val_loss did not improve from 0.00074
#
# Epoch 57: val_loss did not improve from 0.00074
#
# Epoch 58: val_loss did not improve from 0.00074
#
# Epoch 59: val_loss did not improve from 0.00074
#
# Epoch 60: val_loss did not improve from 0.00074
#
# Epoch 61: val_loss did not improve from 0.00074
#
# Epoch 62: val_loss did not improve from 0.00074
#
# Epoch 63: val_loss did not improve from 0.00074
#
# Epoch 64: val_loss did not improve from 0.00074
#
# Epoch 65: val_loss did not improve from 0.00074
#
# Epoch 66: val_loss did not improve from 0.00074
#
# Epoch 67: val_loss did not improve from 0.00074
#
# Epoch 68: val_loss did not improve from 0.00074
#
# Epoch 69: val_loss did not improve from 0.00074
#
# Epoch 70: val_loss did not improve from 0.00074
#
# Epoch 71: val_loss did not improve from 0.00074
#
# Epoch 72: val_loss did not improve from 0.00074
#
# Epoch 73: val_loss did not improve from 0.00074
#
# Epoch 74: val_loss did not improve from 0.00074
#
# Epoch 75: val_loss did not improve from 0.00074
#
# Epoch 76: val_loss did not improve from 0.00074
#
# Epoch 77: val_loss did not improve from 0.00074
#
# Epoch 78: val_loss did not improve from 0.00074
#
# Epoch 79: val_loss did not improve from 0.00074
#
# Epoch 80: val_loss did not improve from 0.00074
#
# Epoch 81: val_loss did not improve from 0.00074
#
# Epoch 82: val_loss did not improve from 0.00074
#
# Epoch 83: val_loss did not improve from 0.00074
#
# Epoch 84: val_loss did not improve from 0.00074
#
# Epoch 85: val_loss did not improve from 0.00074
#
# Epoch 86: val_loss did not improve from 0.00074
#
# Epoch 87: val_loss did not improve from 0.00074
#
# Epoch 88: val_loss did not improve from 0.00074
#
# Epoch 89: val_loss did not improve from 0.00074
#
# Epoch 90: val_loss did not improve from 0.00074
#
# Epoch 91: val_loss did not improve from 0.00074
#
# Epoch 92: val_loss did not improve from 0.00074
#
# Epoch 93: val_loss did not improve from 0.00074
#
# Epoch 94: val_loss did not improve from 0.00074
#
# Epoch 95: val_loss did not improve from 0.00074
#
# Epoch 96: val_loss did not improve from 0.00074
#
# Epoch 97: val_loss did not improve from 0.00074
#
# Epoch 98: val_loss did not improve from 0.00074
#
# Epoch 99: val_loss did not improve from 0.00074
#
# Epoch 100: val_loss did not improve from 0.00074
#
# Epoch 101: val_loss did not improve from 0.00074
#
# Epoch 102: val_loss did not improve from 0.00074
#
# Epoch 103: val_loss did not improve from 0.00074
#
# Epoch 104: val_loss did not improve from 0.00074
#
# Epoch 105: val_loss did not improve from 0.00074
#
# Epoch 106: val_loss did not improve from 0.00074
#
# Epoch 107: val_loss did not improve from 0.00074
#
# Epoch 108: val_loss did not improve from 0.00074
#
# Epoch 109: val_loss did not improve from 0.00074
#
# Epoch 110: val_loss did not improve from 0.00074
#
# Epoch 111: val_loss did not improve from 0.00074
#
# Epoch 112: val_loss did not improve from 0.00074
#
# Epoch 113: val_loss did not improve from 0.00074
#
# Epoch 114: val_loss did not improve from 0.00074
#
# Epoch 115: val_loss did not improve from 0.00074
#
# Epoch 116: val_loss did not improve from 0.00074
#
# Epoch 117: val_loss did not improve from 0.00074
#
# Epoch 118: val_loss did not improve from 0.00074
#
# Epoch 119: val_loss did not improve from 0.00074
#
# Epoch 120: val_loss did not improve from 0.00074
#
# Epoch 121: val_loss did not improve from 0.00074
#
# Epoch 122: val_loss did not improve from 0.00074
#
# Epoch 123: val_loss did not improve from 0.00074
#
# Epoch 124: val_loss did not improve from 0.00074
#
# Epoch 125: val_loss did not improve from 0.00074
#
# Epoch 126: val_loss did not improve from 0.00074
#
# Epoch 127: val_loss did not improve from 0.00074
#
# Epoch 128: val_loss did not improve from 0.00074
#
# Epoch 129: val_loss did not improve from 0.00074
#
# Epoch 130: val_loss did not improve from 0.00074
#
# Epoch 131: val_loss did not improve from 0.00074
#
# Epoch 132: val_loss did not improve from 0.00074
#
# Epoch 133: val_loss did not improve from 0.00074
#
# Epoch 134: val_loss did not improve from 0.00074
#
# Epoch 135: val_loss did not improve from 0.00074
#
# Epoch 136: val_loss did not improve from 0.00074
#
# Epoch 137: val_loss did not improve from 0.00074
#
# Epoch 138: val_loss did not improve from 0.00074
#
# Epoch 139: val_loss did not improve from 0.00074
#
# Epoch 140: val_loss did not improve from 0.00074
#
# Epoch 141: val_loss did not improve from 0.00074
#
# Epoch 142: val_loss did not improve from 0.00074
#
# Epoch 143: val_loss did not improve from 0.00074
#
# Epoch 144: val_loss did not improve from 0.00074
#
# Epoch 145: val_loss did not improve from 0.00074
#
# Epoch 146: val_loss did not improve from 0.00074
#
# Epoch 147: val_loss did not improve from 0.00074
#
# Epoch 148: val_loss did not improve from 0.00074
#
# Epoch 149: val_loss did not improve from 0.00074
#
# Epoch 150: val_loss did not improve from 0.00074
#
# Epoch 151: val_loss did not improve from 0.00074
#
# Epoch 152: val_loss did not improve from 0.00074
#
# Epoch 153: val_loss did not improve from 0.00074
#
# Epoch 154: val_loss did not improve from 0.00074
#
# Epoch 155: val_loss did not improve from 0.00074
#
# Epoch 156: val_loss did not improve from 0.00074
#
# Epoch 157: val_loss did not improve from 0.00074
#
# Epoch 158: val_loss did not improve from 0.00074
#
# Epoch 159: val_loss did not improve from 0.00074
#
# Epoch 160: val_loss did not improve from 0.00074
#
# Epoch 161: val_loss did not improve from 0.00074
#
# Epoch 162: val_loss did not improve from 0.00074
#
# Epoch 163: val_loss did not improve from 0.00074
#
# Epoch 164: val_loss did not improve from 0.00074
#
# Epoch 165: val_loss did not improve from 0.00074
#
# Epoch 166: val_loss did not improve from 0.00074
#
# Epoch 167: val_loss did not improve from 0.00074
#
# Epoch 168: val_loss did not improve from 0.00074
#
# Epoch 169: val_loss did not improve from 0.00074
#
# Epoch 170: val_loss did not improve from 0.00074
#
# Epoch 171: val_loss did not improve from 0.00074
#
# Epoch 172: val_loss did not improve from 0.00074
#
# Epoch 173: val_loss did not improve from 0.00074
#
# Epoch 174: val_loss did not improve from 0.00074
#
# Epoch 175: val_loss did not improve from 0.00074
#
# Epoch 176: val_loss did not improve from 0.00074
#
# Epoch 177: val_loss did not improve from 0.00074
#
# Epoch 178: val_loss did not improve from 0.00074
#
# Epoch 179: val_loss did not improve from 0.00074
#
# Epoch 180: val_loss did not improve from 0.00074
#
# Epoch 181: val_loss did not improve from 0.00074
#
# Epoch 182: val_loss did not improve from 0.00074
#
# Epoch 183: val_loss did not improve from 0.00074
#
# Epoch 184: val_loss did not improve from 0.00074
#
# Epoch 185: val_loss did not improve from 0.00074
#
# Epoch 186: val_loss did not improve from 0.00074
#
# Epoch 187: val_loss did not improve from 0.00074
#
# Epoch 188: val_loss did not improve from 0.00074
#
# Epoch 189: val_loss did not improve from 0.00074
#
# Epoch 190: val_loss did not improve from 0.00074
#
# Epoch 191: val_loss did not improve from 0.00074
#
# Epoch 192: val_loss did not improve from 0.00074
#
# Epoch 193: val_loss did not improve from 0.00074
#
# Epoch 194: val_loss did not improve from 0.00074
#
# Epoch 195: val_loss did not improve from 0.00074
#
# Epoch 196: val_loss did not improve from 0.00074
#
# Epoch 197: val_loss did not improve from 0.00074
#
# Epoch 198: val_loss did not improve from 0.00074
#
# Epoch 199: val_loss did not improve from 0.00074
#
# Epoch 200: val_loss did not improve from 0.00074
#
# Epoch 201: val_loss did not improve from 0.00074
#
# Epoch 202: val_loss did not improve from 0.00074
#
# Epoch 203: val_loss did not improve from 0.00074
#
# Epoch 204: val_loss did not improve from 0.00074
#
# Epoch 205: val_loss did not improve from 0.00074
#
# Epoch 206: val_loss did not improve from 0.00074
#
# Epoch 207: val_loss did not improve from 0.00074
#
# Epoch 208: val_loss did not improve from 0.00074
#
# Epoch 209: val_loss did not improve from 0.00074
#
# Epoch 210: val_loss did not improve from 0.00074
#
# Epoch 211: val_loss did not improve from 0.00074
#
# Epoch 212: val_loss did not improve from 0.00074
#
# Epoch 213: val_loss did not improve from 0.00074
#
# Epoch 214: val_loss did not improve from 0.00074
#
# Epoch 215: val_loss did not improve from 0.00074
#
# Epoch 216: val_loss did not improve from 0.00074
#
# Epoch 217: val_loss did not improve from 0.00074
#
# Epoch 218: val_loss did not improve from 0.00074
#
# Epoch 219: val_loss did not improve from 0.00074
#
# Epoch 220: val_loss did not improve from 0.00074
#
# Epoch 221: val_loss did not improve from 0.00074
#
# Epoch 222: val_loss did not improve from 0.00074
#
# Epoch 223: val_loss did not improve from 0.00074
#
# Epoch 224: val_loss did not improve from 0.00074
#
# Epoch 225: val_loss did not improve from 0.00074
#
# Epoch 226: val_loss did not improve from 0.00074
#
# Epoch 227: val_loss did not improve from 0.00074
#
# Epoch 228: val_loss did not improve from 0.00074
#
# Epoch 229: val_loss did not improve from 0.00074
#
# Epoch 230: val_loss did not improve from 0.00074
#
# Epoch 231: val_loss did not improve from 0.00074
#
# Epoch 232: val_loss did not improve from 0.00074
#
# Epoch 233: val_loss did not improve from 0.00074
#
# Epoch 234: val_loss did not improve from 0.00074
#
# Epoch 235: val_loss did not improve from 0.00074
#
# Epoch 236: val_loss did not improve from 0.00074
#
# Epoch 237: val_loss did not improve from 0.00074
#
# Epoch 238: val_loss did not improve from 0.00074
#
# Epoch 239: val_loss did not improve from 0.00074
#
# Epoch 240: val_loss did not improve from 0.00074
#
# Epoch 241: val_loss did not improve from 0.00074
#
# Epoch 242: val_loss did not improve from 0.00074
#
# Epoch 243: val_loss did not improve from 0.00074
#
# Epoch 244: val_loss did not improve from 0.00074
#
# Epoch 245: val_loss did not improve from 0.00074
#
# Epoch 246: val_loss did not improve from 0.00074
#
# Epoch 247: val_loss did not improve from 0.00074
#
# Epoch 248: val_loss did not improve from 0.00074
#
# Epoch 249: val_loss did not improve from 0.00074
#
# Epoch 250: val_loss did not improve from 0.00074
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step
# Best parameters: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.001, 'batch_size': 32, 'num_epochs': 250}
# Best RMSE score: 0.01982594372277713

# %% [markdown]
# ### Bước 5: Huấn luyện mô hình với bộ tham số tối ưu

# %%
timesteps = 30
hl = [40, 35]
lr = 1e-3
batch_size = 32
num_epochs = 250

model, train_error, val_error = fit_model_4(train, val, timesteps, hl, lr, batch_size, num_epochs)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00044
#
# Epoch 2: val_loss did not improve from 0.00044
#
# Epoch 3: val_loss did not improve from 0.00044
#
# Epoch 4: val_loss did not improve from 0.00044
#
# Epoch 5: val_loss did not improve from 0.00044
#
# Epoch 6: val_loss did not improve from 0.00044
#
# Epoch 7: val_loss did not improve from 0.00044
#
# Epoch 8: val_loss did not improve from 0.00044
#
# Epoch 9: val_loss did not improve from 0.00044
#
# Epoch 10: val_loss did not improve from 0.00044
#
# Epoch 11: val_loss did not improve from 0.00044
#
# Epoch 12: val_loss did not improve from 0.00044
#
# Epoch 13: val_loss did not improve from 0.00044
#
# Epoch 14: val_loss did not improve from 0.00044
#
# Epoch 15: val_loss did not improve from 0.00044
#
# Epoch 16: val_loss did not improve from 0.00044
#
# Epoch 17: val_loss did not improve from 0.00044
#
# Epoch 18: val_loss did not improve from 0.00044
#
# Epoch 19: val_loss did not improve from 0.00044
#
# Epoch 20: val_loss did not improve from 0.00044
#
# Epoch 21: val_loss did not improve from 0.00044
#
# Epoch 22: val_loss did not improve from 0.00044
#
# Epoch 23: val_loss did not improve from 0.00044
#
# Epoch 24: val_loss did not improve from 0.00044
#
# Epoch 25: val_loss did not improve from 0.00044
#
# Epoch 26: val_loss did not improve from 0.00044
#
# Epoch 27: val_loss did not improve from 0.00044
#
# Epoch 28: val_loss did not improve from 0.00044
#
# Epoch 29: val_loss did not improve from 0.00044
#
# Epoch 30: val_loss did not improve from 0.00044
#
# Epoch 31: val_loss did not improve from 0.00044
#
# Epoch 32: val_loss did not improve from 0.00044
#
# Epoch 33: val_loss did not improve from 0.00044
#
# Epoch 34: val_loss did not improve from 0.00044
#
# Epoch 35: val_loss did not improve from 0.00044
#
# Epoch 36: val_loss did not improve from 0.00044
#
# Epoch 37: val_loss did not improve from 0.00044
#
# Epoch 38: val_loss did not improve from 0.00044
#
# Epoch 39: val_loss did not improve from 0.00044
#
# Epoch 40: val_loss did not improve from 0.00044
#
# Epoch 41: val_loss did not improve from 0.00044
#
# Epoch 42: val_loss did not improve from 0.00044
#
# Epoch 43: val_loss did not improve from 0.00044
#
# Epoch 44: val_loss did not improve from 0.00044
#
# Epoch 45: val_loss did not improve from 0.00044
#
# Epoch 46: val_loss did not improve from 0.00044
#
# Epoch 47: val_loss did not improve from 0.00044
#
# Epoch 48: val_loss did not improve from 0.00044
#
# Epoch 49: val_loss did not improve from 0.00044
#
# Epoch 50: val_loss did not improve from 0.00044
#
# Epoch 51: val_loss did not improve from 0.00044
#
# Epoch 52: val_loss did not improve from 0.00044
#
# Epoch 53: val_loss did not improve from 0.00044
#
# Epoch 54: val_loss did not improve from 0.00044
#
# Epoch 55: val_loss did not improve from 0.00044
#
# Epoch 56: val_loss did not improve from 0.00044
#
# Epoch 57: val_loss did not improve from 0.00044
#
# Epoch 58: val_loss did not improve from 0.00044
#
# Epoch 59: val_loss did not improve from 0.00044
#
# Epoch 60: val_loss did not improve from 0.00044
#
# Epoch 61: val_loss did not improve from 0.00044
#
# Epoch 62: val_loss did not improve from 0.00044
#
# Epoch 63: val_loss did not improve from 0.00044
#
# Epoch 64: val_loss did not improve from 0.00044
#
# Epoch 65: val_loss did not improve from 0.00044
#
# Epoch 66: val_loss did not improve from 0.00044
#
# Epoch 67: val_loss did not improve from 0.00044
#
# Epoch 68: val_loss did not improve from 0.00044
#
# Epoch 69: val_loss did not improve from 0.00044
#
# Epoch 70: val_loss did not improve from 0.00044
#
# Epoch 71: val_loss did not improve from 0.00044
#
# Epoch 72: val_loss did not improve from 0.00044
#
# Epoch 73: val_loss did not improve from 0.00044
#
# Epoch 74: val_loss did not improve from 0.00044
#
# Epoch 75: val_loss did not improve from 0.00044
#
# Epoch 76: val_loss did not improve from 0.00044
#
# Epoch 77: val_loss did not improve from 0.00044
#
# Epoch 78: val_loss did not improve from 0.00044
#
# Epoch 79: val_loss did not improve from 0.00044
#
# Epoch 80: val_loss did not improve from 0.00044
#
# Epoch 81: val_loss did not improve from 0.00044
#
# Epoch 82: val_loss did not improve from 0.00044
#
# Epoch 83: val_loss did not improve from 0.00044
#
# Epoch 84: val_loss did not improve from 0.00044
#
# Epoch 85: val_loss did not improve from 0.00044
#
# Epoch 86: val_loss did not improve from 0.00044
#
# Epoch 87: val_loss did not improve from 0.00044
#
# Epoch 88: val_loss did not improve from 0.00044
#
# Epoch 89: val_loss did not improve from 0.00044
#
# Epoch 90: val_loss did not improve from 0.00044
#
# Epoch 91: val_loss did not improve from 0.00044
#
# Epoch 92: val_loss did not improve from 0.00044
#
# Epoch 93: val_loss did not improve from 0.00044
#
# Epoch 94: val_loss did not improve from 0.00044
#
# Epoch 95: val_loss did not improve from 0.00044
#
# Epoch 96: val_loss did not improve from 0.00044
#
# Epoch 97: val_loss did not improve from 0.00044
#
# Epoch 98: val_loss did not improve from 0.00044
#
# Epoch 99: val_loss did not improve from 0.00044
#
# Epoch 100: val_loss did not improve from 0.00044
#
# Epoch 101: val_loss did not improve from 0.00044
#
# Epoch 102: val_loss did not improve from 0.00044
#
# Epoch 103: val_loss did not improve from 0.00044
#
# Epoch 104: val_loss did not improve from 0.00044
#
# Epoch 105: val_loss did not improve from 0.00044
#
# Epoch 106: val_loss did not improve from 0.00044
#
# Epoch 107: val_loss did not improve from 0.00044
#
# Epoch 108: val_loss did not improve from 0.00044
#
# Epoch 109: val_loss did not improve from 0.00044
#
# Epoch 110: val_loss did not improve from 0.00044
#
# Epoch 111: val_loss did not improve from 0.00044
#
# Epoch 112: val_loss did not improve from 0.00044
#
# Epoch 113: val_loss did not improve from 0.00044
#
# Epoch 114: val_loss did not improve from 0.00044
#
# Epoch 115: val_loss did not improve from 0.00044
#
# Epoch 116: val_loss did not improve from 0.00044
#
# Epoch 117: val_loss did not improve from 0.00044
#
# Epoch 118: val_loss did not improve from 0.00044
#
# Epoch 119: val_loss did not improve from 0.00044
#
# Epoch 120: val_loss did not improve from 0.00044
#
# Epoch 121: val_loss did not improve from 0.00044
#
# Epoch 122: val_loss did not improve from 0.00044
#
# Epoch 123: val_loss did not improve from 0.00044
#
# Epoch 124: val_loss did not improve from 0.00044
#
# Epoch 125: val_loss did not improve from 0.00044
#
# Epoch 126: val_loss did not improve from 0.00044
#
# Epoch 127: val_loss did not improve from 0.00044
#
# Epoch 128: val_loss did not improve from 0.00044
#
# Epoch 129: val_loss did not improve from 0.00044
#
# Epoch 130: val_loss did not improve from 0.00044
#
# Epoch 131: val_loss did not improve from 0.00044
#
# Epoch 132: val_loss did not improve from 0.00044
#
# Epoch 133: val_loss did not improve from 0.00044
#
# Epoch 134: val_loss did not improve from 0.00044
#
# Epoch 135: val_loss did not improve from 0.00044
#
# Epoch 136: val_loss did not improve from 0.00044
#
# Epoch 137: val_loss did not improve from 0.00044
#
# Epoch 138: val_loss did not improve from 0.00044
#
# Epoch 139: val_loss did not improve from 0.00044
#
# Epoch 140: val_loss did not improve from 0.00044
#
# Epoch 141: val_loss did not improve from 0.00044
#
# Epoch 142: val_loss did not improve from 0.00044
#
# Epoch 143: val_loss did not improve from 0.00044
#
# Epoch 144: val_loss did not improve from 0.00044
#
# Epoch 145: val_loss did not improve from 0.00044
#
# Epoch 146: val_loss did not improve from 0.00044
#
# Epoch 147: val_loss did not improve from 0.00044
#
# Epoch 148: val_loss did not improve from 0.00044
#
# Epoch 149: val_loss did not improve from 0.00044
#
# Epoch 150: val_loss did not improve from 0.00044
#
# Epoch 151: val_loss did not improve from 0.00044
#
# Epoch 152: val_loss did not improve from 0.00044
#
# Epoch 153: val_loss did not improve from 0.00044
#
# Epoch 154: val_loss did not improve from 0.00044
#
# Epoch 155: val_loss did not improve from 0.00044
#
# Epoch 156: val_loss did not improve from 0.00044
#
# Epoch 157: val_loss did not improve from 0.00044
#
# Epoch 158: val_loss did not improve from 0.00044
#
# Epoch 159: val_loss did not improve from 0.00044
#
# Epoch 160: val_loss did not improve from 0.00044
#
# Epoch 161: val_loss did not improve from 0.00044
#
# Epoch 162: val_loss did not improve from 0.00044
#
# Epoch 163: val_loss did not improve from 0.00044
#
# Epoch 164: val_loss did not improve from 0.00044
#
# Epoch 165: val_loss did not improve from 0.00044
#
# Epoch 166: val_loss did not improve from 0.00044
#
# Epoch 167: val_loss did not improve from 0.00044
#
# Epoch 168: val_loss did not improve from 0.00044
#
# Epoch 169: val_loss did not improve from 0.00044
#
# Epoch 170: val_loss did not improve from 0.00044
#
# Epoch 171: val_loss did not improve from 0.00044
#
# Epoch 172: val_loss did not improve from 0.00044
#
# Epoch 173: val_loss did not improve from 0.00044
#
# Epoch 174: val_loss did not improve from 0.00044
#
# Epoch 175: val_loss did not improve from 0.00044
#
# Epoch 176: val_loss did not improve from 0.00044
#
# Epoch 177: val_loss did not improve from 0.00044
#
# Epoch 178: val_loss did not improve from 0.00044
#
# Epoch 179: val_loss did not improve from 0.00044
#
# Epoch 180: val_loss did not improve from 0.00044
#
# Epoch 181: val_loss did not improve from 0.00044
#
# Epoch 182: val_loss did not improve from 0.00044
#
# Epoch 183: val_loss did not improve from 0.00044
#
# Epoch 184: val_loss did not improve from 0.00044
#
# Epoch 185: val_loss did not improve from 0.00044
#
# Epoch 186: val_loss did not improve from 0.00044
#
# Epoch 187: val_loss did not improve from 0.00044
#
# Epoch 188: val_loss did not improve from 0.00044
#
# Epoch 189: val_loss did not improve from 0.00044
#
# Epoch 190: val_loss did not improve from 0.00044
#
# Epoch 191: val_loss did not improve from 0.00044
#
# Epoch 192: val_loss did not improve from 0.00044
#
# Epoch 193: val_loss did not improve from 0.00044
#
# Epoch 194: val_loss did not improve from 0.00044
#
# Epoch 195: val_loss did not improve from 0.00044
#
# Epoch 196: val_loss did not improve from 0.00044
#
# Epoch 197: val_loss did not improve from 0.00044
#
# Epoch 198: val_loss did not improve from 0.00044
#
# Epoch 199: val_loss did not improve from 0.00044
#
# Epoch 200: val_loss did not improve from 0.00044
#
# Epoch 201: val_loss did not improve from 0.00044
#
# Epoch 202: val_loss did not improve from 0.00044
#
# Epoch 203: val_loss did not improve from 0.00044
#
# Epoch 204: val_loss did not improve from 0.00044
#
# Epoch 205: val_loss did not improve from 0.00044
#
# Epoch 206: val_loss did not improve from 0.00044
#
# Epoch 207: val_loss did not improve from 0.00044
#
# Epoch 208: val_loss did not improve from 0.00044
#
# Epoch 209: val_loss did not improve from 0.00044
#
# Epoch 210: val_loss did not improve from 0.00044
#
# Epoch 211: val_loss did not improve from 0.00044
#
# Epoch 212: val_loss did not improve from 0.00044
#
# Epoch 213: val_loss did not improve from 0.00044
#
# Epoch 214: val_loss did not improve from 0.00044
#
# Epoch 215: val_loss did not improve from 0.00044
#
# Epoch 216: val_loss did not improve from 0.00044
#
# Epoch 217: val_loss did not improve from 0.00044
#
# Epoch 218: val_loss did not improve from 0.00044
#
# Epoch 219: val_loss did not improve from 0.00044
#
# Epoch 220: val_loss did not improve from 0.00044
#
# Epoch 221: val_loss did not improve from 0.00044
#
# Epoch 222: val_loss did not improve from 0.00044
#
# Epoch 223: val_loss did not improve from 0.00044
#
# Epoch 224: val_loss did not improve from 0.00044
#
# Epoch 225: val_loss did not improve from 0.00044
#
# Epoch 226: val_loss did not improve from 0.00044
#
# Epoch 227: val_loss did not improve from 0.00044
#
# Epoch 228: val_loss did not improve from 0.00044
#
# Epoch 229: val_loss did not improve from 0.00044
#
# Epoch 230: val_loss did not improve from 0.00044
#
# Epoch 231: val_loss did not improve from 0.00044
#
# Epoch 232: val_loss did not improve from 0.00044
#
# Epoch 233: val_loss did not improve from 0.00044
#
# Epoch 234: val_loss did not improve from 0.00044
#
# Epoch 235: val_loss did not improve from 0.00044
#
# Epoch 236: val_loss did not improve from 0.00044
#
# Epoch 237: val_loss did not improve from 0.00044
#
# Epoch 238: val_loss did not improve from 0.00044
#
# Epoch 239: val_loss did not improve from 0.00044
#
# Epoch 240: val_loss did not improve from 0.00044
#
# Epoch 241: val_loss did not improve from 0.00044
#
# Epoch 242: val_loss did not improve from 0.00044
#
# Epoch 243: val_loss did not improve from 0.00044
#
# Epoch 244: val_loss did not improve from 0.00044
#
# Epoch 245: val_loss did not improve from 0.00044
#
# Epoch 246: val_loss did not improve from 0.00044
#
# Epoch 247: val_loss did not improve from 0.00044
#
# Epoch 248: val_loss did not improve from 0.00044
#
# Epoch 249: val_loss did not improve from 0.00044
#
# Epoch 250: val_loss did not improve from 0.00044

# %% [markdown]
# ### Bước 6: Đánh giá mô hình và trực quan hóa kết quả

# %% [markdown]
# #### 6.1. Vẽ biểu đồ train_loss và val_loss

# %%
plot_error(train_error, val_error)

# %% [markdown]
# #### 6.2. Đánh giá mô hình trên tập test

# %%
mse, rmse, mape, r2, true, predicted = evaluate_model_4(model, test, timesteps)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %%
print('MSE = {}'.format(mse))
print('RMSE = {}'.format(rmse))
print('MAPE = {}'.format(mape))
print('R-Squared Score = {}'.format(r2))
# Out:
# MSE = 0.0012526778868956426
# RMSE = 0.03539318983781545
# MAPE = 0.02665122978493778
# R-Squared Score = 0.907474135496579

# %% [markdown]
# #### 6.3. Vẽ đồ thị dự đoán vs thực tế

# %%
plot_data_4(true, predicted)

# %%
# Save a model
model.save('3VAR-VN30index-lstm.keras')

# %%
del model
