# %% [markdown]
# # Model 1: Multivariate-3-RNN

# %% [markdown]
# ## RNN

# %% [markdown]
# ### Import các thư viện cần thiết

# %%
import os
os.environ['PYTHONHASHSEED'] = '0' # đảm bảo rằng các giá trị băm của đối tượng bất biến (dict, set, chuỗi, tuple...) luôn giống nhau giữa các lần chạy

import random as rn
import numpy as np
np.random.seed(1)
rn.seed(3)
import tensorflow as tf
tf.random.set_seed(2)
# Out:
# 2025-05-29 05:50:47.080227: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748497847.107350   12257 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748497847.114282   12257 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout
from tensorflow.keras import optimizers

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from math import sqrt
import datetime as dt
import time

from tensorflow.keras.optimizers import Adam

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### Hàm callback

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')  
checkpoint = ModelCheckpoint(
    filepath="10Var-hpg-rnn.h5",   # Tên file lưu mô hình
    monitor="val_loss",         # Theo dõi val_loss
    save_best_only=True,        # Chỉ lưu khi tốt hơn mô hình trước đó
    mode="min",                 # Giảm min của val_loss là tốt nhất
    verbose=1
)
callbacks_list = [earlystop, checkpoint]

# %% [markdown]
# ### Đọc dữ liệu từ file csv

# %%
url = r"hpg_history.csv"
df = pd.read_csv(url, parse_dates= True, index_col= 0)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of              open   high    low  close    volume
# time
# 2007-11-16   2.29   2.29   2.29   2.29    248510
# 2007-11-19   2.17   2.17   2.17   2.17    120480
# 2007-11-20   2.08   2.08   2.08   2.08     58710
# 2007-11-21   1.99   2.16   1.99   2.16    728080
# 2007-11-22   2.16   2.16   2.08   2.16    266040
# ...           ...    ...    ...    ...       ...
# 2025-03-14  27.70  27.85  27.55  27.55  18279900
# 2025-03-17  27.90  28.15  27.75  27.85  19719700
# 2025-03-18  27.90  28.05  27.60  27.60  18741700
# 2025-03-19  27.60  27.60  27.10  27.25  37925600
# 2025-03-20  27.30  27.45  27.05  27.15  25022500
#
# [4322 rows x 5 columns]>

# %%
print(df.isnull().sum())
# Out:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %% [markdown]
# ### Tiền xử lí dữ liệu

# %%
# Xóa các dòng có giá trị Volume bằng 0
df.drop(df[df['volume']==0].index, inplace=True)

# %%
# Ma trận tương quan (ở đây là Pearson tương quan tuyến tính)
df.corr()['close']
# Out:
# open      0.999667
# high      0.999857
# low       0.999838
# close     1.000000
# volume    0.799299
# Name: close, dtype: float64

# %%
#  Tính toán các thống kê mô tả như trung bình (mean), độ lệch chuẩn (std), min, max, phần trăm phân vị (25%, 50%, 75%).
print(df.describe().volume) # Giúp kiểm tra phân bố của Volume, phát hiện các giá trị bất thường (outliers).
# Out:
# count    4.320000e+03
# mean     7.877410e+06
# std      1.133795e+07
# min      5.000000e+01
# 25%      4.646300e+05
# 50%      2.422785e+06
# 75%      1.233620e+07
# max      9.967998e+07
# Name: volume, dtype: float64

# %%
# Vẽ biểu đồ tần suất của Volume
df['volume'].hist(bins=10)
# Out:
# <Axes: >

# %% [markdown]
# **Phân tích phân bố dữ liệu Volume bằng Histogram**
#
# 🔹 `.hist(bins=10)`
# - Vẽ **biểu đồ histogram** của cột `Volume` với **10 bins (nhóm dữ liệu)**.
# - Giúp trực quan hóa **phân bố dữ liệu**, phát hiện sự **lệch** (skewness) và **giá trị ngoại lai** (outliers).
#
# **Ý nghĩa của biểu đồ histogram**
#
# - **Nếu phân bố lệch phải (right-skewed)** → Dữ liệu có nhiều giá trị nhỏ, một số giá trị rất lớn.
# - **Nếu phân bố lệch trái (left-skewed)** → Dữ liệu có nhiều giá trị lớn, một số giá trị rất nhỏ.
# - **Nếu có outliers (điểm nằm xa tập trung chính)** → Có thể cần xử lý như **loại bỏ** hoặc **chuẩn hóa dữ liệu**.
#
# **Cách xử lý dữ liệu lệch/skewed**
#
# ✅ **Log Transformation** → Dùng `np.log1p(Volume)` để giảm độ lệch.
# ✅ **Scaling** → Dùng `MinMaxScaler()` hoặc `StandardScaler()` để chuẩn hóa.
# ✅ **Xử lý outliers** → Loại bỏ hoặc thay thế bằng **giá trị trung bình/median**.

# %%
# Bổ sung các chỉ báo kĩ thuật

# Tính CMA10
df['CMA10'] = df['close'].rolling(window=10, center=True).mean()
# Tính SMA10
df['SMA10'] = df['close'].rolling(window=10).mean()
# Tính SMA50
df['SMA50'] = df['close'].rolling(window=50).mean()
# Tính EMA12 và EMA26
df['EMA12'] = df['close'].ewm(span=12, adjust=False).mean()
df['EMA26'] = df['close'].ewm(span=26, adjust=False).mean()
# Tính MACD
df['MACD'] = df['EMA12'] - df['EMA26']
#Tính RSI
# Tính giá tăng/giảm
delta = df['close'].diff()

# Tính giá tăng
gain = delta.where(delta > 0, 0)

# Tính giá giảm
loss = -delta.where(delta < 0, 0)

# Tính trung bình động
avg_gain = gain.rolling(window=14).mean()
avg_loss = loss.rolling(window=14).mean()

# Tính RS và RSI
rs = avg_gain / avg_loss
df['RSI'] = 100 - (100 / (1 + rs))

#Tính CCI
# Tính giá trung bình
typical_price = (df['high'] + df['low'] + df['close']) / 3

# Tính SMA của giá trung bình
sma_typical_price = typical_price.rolling(window=20).mean()

# Tính độ lệch chuẩn
mean_deviation = typical_price.rolling(window=20).apply(lambda x: np.mean(np.abs(x - x.mean())))

# Tính CCI
df['CCI'] = (typical_price - sma_typical_price) / (0.015 * mean_deviation)
# Tính %K và %D
low_min = df['low'].rolling(window=14).min()
high_max = df['high'].rolling(window=14).max()

df['%K'] = 100 * (df['close'] - low_min) / (high_max - low_min)
df['%D'] = df['%K'].rolling(window=3).mean()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py:73: RuntimeWarning: invalid value encountered in greater
#   return op(a, b)
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py:73: RuntimeWarning: invalid value encountered in less
#   return op(a, b)

# %%
print(df.head())
df.shape
# Out:
#             open  high   low  close  volume  CMA10  SMA10  SMA50     EMA12  \
# time
# 2007-11-16  2.29  2.29  2.29   2.29  248510    NaN    NaN    NaN  2.290000
# 2007-11-19  2.17  2.17  2.17   2.17  120480    NaN    NaN    NaN  2.271538
# 2007-11-20  2.08  2.08  2.08   2.08   58710    NaN    NaN    NaN  2.242071
# 2007-11-21  1.99  2.16  1.99   2.16  728080    NaN    NaN    NaN  2.229445
# 2007-11-22  2.16  2.16  2.08   2.16  266040    NaN    NaN    NaN  2.218761
#
#                EMA26      MACD  RSI  CCI  %K  %D
# time
# 2007-11-16  2.290000  0.000000  NaN  NaN NaN NaN
# 2007-11-19  2.281111 -0.009573  NaN  NaN NaN NaN
# 2007-11-20  2.266214 -0.024143  NaN  NaN NaN NaN
# 2007-11-21  2.258346 -0.028902  NaN  NaN NaN NaN
# 2007-11-22  2.251061 -0.032300  NaN  NaN NaN NaN
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# (4320, 15)

# %% [markdown]
# ## Train model / Hàm **fit_model_2()**

# %%
def fit_model_2(train, val, timesteps, hl, lr, batch, epochs):
    np.random.seed(1)
    tf.random.set_seed(2)
    rn.seed(3)

    X_train = []
    Y_train = []
    X_val = []
    Y_val = []

    # Loop for training data
    for i in range(timesteps, train.shape[0]):
        X_train.append(train[i-timesteps:i])
        Y_train.append(train[i][0])
    X_train, Y_train = np.array(X_train), np.array(Y_train)

    # Loop for val data
    for i in range(timesteps, val.shape[0]):
        X_val.append(val[i-timesteps:i])
        Y_val.append(val[i][0])
    X_val, Y_val = np.array(X_val), np.array(Y_val)

    # Adding Layers to the model
    model = Sequential()
    model.add(SimpleRNN(X_train.shape[2], input_shape = (X_train.shape[1], X_train.shape[2]), activation = 'relu', return_sequences = True))
    for i in range(len(hl)-1):
        model.add(SimpleRNN(hl[i], activation = 'relu', return_sequences = True))
    model.add(SimpleRNN(hl[-1], activation = 'relu'))
    model.add(Dense(1))
    model.compile(optimizer = optimizers.Adam(learning_rate= lr), loss = 'mean_squared_error')

    # Training the data
    history = model.fit(X_train, Y_train, epochs = epochs, batch_size = batch, validation_data = (X_val, Y_val), verbose = 0, shuffle = False, callbacks=callbacks_list)
    for layer in model.layers:
        if isinstance(layer, SimpleRNN):
            layer.reset_states() #Đảm bảo mỗi lần huấn luyện không bị ảnh hưởng bởi trạng thái cũ của LSTM.
    return model, history.history['loss'], history.history['val_loss']

# %% [markdown]
# ###  Bước 1: Đặt Seed để đảm bảo tính tái lập

# %% [markdown]
# Giúp đảm bảo mỗi lần chạy chương trình, các giá trị ngẫu nhiên được tạo ra giống nhau, tránh kết quả huấn luyện thay đổi giữa các lần chạy.

# %%
"""
np.random.seed(1)
tf.random.set_seed(2)
rn.seed(3)
"""
# Out:
# '\nnp.random.seed(1)\ntf.random.set_seed(2)\nrn.seed(3)\n'

# %% [markdown]
# ### Bước 2: Chuẩn bị dữ liệu huấn luyện (train) và kiểm định (val)

# %%
"""
X_train = []
Y_train = []
X_val = []
Y_val = []

for i in range(timesteps, train.shape[0]):
    X_train.append(train[i-timesteps:i])
    Y_train.append(train[i][0])
X_train, Y_train = np.array(X_train, Y_train)

for i in range(timesteps, val.shape[0]):
    X_val.append(val[i-timesteps:i])
    Y_val.append(val[i][0])
X_val, Y_val = np.array(X_val, Y_val)  
"""
# Out:
# '\nX_train = []\nY_train = []\nX_val = []\nY_val = []\n\nfor i in range(timesteps, train.shape[0]):\n    X_train.append(train[i-timesteps:i])\n    Y_train.append(train[i][0])\nX_train, Y_train = np.array(X_train, Y_train)\n\nfor i in range(timesteps, val.shape[0]):\n    X_val.append(val[i-timesteps:i])\n    Y_val.append(val[i][0])\nX_val, Y_val = np.array(X_val, Y_val)  \n'

# %% [markdown]
# ### Bước 3: Xây dựng mô hình RNN

# %%
"""
# Xây dựng mô hình RNN
model = Sequential()
model.add(SimpleRNN(X_train.shape[2], input_shape= (X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences= True))
for i in range(len(hl)-1):
    model.add(SimpleRNN(hl[i], activation='relu', return_sequences= True))
model.add(SimpleRNN(hl[-1], activation='relu'))
model.add(Dense(1))
"""
# Out:
# "\n# Xây dựng mô hình RNN\nmodel = Sequential()\nmodel.add(SimpleRNN(X_train.shape[2], input_shape= (X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences= True))\nfor i in range(len(hl)-1):\n    model.add(SimpleRNN(hl[i], activation='relu', return_sequences= True))\nmodel.add(SimpleRNN(hl[-1], activation='relu'))\nmodel.add(Dense(1))\n"

# %% [markdown]
# Thêm một lớp **SimpleRNN đầu tiên**:
# -   `X_train.shape[2]`: Số đặc trưng (features).
# -   `input_shape = (X_train.shape[1], X_train.shape[2])`: Định dạng đầu vào (timesteps, số đặc trưng).
# -   `activation = 'relu'`: Hàm kích hoạt giúp mô hình học phi tuyến tính.
# -   `return_sequences = True`: Giữ lại toàn bộ chuỗi đầu ra để sử dụng trong các lớp tiếp theo.

# %% [markdown]
# ### Bước 4: Biên dịch mô hình

# %%
"""
# Biên dịch
model.compile(optimizer= optimizers.Adam(learning_rate= lr), loss= 'mean_squared_error')
"""
# Out:
# "\n# Biên dịch\nmodel.compile(optimizer= optimizers.Adam(learning_rate= lr), loss= 'mean_squared_error')\n"

# %% [markdown]
# ### Bước 5: Huấn luyện mô hình

# %%
"""
history = model.fit(X_train, Y_train, epochs = epochs, batch_size = batch, validation_data = (X_val, Y_val), verbose = 0, shuffle = False, callbacks=callbacks_list)
"""
# Out:
# '\nhistory = model.fit(X_train, Y_train, epochs = epochs, batch_size = batch, validation_data = (X_val, Y_val), verbose = 0, shuffle = False, callbacks=callbacks_list)\n'

# %% [markdown]
# **Cấu hình huấn luyện mô hình**
#
# 🔹 Tham số trong quá trình huấn luyện
#
# ✅ `epochs = epochs` → Số vòng huấn luyện
# ✅ `batch_size = batch` → Kích thước batch
# ✅ `validation_data = (X_val, Y_val)` → Dữ liệu kiểm định để theo dõi hiệu suất sau mỗi epoch
# ✅ `verbose = 0` → Không hiển thị log huấn luyện (có thể đặt `verbose = 1` để xem tiến trình)
# ✅ `shuffle = False` → Không xáo trộn dữ liệu (do chuỗi thời gian có tính thứ tự)
# ✅ `callbacks = callbacks_list` → Danh sách callback hỗ trợ huấn luyện

# %% [markdown]
# ### Bước 6: Đảm bảo trạng thái không bị ảnh hưởng khi huấn luyện nhiều lần

# %%
"""
for layer in model.layers:
    if isinstance(layer, SimpleRNN):
        layer.reset_states()
"""
# Out:
# '\nfor layer in model.layers:\n    if isinstance(layer, SimpleRNN):\n        layer.reset_states()\n'

# %% [markdown]
# ### Bước 7: Trả về kết quả

# %%
"""
return model, history.history['train_loss'], history.history['val_loss']
"""
# Out:
# "\nreturn model, history.history['train_loss'], history.history['val_loss']\n"

# %% [markdown]
# ## **Grid Search**: Tìm kiếm siêu tham số tối ưu

# %%
param_grid = {
    'timesteps': [30, 40, 50],
    'hl': [[40, 35]],
    'lr': [1e-3, 1e-4],
    'batch_size': [32, 64],
    'num_epochs': [200, 250]
}

# %%
from itertools import product # Tích đề-các
import pandas as pd

# Hàm Grid Search
def grid_search_rnn(train, val, test, param_grid):
# Khởi tạo danh sách lưu kết quả
    results = []
    best_score = float('inf') # Ban đầu được đặt là vô cùng lớn
    best_params = None # Lưu bộ siêu tham số có hiệu suất tốt nhất
# Tạo tất cả các tổ hợp tham số
    all_combinations = list(product(*param_grid.values()))
    param_names = list(param_grid.keys())
# Lặp qua từng tổ hợp tham số
    for combination in all_combinations:
        params = dict(zip(param_names, combination))
        timesteps = params['timesteps']
        hl = params['hl']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']

    print(f'Training with param: {params}')
# Huấn luyện với fit.model()
    model, train_loss, val_loss = fit_model_2(train, val, timesteps, hl, lr,  batch_size, num_epochs)
# Đánh giá mô hình với evaluate_model()
    mse, rmse, mape, r2, _, _ = evaluate_model_2(model, test, timesteps)
# Lưu kết quả
    results.append({
        'timesteps': timesteps,
        'hl': hl,
        'lr': lr,
        'batch_size': batch_size,
        'num_epochs': num_epochs,
        'MSE': mse,
        'RMSE': rmse,
        'MAPE': mape,
        'R²': r2
    })
# Cập nhật bộ siêu tham số tốt nhất nếu RMSE cải thiện
    if rmse < best_score:
        best_score = rmse
        best_params = params

# Trả về kết quả
    results_df = pd.DataFrame(results)
    return best_params, best_score, results_df

# %% [markdown]
# ## Hàm **Evaluate_model_2()**

# %%
"""
# Định nghĩa hàm mean_absolute_percentage_error() (MAPE)
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true))*100"
    """
# Out:
# '\n# Định nghĩa hàm mean_absolute_percentage_error() (MAPE)\ndef mean_absolute_percentage_error(y_true, y_pred):\n    y_true, y_pred = np.array(y_true), np.array(y_pred)\n    return np.mean(np.abs((y_true - y_pred) / y_true))*100"\n    '

# %%
def evaluate_model_2(model, test, timesteps):
    np.random.seed(1)
    tf.random.set_seed(2)
    rn.seed(3)

    X_test = []
    Y_test = []

    # Loop for testing data
    for i in range(timesteps, test.shape[0]):
        X_test.append(test[i-timesteps:i])
        Y_test.append(test[i][0])
    X_test, Y_test = np.array(X_test), np.array(Y_test)

    # Evaluate model
    Y_hat = model.predict(X_test)                         #chứa dự đoán của model dựa trên đầu vào x_test
    mse = mean_squared_error(Y_test, Y_hat)
    rmse = sqrt(mse)
    mape = mean_absolute_percentage_error(Y_test, Y_hat)
    r2 = r2_score(Y_test, Y_hat)
    return mse, rmse, mape, r2, Y_test, Y_hat

# %% [markdown]
# ## Plot chart (vẽ biểu đồ)

# %%
# Plotting the predictions
def plot_data_2(Y_test,Y_hat):
    plt.plot(Y_test, c = 'r')
    plt.plot(Y_hat, c = 'y')
    plt.xlabel('Day')
    plt.ylabel('Price')
    plt.title("Stock Price Prediction using Multivatiate-RNN")
    plt.legend(['Actual','Predicted'], loc = 'lower right')
    plt.show()

# %%
# Plotting the training errors: trực quan loss qua các epoch -> thấy qtr học mô hình, xem có overfitting ko
def plot_error(train_loss, val_loss):
    plt.plot(train_loss, c = 'r')
    plt.plot(val_loss, c = 'b')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.title('Train Loss and Validation Loss Curve')
    plt.legend(['train', 'val'], loc = 'upper right')
    plt.show()

# %% [markdown]
# ## **Model building**: Xây dựng mô hình

# %% [markdown]
# ### Bước 1: Trích xuất và trực quan hóa dữ liệu

# %%
# Extracting the series
series = df[['close', 'high', 'low', 'CMA10', 'SMA10', 'SMA50', 'EMA12', 'RSI', 'CCI', '%K', '%D', 'MACD']]
# Drop rows with NaN values
series = series.dropna()

# Display the shape and the tail of the cleaned series
print(series.shape)
print(series.tail())
# Out:
# (4267, 12)
#             close   high    low   CMA10   SMA10   SMA50      EMA12        RSI  \
# time
# 2025-03-10  27.95  28.20  27.95  27.860  27.910  26.726  27.664525  66.666667
# 2025-03-11  28.15  28.15  27.60  27.840  27.975  26.749  27.739213  68.965517
# 2025-03-12  27.80  28.20  27.80  27.815  27.980  26.771  27.748565  63.440860
# 2025-03-13  27.70  28.05  27.70  27.785  27.905  26.782  27.741094  63.440860
# 2025-03-14  27.55  27.85  27.55  27.705  27.860  26.793  27.711695  47.887324
#
#                   CCI         %K         %D      MACD
# time
# 2025-03-10  72.152412  75.609756  78.723924  0.419877
# 2025-03-11  61.493516  85.365854  80.790320  0.427503
# 2025-03-12  54.366686  68.292683  76.422764  0.400685
# 2025-03-13  39.488661  40.000000  64.552846  0.367130
# 2025-03-14  16.260163  28.000000  45.430894  0.324692

# %%
series.describe()
# Out:
#              close         high          low        CMA10       SMA10  \
# count  4267.000000  4267.000000  4267.000000  4267.000000  4267.00000
# mean     10.025397    10.160349     9.903063    10.022310     9.99800
# std      10.126221    10.264080    10.012208    10.118056    10.10649
# min       0.680000     0.690000     0.680000     0.710000     0.71000
# 25%       1.780000     1.800000     1.760000     1.778000     1.77800
# 50%       5.680000     5.780000     5.610000     5.725000     5.70500
# 75%      15.415000    15.655000    15.275000    15.376000    15.21950
# max      39.900000    40.180000    39.560000    39.285000    39.28500
#
#              SMA50        EMA12          RSI          CCI           %K  \
# count  4267.000000  4267.000000  4267.000000  4267.000000  4267.000000
# mean      9.880565     9.992086    52.254060    12.008518    53.007353
# std      10.019039    10.097556    17.992688   112.438235    30.851704
# min       0.793800     0.726093     0.000000  -486.486486     0.000000
# 25%       1.760400     1.776499    38.724730   -76.041990    25.730277
# 50%       5.174200     5.719069    52.577320    21.806854    55.445545
# 75%      15.065600    15.178271    66.146301   101.156626    80.702355
# max      37.489200    39.090578   100.000000   364.285714   100.000000
#
#                 %D         MACD
# count  4267.000000  4267.000000
# mean     53.000609     0.041366
# std      29.031483     0.373255
# min       0.000000    -1.739242
# 25%      26.681097    -0.045488
# 50%      55.238095     0.020672
# 75%      79.987975     0.119916
# max     100.000000     2.247325

# %% [markdown]
# ### Bước 2: Chia dữ liệu thành các tập Train, Validation, Test

# %%
series.shape
# Out:
# (4267, 12)

# %%
n = series.shape[0]
val_size =  test_size = int(n * 0.15)
train_size = n - val_size - test_size # Để tránh sai số làm mất dữ liệu

# Chia tập dữ liệu theo thứ tự thời gian
train_data = series.iloc[:train_size].values
val_data = series.iloc[train_size:train_size + val_size].values
test_data = series.iloc[(train_size + val_size):].values
# Kiểm tra kích thước của từng tập
print(train_data.shape, val_data.shape, test_data.shape)
# Out:
# (2987, 12) (640, 12) (640, 12)

# %% [markdown]
# ### Bước 3: Chuẩn hóa dữ liệu bằng MinMaxScaler

# %%
# Normalisation
np.random.seed(1)
tf.random.set_seed(2)
rn.seed(3)

# Chuẩn hóa
sc = MinMaxScaler() # Tạo bộ chuẩn hóa MinMaxScaler
train = sc.fit_transform(train_data)
val = sc.transform(val_data)
test = sc.transform(test_data)

print(train.shape, val.shape, test.shape)
# Out:
# (2987, 12) (640, 12) (640, 12)

# %% [markdown]
# ### Bước 4: Tìm siêu tham số tốt nhất bằng Grid Search

# %%
best_params, best_score, results_df = grid_search_rnn(train, val, test, param_grid)

print(results_df)
print("Best parameters:", best_params)
print("Best RMSE score:", best_score)
# Out:
# Training with param: {'timesteps': 50, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 64, 'num_epochs': 250}
# I0000 00:00:1748497852.244358   12257 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1748497852.244998   12257 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748497857.291931   12309 service.cc:148] XLA service 0x793b500b9cc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748497857.291962   12309 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748497857.291969   12309 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748497857.631916   12309 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1748497859.010795   12309 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 1.03951, saving model to 10Var-hpg-rnn.h5
#
# Epoch 2: val_loss improved from 1.03951 to 0.50758, saving model to 10Var-hpg-rnn.h5
#
# Epoch 3: val_loss improved from 0.50758 to 0.24866, saving model to 10Var-hpg-rnn.h5
#
# Epoch 4: val_loss improved from 0.24866 to 0.12737, saving model to 10Var-hpg-rnn.h5
#
# Epoch 5: val_loss improved from 0.12737 to 0.07982, saving model to 10Var-hpg-rnn.h5
#
# Epoch 6: val_loss improved from 0.07982 to 0.05849, saving model to 10Var-hpg-rnn.h5
#
# Epoch 7: val_loss improved from 0.05849 to 0.04698, saving model to 10Var-hpg-rnn.h5
#
# Epoch 8: val_loss improved from 0.04698 to 0.04039, saving model to 10Var-hpg-rnn.h5
#
# Epoch 9: val_loss improved from 0.04039 to 0.03633, saving model to 10Var-hpg-rnn.h5
#
# Epoch 10: val_loss improved from 0.03633 to 0.03264, saving model to 10Var-hpg-rnn.h5
#
# Epoch 11: val_loss improved from 0.03264 to 0.02947, saving model to 10Var-hpg-rnn.h5
#
# Epoch 12: val_loss improved from 0.02947 to 0.02673, saving model to 10Var-hpg-rnn.h5
#
# Epoch 13: val_loss improved from 0.02673 to 0.02465, saving model to 10Var-hpg-rnn.h5
#
# Epoch 14: val_loss improved from 0.02465 to 0.02284, saving model to 10Var-hpg-rnn.h5
#
# Epoch 15: val_loss improved from 0.02284 to 0.02111, saving model to 10Var-hpg-rnn.h5
#
# Epoch 16: val_loss improved from 0.02111 to 0.01963, saving model to 10Var-hpg-rnn.h5
#
# Epoch 17: val_loss improved from 0.01963 to 0.01862, saving model to 10Var-hpg-rnn.h5
#
# Epoch 18: val_loss improved from 0.01862 to 0.01800, saving model to 10Var-hpg-rnn.h5
#
# Epoch 19: val_loss improved from 0.01800 to 0.01693, saving model to 10Var-hpg-rnn.h5
#
# Epoch 20: val_loss improved from 0.01693 to 0.01642, saving model to 10Var-hpg-rnn.h5
#
# Epoch 21: val_loss improved from 0.01642 to 0.01575, saving model to 10Var-hpg-rnn.h5
#
# Epoch 22: val_loss improved from 0.01575 to 0.01513, saving model to 10Var-hpg-rnn.h5
#
# Epoch 23: val_loss improved from 0.01513 to 0.01479, saving model to 10Var-hpg-rnn.h5
#
# Epoch 24: val_loss improved from 0.01479 to 0.01428, saving model to 10Var-hpg-rnn.h5
#
# Epoch 25: val_loss improved from 0.01428 to 0.01361, saving model to 10Var-hpg-rnn.h5
#
# Epoch 26: val_loss improved from 0.01361 to 0.01312, saving model to 10Var-hpg-rnn.h5
#
# Epoch 27: val_loss improved from 0.01312 to 0.01229, saving model to 10Var-hpg-rnn.h5
#
# Epoch 28: val_loss improved from 0.01229 to 0.01166, saving model to 10Var-hpg-rnn.h5
#
# Epoch 29: val_loss improved from 0.01166 to 0.01090, saving model to 10Var-hpg-rnn.h5
#
# Epoch 30: val_loss improved from 0.01090 to 0.01042, saving model to 10Var-hpg-rnn.h5
#
# Epoch 31: val_loss improved from 0.01042 to 0.00980, saving model to 10Var-hpg-rnn.h5
#
# Epoch 32: val_loss improved from 0.00980 to 0.00944, saving model to 10Var-hpg-rnn.h5
#
# Epoch 33: val_loss improved from 0.00944 to 0.00909, saving model to 10Var-hpg-rnn.h5
#
# Epoch 34: val_loss improved from 0.00909 to 0.00880, saving model to 10Var-hpg-rnn.h5
#
# Epoch 35: val_loss improved from 0.00880 to 0.00849, saving model to 10Var-hpg-rnn.h5
#
# Epoch 36: val_loss improved from 0.00849 to 0.00824, saving model to 10Var-hpg-rnn.h5
#
# Epoch 37: val_loss improved from 0.00824 to 0.00804, saving model to 10Var-hpg-rnn.h5
#
# Epoch 38: val_loss improved from 0.00804 to 0.00786, saving model to 10Var-hpg-rnn.h5
#
# Epoch 39: val_loss improved from 0.00786 to 0.00759, saving model to 10Var-hpg-rnn.h5
#
# Epoch 40: val_loss improved from 0.00759 to 0.00740, saving model to 10Var-hpg-rnn.h5
#
# Epoch 41: val_loss improved from 0.00740 to 0.00720, saving model to 10Var-hpg-rnn.h5
#
# Epoch 42: val_loss improved from 0.00720 to 0.00706, saving model to 10Var-hpg-rnn.h5
#
# Epoch 43: val_loss improved from 0.00706 to 0.00692, saving model to 10Var-hpg-rnn.h5
#
# Epoch 44: val_loss improved from 0.00692 to 0.00686, saving model to 10Var-hpg-rnn.h5
#
# Epoch 45: val_loss improved from 0.00686 to 0.00678, saving model to 10Var-hpg-rnn.h5
#
# Epoch 46: val_loss improved from 0.00678 to 0.00671, saving model to 10Var-hpg-rnn.h5
#
# Epoch 47: val_loss improved from 0.00671 to 0.00659, saving model to 10Var-hpg-rnn.h5
#
# Epoch 48: val_loss improved from 0.00659 to 0.00652, saving model to 10Var-hpg-rnn.h5
#
# Epoch 49: val_loss improved from 0.00652 to 0.00640, saving model to 10Var-hpg-rnn.h5
#
# Epoch 50: val_loss improved from 0.00640 to 0.00624, saving model to 10Var-hpg-rnn.h5
#
# Epoch 51: val_loss improved from 0.00624 to 0.00609, saving model to 10Var-hpg-rnn.h5
#
# Epoch 52: val_loss improved from 0.00609 to 0.00592, saving model to 10Var-hpg-rnn.h5
#
# Epoch 53: val_loss improved from 0.00592 to 0.00577, saving model to 10Var-hpg-rnn.h5
#
# Epoch 54: val_loss improved from 0.00577 to 0.00565, saving model to 10Var-hpg-rnn.h5
#
# Epoch 55: val_loss improved from 0.00565 to 0.00554, saving model to 10Var-hpg-rnn.h5
#
# Epoch 56: val_loss improved from 0.00554 to 0.00546, saving model to 10Var-hpg-rnn.h5
#
# Epoch 57: val_loss improved from 0.00546 to 0.00539, saving model to 10Var-hpg-rnn.h5
#
# Epoch 58: val_loss improved from 0.00539 to 0.00535, saving model to 10Var-hpg-rnn.h5
#
# Epoch 59: val_loss improved from 0.00535 to 0.00531, saving model to 10Var-hpg-rnn.h5
#
# Epoch 60: val_loss improved from 0.00531 to 0.00525, saving model to 10Var-hpg-rnn.h5
#
# Epoch 61: val_loss improved from 0.00525 to 0.00521, saving model to 10Var-hpg-rnn.h5
#
# Epoch 62: val_loss improved from 0.00521 to 0.00518, saving model to 10Var-hpg-rnn.h5
#
# Epoch 63: val_loss improved from 0.00518 to 0.00513, saving model to 10Var-hpg-rnn.h5
#
# Epoch 64: val_loss improved from 0.00513 to 0.00511, saving model to 10Var-hpg-rnn.h5
#
# Epoch 65: val_loss improved from 0.00511 to 0.00508, saving model to 10Var-hpg-rnn.h5
#
# Epoch 66: val_loss improved from 0.00508 to 0.00505, saving model to 10Var-hpg-rnn.h5
#
# Epoch 67: val_loss improved from 0.00505 to 0.00504, saving model to 10Var-hpg-rnn.h5
#
# Epoch 68: val_loss improved from 0.00504 to 0.00501, saving model to 10Var-hpg-rnn.h5
#
# Epoch 69: val_loss improved from 0.00501 to 0.00500, saving model to 10Var-hpg-rnn.h5
#
# Epoch 70: val_loss improved from 0.00500 to 0.00498, saving model to 10Var-hpg-rnn.h5
#
# Epoch 71: val_loss improved from 0.00498 to 0.00497, saving model to 10Var-hpg-rnn.h5
#
# Epoch 72: val_loss improved from 0.00497 to 0.00496, saving model to 10Var-hpg-rnn.h5
#
# Epoch 73: val_loss did not improve from 0.00496
#
# Epoch 74: val_loss did not improve from 0.00496
#
# Epoch 75: val_loss did not improve from 0.00496
#
# Epoch 76: val_loss did not improve from 0.00496
#
# Epoch 77: val_loss did not improve from 0.00496
#
# Epoch 78: val_loss did not improve from 0.00496
#
# Epoch 79: val_loss did not improve from 0.00496
#
# Epoch 80: val_loss did not improve from 0.00496
#
# Epoch 81: val_loss did not improve from 0.00496
#
# Epoch 82: val_loss did not improve from 0.00496
#
# Epoch 83: val_loss did not improve from 0.00496
#
# Epoch 84: val_loss did not improve from 0.00496
#
# Epoch 85: val_loss did not improve from 0.00496
#
# Epoch 86: val_loss did not improve from 0.00496
#
# Epoch 87: val_loss did not improve from 0.00496
#
# Epoch 88: val_loss did not improve from 0.00496
#
# Epoch 89: val_loss did not improve from 0.00496
#
# Epoch 90: val_loss did not improve from 0.00496
#
# Epoch 91: val_loss did not improve from 0.00496
#
# Epoch 92: val_loss did not improve from 0.00496
#
# Epoch 93: val_loss did not improve from 0.00496
#
# Epoch 94: val_loss did not improve from 0.00496
#
# Epoch 95: val_loss did not improve from 0.00496
#
# Epoch 96: val_loss did not improve from 0.00496
#
# Epoch 97: val_loss did not improve from 0.00496
#
# Epoch 98: val_loss did not improve from 0.00496
#
# Epoch 99: val_loss did not improve from 0.00496
#
# Epoch 100: val_loss did not improve from 0.00496
#
# Epoch 101: val_loss did not improve from 0.00496
#
# Epoch 102: val_loss did not improve from 0.00496
#
# Epoch 103: val_loss did not improve from 0.00496
#
# Epoch 104: val_loss did not improve from 0.00496
#
# Epoch 105: val_loss did not improve from 0.00496
#
# Epoch 106: val_loss did not improve from 0.00496
#
# Epoch 107: val_loss did not improve from 0.00496
#
# Epoch 108: val_loss did not improve from 0.00496
#
# Epoch 109: val_loss did not improve from 0.00496
#
# Epoch 110: val_loss did not improve from 0.00496
#
# Epoch 111: val_loss did not improve from 0.00496
#
# Epoch 112: val_loss did not improve from 0.00496
#
# Epoch 113: val_loss did not improve from 0.00496
#
# Epoch 114: val_loss improved from 0.00496 to 0.00475, saving model to 10Var-hpg-rnn.h5
#
# Epoch 115: val_loss improved from 0.00475 to 0.00473, saving model to 10Var-hpg-rnn.h5
#
# Epoch 116: val_loss did not improve from 0.00473
#
# Epoch 117: val_loss did not improve from 0.00473
#
# Epoch 118: val_loss did not improve from 0.00473
#
# Epoch 119: val_loss did not improve from 0.00473
#
# Epoch 120: val_loss improved from 0.00473 to 0.00445, saving model to 10Var-hpg-rnn.h5
#
# Epoch 121: val_loss improved from 0.00445 to 0.00419, saving model to 10Var-hpg-rnn.h5
#
# Epoch 122: val_loss did not improve from 0.00419
#
# Epoch 123: val_loss did not improve from 0.00419
#
# Epoch 124: val_loss did not improve from 0.00419
#
# Epoch 125: val_loss did not improve from 0.00419
#
# Epoch 126: val_loss did not improve from 0.00419
#
# Epoch 127: val_loss did not improve from 0.00419
#
# Epoch 128: val_loss did not improve from 0.00419
#
# Epoch 129: val_loss did not improve from 0.00419
#
# Epoch 130: val_loss did not improve from 0.00419
#
# Epoch 131: val_loss did not improve from 0.00419
#
# Epoch 132: val_loss did not improve from 0.00419
#
# Epoch 133: val_loss did not improve from 0.00419
#
# Epoch 134: val_loss did not improve from 0.00419
#
# Epoch 135: val_loss did not improve from 0.00419
#
# Epoch 136: val_loss did not improve from 0.00419
#
# Epoch 137: val_loss did not improve from 0.00419
#
# Epoch 138: val_loss did not improve from 0.00419
#
# Epoch 139: val_loss did not improve from 0.00419
#
# Epoch 140: val_loss did not improve from 0.00419
#
# Epoch 141: val_loss did not improve from 0.00419
#
# Epoch 142: val_loss did not improve from 0.00419
#
# Epoch 143: val_loss did not improve from 0.00419
#
# Epoch 144: val_loss did not improve from 0.00419
#
# Epoch 145: val_loss did not improve from 0.00419
#
# Epoch 146: val_loss did not improve from 0.00419
#
# Epoch 147: val_loss did not improve from 0.00419
#
# Epoch 148: val_loss did not improve from 0.00419
#
# Epoch 149: val_loss did not improve from 0.00419
#
# Epoch 150: val_loss did not improve from 0.00419
#
# Epoch 151: val_loss did not improve from 0.00419
#
# Epoch 152: val_loss did not improve from 0.00419
#
# Epoch 153: val_loss did not improve from 0.00419
#
# Epoch 154: val_loss did not improve from 0.00419
#
# Epoch 155: val_loss did not improve from 0.00419
#
# Epoch 156: val_loss did not improve from 0.00419
#
# Epoch 157: val_loss did not improve from 0.00419
#
# Epoch 158: val_loss did not improve from 0.00419
#
# Epoch 159: val_loss did not improve from 0.00419
#
# Epoch 160: val_loss did not improve from 0.00419
#
# Epoch 161: val_loss did not improve from 0.00419
#
# Epoch 162: val_loss did not improve from 0.00419
#
# Epoch 163: val_loss did not improve from 0.00419
#
# Epoch 164: val_loss did not improve from 0.00419
#
# Epoch 165: val_loss did not improve from 0.00419
#
# Epoch 166: val_loss did not improve from 0.00419
#
# Epoch 167: val_loss did not improve from 0.00419
#
# Epoch 168: val_loss did not improve from 0.00419
#
# Epoch 169: val_loss did not improve from 0.00419
#
# Epoch 170: val_loss did not improve from 0.00419
#
# Epoch 171: val_loss did not improve from 0.00419
#
# Epoch 172: val_loss did not improve from 0.00419
#
# Epoch 173: val_loss did not improve from 0.00419
#
# Epoch 174: val_loss did not improve from 0.00419
#
# Epoch 175: val_loss did not improve from 0.00419
#
# Epoch 176: val_loss did not improve from 0.00419
#
# Epoch 177: val_loss did not improve from 0.00419
#
# Epoch 178: val_loss did not improve from 0.00419
#
# Epoch 179: val_loss did not improve from 0.00419
#
# Epoch 180: val_loss did not improve from 0.00419
#
# Epoch 181: val_loss did not improve from 0.00419
#
# Epoch 182: val_loss did not improve from 0.00419
#
# Epoch 183: val_loss did not improve from 0.00419
#
# Epoch 184: val_loss did not improve from 0.00419
#
# Epoch 185: val_loss did not improve from 0.00419
#
# Epoch 186: val_loss did not improve from 0.00419
#
# Epoch 187: val_loss did not improve from 0.00419
#
# Epoch 188: val_loss did not improve from 0.00419
#
# Epoch 189: val_loss did not improve from 0.00419
#
# Epoch 190: val_loss did not improve from 0.00419
#
# Epoch 191: val_loss did not improve from 0.00419
#
# Epoch 192: val_loss did not improve from 0.00419
#
# Epoch 193: val_loss did not improve from 0.00419
#
# Epoch 194: val_loss improved from 0.00419 to 0.00414, saving model to 10Var-hpg-rnn.h5
#
# Epoch 195: val_loss improved from 0.00414 to 0.00409, saving model to 10Var-hpg-rnn.h5
#
# Epoch 196: val_loss did not improve from 0.00409
#
# Epoch 197: val_loss did not improve from 0.00409
#
# Epoch 198: val_loss did not improve from 0.00409
#
# Epoch 199: val_loss did not improve from 0.00409
#
# Epoch 200: val_loss did not improve from 0.00409
#
# Epoch 201: val_loss improved from 0.00409 to 0.00355, saving model to 10Var-hpg-rnn.h5
#
# Epoch 202: val_loss did not improve from 0.00355
#
# Epoch 203: val_loss did not improve from 0.00355
#
# Epoch 204: val_loss did not improve from 0.00355
#
# Epoch 205: val_loss did not improve from 0.00355
#
# Epoch 206: val_loss did not improve from 0.00355
#
# Epoch 207: val_loss did not improve from 0.00355
#
# Epoch 208: val_loss did not improve from 0.00355
#
# Epoch 209: val_loss did not improve from 0.00355
#
# Epoch 210: val_loss did not improve from 0.00355
#
# Epoch 211: val_loss did not improve from 0.00355
#
# Epoch 212: val_loss did not improve from 0.00355
#
# Epoch 213: val_loss did not improve from 0.00355
#
# Epoch 214: val_loss did not improve from 0.00355
#
# Epoch 215: val_loss did not improve from 0.00355
#
# Epoch 216: val_loss did not improve from 0.00355
#
# Epoch 217: val_loss did not improve from 0.00355
#
# Epoch 218: val_loss did not improve from 0.00355
#
# Epoch 219: val_loss did not improve from 0.00355
#
# Epoch 220: val_loss did not improve from 0.00355
#
# Epoch 221: val_loss did not improve from 0.00355
#
# Epoch 222: val_loss did not improve from 0.00355
#
# Epoch 223: val_loss did not improve from 0.00355
#
# Epoch 224: val_loss did not improve from 0.00355
#
# Epoch 225: val_loss did not improve from 0.00355
#
# Epoch 226: val_loss did not improve from 0.00355
#
# Epoch 227: val_loss did not improve from 0.00355
#
# Epoch 228: val_loss did not improve from 0.00355
#
# Epoch 229: val_loss did not improve from 0.00355
#
# Epoch 230: val_loss did not improve from 0.00355
#
# Epoch 231: val_loss did not improve from 0.00355
#
# Epoch 232: val_loss did not improve from 0.00355
#
# Epoch 233: val_loss did not improve from 0.00355
#
# Epoch 234: val_loss did not improve from 0.00355
#
# Epoch 235: val_loss did not improve from 0.00355
#
# Epoch 236: val_loss did not improve from 0.00355
#
# Epoch 237: val_loss did not improve from 0.00355
#
# Epoch 238: val_loss did not improve from 0.00355
#
# Epoch 239: val_loss did not improve from 0.00355
#
# Epoch 240: val_loss did not improve from 0.00355
#
# Epoch 241: val_loss did not improve from 0.00355
#
# Epoch 242: val_loss did not improve from 0.00355
#
# Epoch 243: val_loss did not improve from 0.00355
#
# Epoch 244: val_loss did not improve from 0.00355
#
# Epoch 245: val_loss did not improve from 0.00355
#
# Epoch 246: val_loss did not improve from 0.00355
#
# Epoch 247: val_loss did not improve from 0.00355
#
# Epoch 248: val_loss did not improve from 0.00355
#
# Epoch 249: val_loss did not improve from 0.00355
#
# Epoch 250: val_loss did not improve from 0.00355
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step
#    timesteps        hl      lr  batch_size  num_epochs       MSE     RMSE  \
# 0         50  [40, 35]  0.0001          64         250  0.003223  0.05677
#
#      MAPE        R²
# 0  0.0302  0.957956
# Best parameters: {'timesteps': 50, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 64, 'num_epochs': 250}
# Best RMSE score: 0.05676976868534391

# %% [markdown]
# ### Bước 5: Huấn luyện mô hình với bộ tham số tối ưu

# %%
timesteps = 50
hl = [40, 35]
lr = 0.0001
batch_size = 64
num_epochs = 250

model, train_error, val_error = fit_model_2(train, val, timesteps, hl, lr, batch_size, num_epochs)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00355
#
# Epoch 2: val_loss did not improve from 0.00355
#
# Epoch 3: val_loss did not improve from 0.00355
#
# Epoch 4: val_loss did not improve from 0.00355
#
# Epoch 5: val_loss did not improve from 0.00355
#
# Epoch 6: val_loss did not improve from 0.00355
#
# Epoch 7: val_loss did not improve from 0.00355
#
# Epoch 8: val_loss did not improve from 0.00355
#
# Epoch 9: val_loss did not improve from 0.00355
#
# Epoch 10: val_loss did not improve from 0.00355
#
# Epoch 11: val_loss did not improve from 0.00355
#
# Epoch 12: val_loss did not improve from 0.00355
#
# Epoch 13: val_loss did not improve from 0.00355
#
# Epoch 14: val_loss did not improve from 0.00355
#
# Epoch 15: val_loss did not improve from 0.00355
#
# Epoch 16: val_loss did not improve from 0.00355
#
# Epoch 17: val_loss did not improve from 0.00355
#
# Epoch 18: val_loss did not improve from 0.00355
#
# Epoch 19: val_loss did not improve from 0.00355
#
# Epoch 20: val_loss did not improve from 0.00355
#
# Epoch 21: val_loss did not improve from 0.00355
#
# Epoch 22: val_loss did not improve from 0.00355
#
# Epoch 23: val_loss did not improve from 0.00355
#
# Epoch 24: val_loss did not improve from 0.00355
#
# Epoch 25: val_loss did not improve from 0.00355
#
# Epoch 26: val_loss did not improve from 0.00355
#
# Epoch 27: val_loss did not improve from 0.00355
#
# Epoch 28: val_loss did not improve from 0.00355
#
# Epoch 29: val_loss did not improve from 0.00355
#
# Epoch 30: val_loss did not improve from 0.00355
#
# Epoch 31: val_loss did not improve from 0.00355
#
# Epoch 32: val_loss did not improve from 0.00355
#
# Epoch 33: val_loss did not improve from 0.00355
#
# Epoch 34: val_loss did not improve from 0.00355
#
# Epoch 35: val_loss did not improve from 0.00355
#
# Epoch 36: val_loss did not improve from 0.00355
#
# Epoch 37: val_loss did not improve from 0.00355
#
# Epoch 38: val_loss did not improve from 0.00355
#
# Epoch 39: val_loss did not improve from 0.00355
#
# Epoch 40: val_loss did not improve from 0.00355
#
# Epoch 41: val_loss did not improve from 0.00355
#
# Epoch 42: val_loss did not improve from 0.00355
#
# Epoch 43: val_loss did not improve from 0.00355
#
# Epoch 44: val_loss did not improve from 0.00355
#
# Epoch 45: val_loss did not improve from 0.00355
#
# Epoch 46: val_loss did not improve from 0.00355
#
# Epoch 47: val_loss did not improve from 0.00355
#
# Epoch 48: val_loss did not improve from 0.00355
#
# Epoch 49: val_loss did not improve from 0.00355
#
# Epoch 50: val_loss did not improve from 0.00355
#
# Epoch 51: val_loss did not improve from 0.00355
#
# Epoch 52: val_loss did not improve from 0.00355
#
# Epoch 53: val_loss did not improve from 0.00355
#
# Epoch 54: val_loss did not improve from 0.00355
#
# Epoch 55: val_loss did not improve from 0.00355
#
# Epoch 56: val_loss did not improve from 0.00355
#
# Epoch 57: val_loss did not improve from 0.00355
#
# Epoch 58: val_loss did not improve from 0.00355
#
# Epoch 59: val_loss did not improve from 0.00355
#
# Epoch 60: val_loss did not improve from 0.00355
#
# Epoch 61: val_loss did not improve from 0.00355
#
# Epoch 62: val_loss did not improve from 0.00355
#
# Epoch 63: val_loss did not improve from 0.00355
#
# Epoch 64: val_loss did not improve from 0.00355
#
# Epoch 65: val_loss did not improve from 0.00355
#
# Epoch 66: val_loss did not improve from 0.00355
#
# Epoch 67: val_loss did not improve from 0.00355
#
# Epoch 68: val_loss did not improve from 0.00355
#
# Epoch 69: val_loss did not improve from 0.00355
#
# Epoch 70: val_loss did not improve from 0.00355
#
# Epoch 71: val_loss did not improve from 0.00355
#
# Epoch 72: val_loss did not improve from 0.00355
#
# Epoch 73: val_loss did not improve from 0.00355
#
# Epoch 74: val_loss did not improve from 0.00355
#
# Epoch 75: val_loss did not improve from 0.00355
#
# Epoch 76: val_loss did not improve from 0.00355
#
# Epoch 77: val_loss did not improve from 0.00355
#
# Epoch 78: val_loss did not improve from 0.00355
#
# Epoch 79: val_loss did not improve from 0.00355
#
# Epoch 80: val_loss did not improve from 0.00355
#
# Epoch 81: val_loss did not improve from 0.00355
#
# Epoch 82: val_loss did not improve from 0.00355
#
# Epoch 83: val_loss did not improve from 0.00355
#
# Epoch 84: val_loss did not improve from 0.00355
#
# Epoch 85: val_loss did not improve from 0.00355
#
# Epoch 86: val_loss did not improve from 0.00355
#
# Epoch 87: val_loss did not improve from 0.00355
#
# Epoch 88: val_loss did not improve from 0.00355
#
# Epoch 89: val_loss did not improve from 0.00355
#
# Epoch 90: val_loss did not improve from 0.00355
#
# Epoch 91: val_loss did not improve from 0.00355
#
# Epoch 92: val_loss did not improve from 0.00355
#
# Epoch 93: val_loss did not improve from 0.00355
#
# Epoch 94: val_loss did not improve from 0.00355
#
# Epoch 95: val_loss did not improve from 0.00355
#
# Epoch 96: val_loss did not improve from 0.00355
#
# Epoch 97: val_loss did not improve from 0.00355
#
# Epoch 98: val_loss did not improve from 0.00355
#
# Epoch 99: val_loss did not improve from 0.00355
#
# Epoch 100: val_loss did not improve from 0.00355
#
# Epoch 101: val_loss did not improve from 0.00355
#
# Epoch 102: val_loss did not improve from 0.00355
#
# Epoch 103: val_loss did not improve from 0.00355
#
# Epoch 104: val_loss did not improve from 0.00355
#
# Epoch 105: val_loss did not improve from 0.00355
#
# Epoch 106: val_loss did not improve from 0.00355
#
# Epoch 107: val_loss did not improve from 0.00355
#
# Epoch 108: val_loss did not improve from 0.00355
#
# Epoch 109: val_loss did not improve from 0.00355
#
# Epoch 110: val_loss did not improve from 0.00355
#
# Epoch 111: val_loss did not improve from 0.00355
#
# Epoch 112: val_loss did not improve from 0.00355
#
# Epoch 113: val_loss did not improve from 0.00355
#
# Epoch 114: val_loss did not improve from 0.00355
#
# Epoch 115: val_loss did not improve from 0.00355
#
# Epoch 116: val_loss did not improve from 0.00355
#
# Epoch 117: val_loss did not improve from 0.00355
#
# Epoch 118: val_loss did not improve from 0.00355
#
# Epoch 119: val_loss did not improve from 0.00355
#
# Epoch 120: val_loss did not improve from 0.00355
#
# Epoch 121: val_loss did not improve from 0.00355
#
# Epoch 122: val_loss did not improve from 0.00355
#
# Epoch 123: val_loss did not improve from 0.00355
#
# Epoch 124: val_loss did not improve from 0.00355
#
# Epoch 125: val_loss did not improve from 0.00355
#
# Epoch 126: val_loss did not improve from 0.00355
#
# Epoch 127: val_loss did not improve from 0.00355
#
# Epoch 128: val_loss did not improve from 0.00355
#
# Epoch 129: val_loss did not improve from 0.00355
#
# Epoch 130: val_loss did not improve from 0.00355
#
# Epoch 131: val_loss did not improve from 0.00355
#
# Epoch 132: val_loss did not improve from 0.00355
#
# Epoch 133: val_loss did not improve from 0.00355
#
# Epoch 134: val_loss did not improve from 0.00355
#
# Epoch 135: val_loss did not improve from 0.00355
#
# Epoch 136: val_loss did not improve from 0.00355
#
# Epoch 137: val_loss did not improve from 0.00355
#
# Epoch 138: val_loss did not improve from 0.00355
#
# Epoch 139: val_loss did not improve from 0.00355
#
# Epoch 140: val_loss did not improve from 0.00355
#
# Epoch 141: val_loss did not improve from 0.00355
#
# Epoch 142: val_loss did not improve from 0.00355
#
# Epoch 143: val_loss did not improve from 0.00355
#
# Epoch 144: val_loss did not improve from 0.00355
#
# Epoch 145: val_loss did not improve from 0.00355
#
# Epoch 146: val_loss did not improve from 0.00355
#
# Epoch 147: val_loss did not improve from 0.00355
#
# Epoch 148: val_loss did not improve from 0.00355
#
# Epoch 149: val_loss did not improve from 0.00355
#
# Epoch 150: val_loss did not improve from 0.00355
#
# Epoch 151: val_loss did not improve from 0.00355
#
# Epoch 152: val_loss did not improve from 0.00355
#
# Epoch 153: val_loss did not improve from 0.00355
#
# Epoch 154: val_loss did not improve from 0.00355
#
# Epoch 155: val_loss did not improve from 0.00355
#
# Epoch 156: val_loss did not improve from 0.00355
#
# Epoch 157: val_loss did not improve from 0.00355
#
# Epoch 158: val_loss did not improve from 0.00355
#
# Epoch 159: val_loss did not improve from 0.00355
#
# Epoch 160: val_loss did not improve from 0.00355
#
# Epoch 161: val_loss did not improve from 0.00355
#
# Epoch 162: val_loss did not improve from 0.00355
#
# Epoch 163: val_loss did not improve from 0.00355
#
# Epoch 164: val_loss did not improve from 0.00355
#
# Epoch 165: val_loss did not improve from 0.00355
#
# Epoch 166: val_loss did not improve from 0.00355
#
# Epoch 167: val_loss did not improve from 0.00355
#
# Epoch 168: val_loss did not improve from 0.00355
#
# Epoch 169: val_loss did not improve from 0.00355
#
# Epoch 170: val_loss did not improve from 0.00355
#
# Epoch 171: val_loss did not improve from 0.00355
#
# Epoch 172: val_loss did not improve from 0.00355
#
# Epoch 173: val_loss did not improve from 0.00355
#
# Epoch 174: val_loss did not improve from 0.00355
#
# Epoch 175: val_loss did not improve from 0.00355
#
# Epoch 176: val_loss did not improve from 0.00355
#
# Epoch 177: val_loss did not improve from 0.00355
#
# Epoch 178: val_loss did not improve from 0.00355
#
# Epoch 179: val_loss did not improve from 0.00355
#
# Epoch 180: val_loss did not improve from 0.00355
#
# Epoch 181: val_loss did not improve from 0.00355
#
# Epoch 182: val_loss did not improve from 0.00355
#
# Epoch 183: val_loss did not improve from 0.00355
#
# Epoch 184: val_loss did not improve from 0.00355
#
# Epoch 185: val_loss did not improve from 0.00355
#
# Epoch 186: val_loss did not improve from 0.00355
#
# Epoch 187: val_loss did not improve from 0.00355
#
# Epoch 188: val_loss did not improve from 0.00355
#
# Epoch 189: val_loss did not improve from 0.00355
#
# Epoch 190: val_loss did not improve from 0.00355
#
# Epoch 191: val_loss did not improve from 0.00355
#
# Epoch 192: val_loss did not improve from 0.00355
#
# Epoch 193: val_loss did not improve from 0.00355
#
# Epoch 194: val_loss did not improve from 0.00355
#
# Epoch 195: val_loss did not improve from 0.00355
#
# Epoch 196: val_loss did not improve from 0.00355
#
# Epoch 197: val_loss did not improve from 0.00355
#
# Epoch 198: val_loss did not improve from 0.00355
#
# Epoch 199: val_loss did not improve from 0.00355
#
# Epoch 200: val_loss did not improve from 0.00355
#
# Epoch 201: val_loss did not improve from 0.00355
#
# Epoch 202: val_loss did not improve from 0.00355
#
# Epoch 203: val_loss did not improve from 0.00355
#
# Epoch 204: val_loss did not improve from 0.00355
#
# Epoch 205: val_loss did not improve from 0.00355
#
# Epoch 206: val_loss did not improve from 0.00355
#
# Epoch 207: val_loss did not improve from 0.00355
#
# Epoch 208: val_loss did not improve from 0.00355
#
# Epoch 209: val_loss did not improve from 0.00355
#
# Epoch 210: val_loss did not improve from 0.00355
#
# Epoch 211: val_loss did not improve from 0.00355
#
# Epoch 212: val_loss did not improve from 0.00355
#
# Epoch 213: val_loss did not improve from 0.00355
#
# Epoch 214: val_loss did not improve from 0.00355
#
# Epoch 215: val_loss did not improve from 0.00355
#
# Epoch 216: val_loss did not improve from 0.00355
#
# Epoch 217: val_loss did not improve from 0.00355
#
# Epoch 218: val_loss did not improve from 0.00355
#
# Epoch 219: val_loss did not improve from 0.00355
#
# Epoch 220: val_loss did not improve from 0.00355
#
# Epoch 221: val_loss did not improve from 0.00355
#
# Epoch 222: val_loss did not improve from 0.00355
#
# Epoch 223: val_loss did not improve from 0.00355
#
# Epoch 224: val_loss did not improve from 0.00355
#
# Epoch 225: val_loss did not improve from 0.00355
#
# Epoch 226: val_loss did not improve from 0.00355
#
# Epoch 227: val_loss did not improve from 0.00355
#
# Epoch 228: val_loss did not improve from 0.00355
#
# Epoch 229: val_loss did not improve from 0.00355
#
# Epoch 230: val_loss did not improve from 0.00355
#
# Epoch 231: val_loss did not improve from 0.00355
#
# Epoch 232: val_loss did not improve from 0.00355
#
# Epoch 233: val_loss did not improve from 0.00355
#
# Epoch 234: val_loss did not improve from 0.00355
#
# Epoch 235: val_loss did not improve from 0.00355
#
# Epoch 236: val_loss did not improve from 0.00355
#
# Epoch 237: val_loss did not improve from 0.00355
#
# Epoch 238: val_loss did not improve from 0.00355
#
# Epoch 239: val_loss did not improve from 0.00355
#
# Epoch 240: val_loss did not improve from 0.00355
#
# Epoch 241: val_loss did not improve from 0.00355
#
# Epoch 242: val_loss did not improve from 0.00355
#
# Epoch 243: val_loss did not improve from 0.00355
#
# Epoch 244: val_loss did not improve from 0.00355
#
# Epoch 245: val_loss did not improve from 0.00355
#
# Epoch 246: val_loss did not improve from 0.00355
#
# Epoch 247: val_loss did not improve from 0.00355
#
# Epoch 248: val_loss did not improve from 0.00355
#
# Epoch 249: val_loss did not improve from 0.00355
#
# Epoch 250: val_loss did not improve from 0.00355

# %% [markdown]
# ### Bước 6: Đánh giá mô hình và trực quan hóa kết quả

# %% [markdown]
# #### 6.1. Vẽ biểu đồ train_loss và val_loss

# %%
plot_error(train_error, val_error)

# %% [markdown]
# #### 6.2. Đánh giá mô hình trên tập test

# %%
mse, rmse, mape, r2, true, predicted = evaluate_model_2(model, test, timesteps) #được tính dựa trên bộ dữ liệu đã chuẩn hoá
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step

# %%
print('MSE = {}'.format(mse))
print('RMSE = {}'.format(rmse))
print('MAPE = {}'.format(mape))
print('R-Squared Score = {}'.format(r2))
# Out:
# MSE = 0.0032228066365874546
# RMSE = 0.05676976868534391
# MAPE = 0.03019993698101792
# R-Squared Score = 0.9579559753444818

# %% [markdown]
# #### 6.3. Vẽ đồ thị dự đoán vs thực tế

# %%
plot_data_2(true, predicted)

# %%
# Save a model
model.save('10VAR-hpg-rnn.keras')

# %%
del model

# %% [markdown]
# # Model 2: Multivariate-3-GRU

# %% [markdown]
# ## GRU

# %% [markdown]
# ### Import các thư viện cần thiết

# %%
import os
os.environ['PYTHONHASHSEED'] = '0' # đảm bảo rằng các giá trị băm của đối tượng bất biến (dict, set, chuỗi, tuple...) luôn giống nhau giữa các lần chạy

import random as rn
import numpy as np
np.random.seed(1)
rn.seed(3)
import tensorflow as tf
tf.random.set_seed(2)

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, GRU, Dropout
from tensorflow.keras import optimizers

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from math import sqrt
import datetime as dt
import time

from tensorflow.keras.optimizers import Adam

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### Hàm callback

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')  
checkpoint = ModelCheckpoint(
    filepath="10Var-hpg-gru.h5",   # Tên file lưu mô hình
    monitor="val_loss",         # Theo dõi val_loss
    save_best_only=True,        # Chỉ lưu khi tốt hơn mô hình trước đó
    mode="min",                 # Giảm min của val_loss là tốt nhất
    verbose=1
)
callbacks_list = [earlystop, checkpoint]

# %% [markdown]
# ### Đọc dữ liệu từ file csv

# %%
url = r"hpg_history.csv"
df = pd.read_csv(url, parse_dates= True, index_col= 0)

# %%
df.head()
# Out:
#             open  high   low  close  volume
# time
# 2007-11-16  2.29  2.29  2.29   2.29  248510
# 2007-11-19  2.17  2.17  2.17   2.17  120480
# 2007-11-20  2.08  2.08  2.08   2.08   58710
# 2007-11-21  1.99  2.16  1.99   2.16  728080
# 2007-11-22  2.16  2.16  2.08   2.16  266040

# %%
df.isnull().sum()
# Out:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %% [markdown]
# ### Tiền xử lí dữ liệu

# %%
# Xóa các dòng có giá trị Volume bằng 0
df.drop(df[df['volume']==0].index, inplace=True)

# %%
# Ma trận tương quan (ở đây là Pearson tương quan tuyến tính)
df.corr()['close']
# Out:
# open      0.999667
# high      0.999857
# low       0.999838
# close     1.000000
# volume    0.799299
# Name: close, dtype: float64

# %%
print(df.describe().volume)
# Out:
# count    4.320000e+03
# mean     7.877410e+06
# std      1.133795e+07
# min      5.000000e+01
# 25%      4.646300e+05
# 50%      2.422785e+06
# 75%      1.233620e+07
# max      9.967998e+07
# Name: volume, dtype: float64

# %%
df['volume'].hist(bins= 10)
# Out:
# <Axes: >

# %%
# Bổ sung các chỉ báo kĩ thuật

# Tính CMA10
df['CMA10'] = df['close'].rolling(window=10, center=True).mean()
# Tính SMA10
df['SMA10'] = df['close'].rolling(window=10).mean()
# Tính SMA50
df['SMA50'] = df['close'].rolling(window=50).mean()
# Tính EMA12 và EMA26
df['EMA12'] = df['close'].ewm(span=12, adjust=False).mean()
df['EMA26'] = df['close'].ewm(span=26, adjust=False).mean()
# Tính MACD
df['MACD'] = df['EMA12'] - df['EMA26']
#Tính RSI
# Tính giá tăng/giảm
delta = df['close'].diff()

# Tính giá tăng
gain = delta.where(delta > 0, 0)

# Tính giá giảm
loss = -delta.where(delta < 0, 0)

# Tính trung bình động
avg_gain = gain.rolling(window=14).mean()
avg_loss = loss.rolling(window=14).mean()

# Tính RS và RSI
rs = avg_gain / avg_loss
df['RSI'] = 100 - (100 / (1 + rs))

#Tính CCI
# Tính giá trung bình
typical_price = (df['high'] + df['low'] + df['close']) / 3

# Tính SMA của giá trung bình
sma_typical_price = typical_price.rolling(window=20).mean()

# Tính độ lệch chuẩn
mean_deviation = typical_price.rolling(window=20).apply(lambda x: np.mean(np.abs(x - x.mean())))

# Tính CCI
df['CCI'] = (typical_price - sma_typical_price) / (0.015 * mean_deviation)
# Tính %K và %D
low_min = df['low'].rolling(window=14).min()
high_max = df['high'].rolling(window=14).max()

df['%K'] = 100 * (df['close'] - low_min) / (high_max - low_min)
df['%D'] = df['%K'].rolling(window=3).mean()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py:73: RuntimeWarning: invalid value encountered in greater
#   return op(a, b)
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py:73: RuntimeWarning: invalid value encountered in less
#   return op(a, b)

# %%
print(df.head())
df.shape
# Out:
#             open  high   low  close  volume  CMA10  SMA10  SMA50     EMA12  \
# time
# 2007-11-16  2.29  2.29  2.29   2.29  248510    NaN    NaN    NaN  2.290000
# 2007-11-19  2.17  2.17  2.17   2.17  120480    NaN    NaN    NaN  2.271538
# 2007-11-20  2.08  2.08  2.08   2.08   58710    NaN    NaN    NaN  2.242071
# 2007-11-21  1.99  2.16  1.99   2.16  728080    NaN    NaN    NaN  2.229445
# 2007-11-22  2.16  2.16  2.08   2.16  266040    NaN    NaN    NaN  2.218761
#
#                EMA26      MACD  RSI  CCI  %K  %D
# time
# 2007-11-16  2.290000  0.000000  NaN  NaN NaN NaN
# 2007-11-19  2.281111 -0.009573  NaN  NaN NaN NaN
# 2007-11-20  2.266214 -0.024143  NaN  NaN NaN NaN
# 2007-11-21  2.258346 -0.028902  NaN  NaN NaN NaN
# 2007-11-22  2.251061 -0.032300  NaN  NaN NaN NaN
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# (4320, 15)

# %% [markdown]
# ## Train model / Hàm **fit_model_3()**

# %%
def fit_model_3(train, val, timesteps, hl, lr, batch, epochs):
    """
    np.random.seed(1)
    tf.random.set_seed(2)
    rn.seed(3)
    """
    X_train = []
    Y_train = []
    X_val = []
    Y_val = []

    for i in range(timesteps, train.shape[0]):
        X_train.append(train[i-timesteps:i])
        Y_train.append(train[i][0])
    X_train, Y_train = np.array(X_train), np.array(Y_train)

    for i in range(timesteps, val.shape[0]):
        X_val.append(val[i-timesteps:i])
        Y_val.append(val[i][0])
    X_val, Y_val = np.array(X_val), np.array(Y_val)

    # Thêm các lớp vào mô hình
    model = Sequential()
    model.add(GRU(X_train.shape[2], input_shape= (X_train.shape[1], X_train.shape[2]), activation= 'relu', return_sequences= True))
    for i in range(len(hl)-1):
        model.add(GRU(hl[i], activation='relu', return_sequences= True))
    model.add(GRU(hl[-1], activation='relu'))
    model.add(Dense(1))

    # Biên dịch
    model.compile(optimizer= optimizers.Adam(learning_rate= lr), loss= 'mean_squared_error')

    # Huấn luyện dữ liệu
    history = model.fit(X_train, Y_train, epochs= epochs, batch_size= batch, validation_data= (X_val, Y_val), verbose= 0, shuffle= False, callbacks= callbacks_list)
    
    # Đặt lại trạng thái
    for layer in model.layers:
        if isinstance(layer, GRU):
            layer.reset_states()
    
    return model, history.history['loss'], history.history['val_loss']

# %% [markdown]
# ## Hàm **Evaluate_model_3()**

# %%
def evaluate_model_3(model, test, timesteps):
    """
    np.random.seed(1)
    tf.random.set_seed(2)
    """
    X_test = []
    Y_test = []

    for i in range(timesteps, test.shape[0]):
        X_test.append(test[i-timesteps:i])
        Y_test.append(test[i][0])
    X_test, Y_test= np.array(X_test), np.array(Y_test)

    # Các chỉ số đánh giá
    Y_hat = model.predict(X_test)
    mse = mean_squared_error(Y_test, Y_hat)
    rmse = sqrt(mse)
    mape = mean_absolute_percentage_error(Y_test, Y_hat)
    r2 = r2_score(Y_test, Y_hat)

    return mse, rmse, mape, r2, Y_test, Y_hat

# %% [markdown]
# ## **Grid Search**: Tìm kiếm siêu tham số tối ưu

# %%
param_grid = {
    'timesteps': [30, 40, 50],
    'hl': [[40, 35]],
    'lr': [1e-4, 1e-3],
    'batch_size': [32, 64],
    'num_epochs': [200, 250]
}

# %%
# Hàm grid search
def grid_search_rnn(train, val, test, param_grid):
    results = []
    best_score = float('inf')
    best_params = None

    # Tạo tất cả các tổ hợp tham số
    all_combinations = list(product(*(param_grid.values())))
    param_names = param_grid.keys()

    for combination in all_combinations:
        # Gán giá trị tham số hiện tại
        params = dict(zip(param_names, combination))
        hl = params['hl']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']

        print(f'Training with params: {params}')

        # Huấn luyện mô hình
        model, train_loss, val_loss = fit_model_3(train, val, timesteps, hl, lr, batch_size, num_epochs)

        # Đánh giá mô hình
        mse, rmse, mape, r2, _, _ = evaluate_model_3(model, test, timesteps)

        # Lưu kết quả
        results.append({
            'timesteps': timesteps,
            'hl': hl,
            'lr': lr,
            'batch_size': batch_size,
            'num_epochs': num_epochs,
            'mse': mse,
            'rmse': rmse,
            'mape': mape,
            'r2': r2
        })

        # Cập nhật tham số tốt nhất nếu RMSE cải thiện
        if rmse < best_score:
            best_score = rmse
            best_params = params

        # Trả về kết quả
        results_df = pd.DataFrame(results)
        return best_params, best_score, results_df

# %% [markdown]
# ## Plot chart (vẽ biểu đồ)

# %%
# Plotting the predictions
def plot_data_3(Y_test, Y_hat):
    plt.plot(Y_test, c = 'r')
    plt.plot(Y_hat, c = 'y')
    plt.xlabel('Day')
    plt.ylabel('Price')
    plt.title("Stock Price Prediction using Multivariate-GRU")
    plt.legend(['Actual','Predicted'], loc = 'lower right')
    plt.show()

# %%
# Plotting the training errors: trực quan loss qua các epoch -> thấy qtr học mô hình, xem có overfitting ko
def plot_error(train_loss, val_loss):
    plt.plot(train_loss, c = 'r')
    plt.plot(val_loss, c = 'b')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.title('Train Loss and Validation Loss Curve')
    plt.legend(['train', 'val'], loc = 'upper right')
    plt.show()

# %% [markdown]
# ## **Model building**: Xây dựng mô hình

# %% [markdown]
# ### Bước 1: Trích xuất và trực quan hóa dữ liệu

# %%
# Extracting the series
series = df[['close', 'high', 'low', 'CMA10', 'SMA10', 'SMA50', 'EMA12', 'RSI', 'CCI', '%K', '%D', 'MACD']]
# Drop rows with NaN values
series = series.dropna()

# Display the shape and the tail of the cleaned series
print(series.shape)
print(series.tail())
# Out:
# (4267, 12)
#             close   high    low   CMA10   SMA10   SMA50      EMA12        RSI  \
# time
# 2025-03-10  27.95  28.20  27.95  27.860  27.910  26.726  27.664525  66.666667
# 2025-03-11  28.15  28.15  27.60  27.840  27.975  26.749  27.739213  68.965517
# 2025-03-12  27.80  28.20  27.80  27.815  27.980  26.771  27.748565  63.440860
# 2025-03-13  27.70  28.05  27.70  27.785  27.905  26.782  27.741094  63.440860
# 2025-03-14  27.55  27.85  27.55  27.705  27.860  26.793  27.711695  47.887324
#
#                   CCI         %K         %D      MACD
# time
# 2025-03-10  72.152412  75.609756  78.723924  0.419877
# 2025-03-11  61.493516  85.365854  80.790320  0.427503
# 2025-03-12  54.366686  68.292683  76.422764  0.400685
# 2025-03-13  39.488661  40.000000  64.552846  0.367130
# 2025-03-14  16.260163  28.000000  45.430894  0.324692

# %% [markdown]
# ### Bước 2: Chia dữ liệu thành các tập Train, Validation, Test

# %%
series.shape
# Out:
# (4267, 12)

# %%
n = series.shape[0]
val_size =  test_size = int(n * 0.15)
train_size = n - val_size - test_size # Để tránh sai số làm mất dữ liệu

# Chia tập dữ liệu theo thứ tự thời gian
train_data = series.iloc[:train_size].values
val_data = series.iloc[train_size:train_size + val_size].values
test_data = series.iloc[(train_size + val_size):].values
# Kiểm tra kích thước của từng tập
print(train_data.shape, val_data.shape, test_data.shape)
# Out:
# (2987, 12) (640, 12) (640, 12)

# %% [markdown]
# ### Bước 3: Chuẩn hóa dữ liệu bằng MinMaxScaler

# %%
# Normalisation
np.random.seed(1)
tf.random.set_seed(2)

sc = MinMaxScaler()
train = sc.fit_transform(train_data)
val = sc.transform(val_data)
test = sc.transform(test_data)

print(train.shape, val.shape, test.shape)
# Out:
# (2987, 12) (640, 12) (640, 12)

# %% [markdown]
# ### Bước 4: Tìm siêu tham số tốt nhất bằng Grid Search

# %%
best_params, best_score, results_df = grid_search_rnn(train, val, test, param_grid)

print(results_df)
print("Best parameters:", best_params)
print("Best RMSE score:", best_score)
# Out:
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 32, 'num_epochs': 200}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss improved from inf to 3.39805, saving model to 10Var-hpg-gru.h5
#
# Epoch 2: val_loss improved from 3.39805 to 2.78381, saving model to 10Var-hpg-gru.h5
#
# Epoch 3: val_loss improved from 2.78381 to 2.19997, saving model to 10Var-hpg-gru.h5
#
# Epoch 4: val_loss improved from 2.19997 to 1.64432, saving model to 10Var-hpg-gru.h5
#
# Epoch 5: val_loss improved from 1.64432 to 1.07004, saving model to 10Var-hpg-gru.h5
#
# Epoch 6: val_loss improved from 1.07004 to 0.58237, saving model to 10Var-hpg-gru.h5
#
# Epoch 7: val_loss improved from 0.58237 to 0.28054, saving model to 10Var-hpg-gru.h5
#
# Epoch 8: val_loss improved from 0.28054 to 0.15742, saving model to 10Var-hpg-gru.h5
#
# Epoch 9: val_loss improved from 0.15742 to 0.11269, saving model to 10Var-hpg-gru.h5
#
# Epoch 10: val_loss improved from 0.11269 to 0.09387, saving model to 10Var-hpg-gru.h5
#
# Epoch 11: val_loss improved from 0.09387 to 0.08231, saving model to 10Var-hpg-gru.h5
#
# Epoch 12: val_loss improved from 0.08231 to 0.07416, saving model to 10Var-hpg-gru.h5
#
# Epoch 13: val_loss improved from 0.07416 to 0.06739, saving model to 10Var-hpg-gru.h5
#
# Epoch 14: val_loss improved from 0.06739 to 0.06124, saving model to 10Var-hpg-gru.h5
#
# Epoch 15: val_loss improved from 0.06124 to 0.05654, saving model to 10Var-hpg-gru.h5
#
# Epoch 16: val_loss improved from 0.05654 to 0.05314, saving model to 10Var-hpg-gru.h5
#
# Epoch 17: val_loss improved from 0.05314 to 0.05036, saving model to 10Var-hpg-gru.h5
#
# Epoch 18: val_loss improved from 0.05036 to 0.04725, saving model to 10Var-hpg-gru.h5
#
# Epoch 19: val_loss improved from 0.04725 to 0.04443, saving model to 10Var-hpg-gru.h5
#
# Epoch 20: val_loss improved from 0.04443 to 0.04192, saving model to 10Var-hpg-gru.h5
#
# Epoch 21: val_loss improved from 0.04192 to 0.03955, saving model to 10Var-hpg-gru.h5
#
# Epoch 22: val_loss improved from 0.03955 to 0.03728, saving model to 10Var-hpg-gru.h5
#
# Epoch 23: val_loss improved from 0.03728 to 0.03517, saving model to 10Var-hpg-gru.h5
#
# Epoch 24: val_loss improved from 0.03517 to 0.03322, saving model to 10Var-hpg-gru.h5
#
# Epoch 25: val_loss improved from 0.03322 to 0.03139, saving model to 10Var-hpg-gru.h5
#
# Epoch 26: val_loss improved from 0.03139 to 0.02962, saving model to 10Var-hpg-gru.h5
#
# Epoch 27: val_loss improved from 0.02962 to 0.02806, saving model to 10Var-hpg-gru.h5
#
# Epoch 28: val_loss improved from 0.02806 to 0.02652, saving model to 10Var-hpg-gru.h5
#
# Epoch 29: val_loss improved from 0.02652 to 0.02505, saving model to 10Var-hpg-gru.h5
#
# Epoch 30: val_loss improved from 0.02505 to 0.02359, saving model to 10Var-hpg-gru.h5
#
# Epoch 31: val_loss improved from 0.02359 to 0.02231, saving model to 10Var-hpg-gru.h5
#
# Epoch 32: val_loss improved from 0.02231 to 0.02102, saving model to 10Var-hpg-gru.h5
#
# Epoch 33: val_loss improved from 0.02102 to 0.01986, saving model to 10Var-hpg-gru.h5
#
# Epoch 34: val_loss improved from 0.01986 to 0.01869, saving model to 10Var-hpg-gru.h5
#
# Epoch 35: val_loss improved from 0.01869 to 0.01772, saving model to 10Var-hpg-gru.h5
#
# Epoch 36: val_loss improved from 0.01772 to 0.01674, saving model to 10Var-hpg-gru.h5
#
# Epoch 37: val_loss improved from 0.01674 to 0.01590, saving model to 10Var-hpg-gru.h5
#
# Epoch 38: val_loss improved from 0.01590 to 0.01512, saving model to 10Var-hpg-gru.h5
#
# Epoch 39: val_loss improved from 0.01512 to 0.01430, saving model to 10Var-hpg-gru.h5
#
# Epoch 40: val_loss improved from 0.01430 to 0.01359, saving model to 10Var-hpg-gru.h5
#
# Epoch 41: val_loss improved from 0.01359 to 0.01291, saving model to 10Var-hpg-gru.h5
#
# Epoch 42: val_loss improved from 0.01291 to 0.01235, saving model to 10Var-hpg-gru.h5
#
# Epoch 43: val_loss improved from 0.01235 to 0.01184, saving model to 10Var-hpg-gru.h5
#
# Epoch 44: val_loss improved from 0.01184 to 0.01140, saving model to 10Var-hpg-gru.h5
#
# Epoch 45: val_loss improved from 0.01140 to 0.01101, saving model to 10Var-hpg-gru.h5
#
# Epoch 46: val_loss improved from 0.01101 to 0.01062, saving model to 10Var-hpg-gru.h5
#
# Epoch 47: val_loss improved from 0.01062 to 0.01027, saving model to 10Var-hpg-gru.h5
#
# Epoch 48: val_loss improved from 0.01027 to 0.00997, saving model to 10Var-hpg-gru.h5
#
# Epoch 49: val_loss improved from 0.00997 to 0.00971, saving model to 10Var-hpg-gru.h5
#
# Epoch 50: val_loss improved from 0.00971 to 0.00943, saving model to 10Var-hpg-gru.h5
#
# Epoch 51: val_loss improved from 0.00943 to 0.00916, saving model to 10Var-hpg-gru.h5
#
# Epoch 52: val_loss improved from 0.00916 to 0.00891, saving model to 10Var-hpg-gru.h5
#
# Epoch 53: val_loss improved from 0.00891 to 0.00868, saving model to 10Var-hpg-gru.h5
#
# Epoch 54: val_loss improved from 0.00868 to 0.00841, saving model to 10Var-hpg-gru.h5
#
# Epoch 55: val_loss improved from 0.00841 to 0.00818, saving model to 10Var-hpg-gru.h5
#
# Epoch 56: val_loss improved from 0.00818 to 0.00787, saving model to 10Var-hpg-gru.h5
#
# Epoch 57: val_loss improved from 0.00787 to 0.00771, saving model to 10Var-hpg-gru.h5
#
# Epoch 58: val_loss improved from 0.00771 to 0.00741, saving model to 10Var-hpg-gru.h5
#
# Epoch 59: val_loss improved from 0.00741 to 0.00719, saving model to 10Var-hpg-gru.h5
#
# Epoch 60: val_loss improved from 0.00719 to 0.00696, saving model to 10Var-hpg-gru.h5
#
# Epoch 61: val_loss improved from 0.00696 to 0.00689, saving model to 10Var-hpg-gru.h5
#
# Epoch 62: val_loss improved from 0.00689 to 0.00673, saving model to 10Var-hpg-gru.h5
#
# Epoch 63: val_loss improved from 0.00673 to 0.00668, saving model to 10Var-hpg-gru.h5
#
# Epoch 64: val_loss improved from 0.00668 to 0.00665, saving model to 10Var-hpg-gru.h5
#
# Epoch 65: val_loss improved from 0.00665 to 0.00665, saving model to 10Var-hpg-gru.h5
#
# Epoch 66: val_loss did not improve from 0.00665
#
# Epoch 67: val_loss did not improve from 0.00665
#
# Epoch 68: val_loss did not improve from 0.00665
#
# Epoch 69: val_loss did not improve from 0.00665
#
# Epoch 70: val_loss did not improve from 0.00665
#
# Epoch 71: val_loss did not improve from 0.00665
#
# Epoch 72: val_loss did not improve from 0.00665
#
# Epoch 73: val_loss did not improve from 0.00665
#
# Epoch 74: val_loss did not improve from 0.00665
#
# Epoch 75: val_loss did not improve from 0.00665
#
# Epoch 76: val_loss did not improve from 0.00665
#
# Epoch 77: val_loss did not improve from 0.00665
#
# Epoch 78: val_loss did not improve from 0.00665
#
# Epoch 79: val_loss did not improve from 0.00665
#
# Epoch 80: val_loss did not improve from 0.00665
#
# Epoch 81: val_loss did not improve from 0.00665
#
# Epoch 82: val_loss did not improve from 0.00665
#
# Epoch 83: val_loss did not improve from 0.00665
#
# Epoch 84: val_loss did not improve from 0.00665
#
# Epoch 85: val_loss did not improve from 0.00665
#
# Epoch 86: val_loss did not improve from 0.00665
#
# Epoch 87: val_loss did not improve from 0.00665
#
# Epoch 88: val_loss did not improve from 0.00665
#
# Epoch 89: val_loss did not improve from 0.00665
#
# Epoch 90: val_loss did not improve from 0.00665
#
# Epoch 91: val_loss did not improve from 0.00665
#
# Epoch 92: val_loss did not improve from 0.00665
#
# Epoch 93: val_loss did not improve from 0.00665
#
# Epoch 94: val_loss did not improve from 0.00665
#
# Epoch 95: val_loss did not improve from 0.00665
#
# Epoch 96: val_loss did not improve from 0.00665
#
# Epoch 97: val_loss did not improve from 0.00665
#
# Epoch 98: val_loss did not improve from 0.00665
#
# Epoch 99: val_loss did not improve from 0.00665
#
# Epoch 100: val_loss did not improve from 0.00665
#
# Epoch 101: val_loss did not improve from 0.00665
#
# Epoch 102: val_loss did not improve from 0.00665
#
# Epoch 103: val_loss did not improve from 0.00665
#
# Epoch 104: val_loss did not improve from 0.00665
#
# Epoch 105: val_loss did not improve from 0.00665
#
# Epoch 106: val_loss did not improve from 0.00665
#
# Epoch 107: val_loss did not improve from 0.00665
#
# Epoch 108: val_loss did not improve from 0.00665
#
# Epoch 109: val_loss did not improve from 0.00665
#
# Epoch 110: val_loss did not improve from 0.00665
#
# Epoch 111: val_loss did not improve from 0.00665
#
# Epoch 112: val_loss did not improve from 0.00665
#
# Epoch 113: val_loss did not improve from 0.00665
#
# Epoch 114: val_loss did not improve from 0.00665
#
# Epoch 115: val_loss did not improve from 0.00665
#
# Epoch 116: val_loss did not improve from 0.00665
#
# Epoch 117: val_loss did not improve from 0.00665
#
# Epoch 118: val_loss did not improve from 0.00665
#
# Epoch 119: val_loss did not improve from 0.00665
#
# Epoch 120: val_loss did not improve from 0.00665
#
# Epoch 121: val_loss did not improve from 0.00665
#
# Epoch 122: val_loss did not improve from 0.00665
#
# Epoch 123: val_loss did not improve from 0.00665
#
# Epoch 124: val_loss did not improve from 0.00665
#
# Epoch 125: val_loss did not improve from 0.00665
#
# Epoch 126: val_loss did not improve from 0.00665
#
# Epoch 127: val_loss did not improve from 0.00665
#
# Epoch 128: val_loss did not improve from 0.00665
#
# Epoch 129: val_loss did not improve from 0.00665
#
# Epoch 130: val_loss did not improve from 0.00665
#
# Epoch 131: val_loss did not improve from 0.00665
#
# Epoch 132: val_loss did not improve from 0.00665
#
# Epoch 133: val_loss did not improve from 0.00665
#
# Epoch 134: val_loss did not improve from 0.00665
#
# Epoch 135: val_loss did not improve from 0.00665
#
# Epoch 136: val_loss did not improve from 0.00665
#
# Epoch 137: val_loss did not improve from 0.00665
#
# Epoch 138: val_loss did not improve from 0.00665
#
# Epoch 139: val_loss did not improve from 0.00665
#
# Epoch 140: val_loss did not improve from 0.00665
#
# Epoch 141: val_loss did not improve from 0.00665
#
# Epoch 142: val_loss did not improve from 0.00665
# Epoch 142: early stopping
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step
#    timesteps        hl      lr  batch_size  num_epochs       mse      rmse  \
# 0         50  [40, 35]  0.0001          32         200  0.015306  0.123718
#
#        mape       r2
# 0  0.067682  0.80032
# Best parameters: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 32, 'num_epochs': 200}
# Best RMSE score: 0.12371786323866477

# %% [markdown]
# ### Bước 5: Huấn luyện mô hình với bộ tham số tối ưu

# %%
timesteps = 30
hl = [40, 35]
lr = 1e-4
batch_size = 32
num_epochs = 200

model, train_loss, val_loss = fit_model_3(train, val, timesteps, hl, lr, batch_size, num_epochs)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00665
#
# Epoch 2: val_loss did not improve from 0.00665
#
# Epoch 3: val_loss did not improve from 0.00665
#
# Epoch 4: val_loss did not improve from 0.00665
#
# Epoch 5: val_loss did not improve from 0.00665
#
# Epoch 6: val_loss did not improve from 0.00665
#
# Epoch 7: val_loss did not improve from 0.00665
#
# Epoch 8: val_loss did not improve from 0.00665
#
# Epoch 9: val_loss did not improve from 0.00665
#
# Epoch 10: val_loss did not improve from 0.00665
#
# Epoch 11: val_loss did not improve from 0.00665
#
# Epoch 12: val_loss did not improve from 0.00665
#
# Epoch 13: val_loss did not improve from 0.00665
#
# Epoch 14: val_loss did not improve from 0.00665
#
# Epoch 15: val_loss did not improve from 0.00665
#
# Epoch 16: val_loss did not improve from 0.00665
#
# Epoch 17: val_loss did not improve from 0.00665
#
# Epoch 18: val_loss did not improve from 0.00665
#
# Epoch 19: val_loss did not improve from 0.00665
#
# Epoch 20: val_loss did not improve from 0.00665
#
# Epoch 21: val_loss did not improve from 0.00665
#
# Epoch 22: val_loss did not improve from 0.00665
#
# Epoch 23: val_loss did not improve from 0.00665
#
# Epoch 24: val_loss did not improve from 0.00665
#
# Epoch 25: val_loss did not improve from 0.00665
#
# Epoch 26: val_loss did not improve from 0.00665
#
# Epoch 27: val_loss did not improve from 0.00665
#
# Epoch 28: val_loss did not improve from 0.00665
#
# Epoch 29: val_loss did not improve from 0.00665
#
# Epoch 30: val_loss did not improve from 0.00665
#
# Epoch 31: val_loss did not improve from 0.00665
#
# Epoch 32: val_loss did not improve from 0.00665
#
# Epoch 33: val_loss did not improve from 0.00665
#
# Epoch 34: val_loss did not improve from 0.00665
#
# Epoch 35: val_loss improved from 0.00665 to 0.00652, saving model to 10Var-hpg-gru.h5
#
# Epoch 36: val_loss improved from 0.00652 to 0.00604, saving model to 10Var-hpg-gru.h5
#
# Epoch 37: val_loss improved from 0.00604 to 0.00566, saving model to 10Var-hpg-gru.h5
#
# Epoch 38: val_loss improved from 0.00566 to 0.00537, saving model to 10Var-hpg-gru.h5
#
# Epoch 39: val_loss improved from 0.00537 to 0.00521, saving model to 10Var-hpg-gru.h5
#
# Epoch 40: val_loss improved from 0.00521 to 0.00515, saving model to 10Var-hpg-gru.h5
#
# Epoch 41: val_loss improved from 0.00515 to 0.00514, saving model to 10Var-hpg-gru.h5
#
# Epoch 42: val_loss did not improve from 0.00514
#
# Epoch 43: val_loss did not improve from 0.00514
#
# Epoch 44: val_loss did not improve from 0.00514
#
# Epoch 45: val_loss did not improve from 0.00514
#
# Epoch 46: val_loss did not improve from 0.00514
#
# Epoch 47: val_loss did not improve from 0.00514
#
# Epoch 48: val_loss did not improve from 0.00514
#
# Epoch 49: val_loss did not improve from 0.00514
#
# Epoch 50: val_loss did not improve from 0.00514
#
# Epoch 51: val_loss did not improve from 0.00514
#
# Epoch 52: val_loss did not improve from 0.00514
#
# Epoch 53: val_loss did not improve from 0.00514
#
# Epoch 54: val_loss improved from 0.00514 to 0.00511, saving model to 10Var-hpg-gru.h5
#
# Epoch 55: val_loss did not improve from 0.00511
#
# Epoch 56: val_loss improved from 0.00511 to 0.00506, saving model to 10Var-hpg-gru.h5
#
# Epoch 57: val_loss did not improve from 0.00506
#
# Epoch 58: val_loss did not improve from 0.00506
#
# Epoch 59: val_loss did not improve from 0.00506
#
# Epoch 60: val_loss did not improve from 0.00506
#
# Epoch 61: val_loss did not improve from 0.00506
#
# Epoch 62: val_loss did not improve from 0.00506
#
# Epoch 63: val_loss did not improve from 0.00506
#
# Epoch 64: val_loss did not improve from 0.00506
#
# Epoch 65: val_loss did not improve from 0.00506
#
# Epoch 66: val_loss did not improve from 0.00506
#
# Epoch 67: val_loss did not improve from 0.00506
#
# Epoch 68: val_loss did not improve from 0.00506
#
# Epoch 69: val_loss did not improve from 0.00506
#
# Epoch 70: val_loss did not improve from 0.00506
#
# Epoch 71: val_loss did not improve from 0.00506
#
# Epoch 72: val_loss did not improve from 0.00506
#
# Epoch 73: val_loss did not improve from 0.00506
#
# Epoch 74: val_loss did not improve from 0.00506
#
# Epoch 75: val_loss did not improve from 0.00506
#
# Epoch 76: val_loss did not improve from 0.00506
#
# Epoch 77: val_loss did not improve from 0.00506
#
# Epoch 78: val_loss did not improve from 0.00506
#
# Epoch 79: val_loss did not improve from 0.00506
#
# Epoch 80: val_loss did not improve from 0.00506
#
# Epoch 81: val_loss did not improve from 0.00506
#
# Epoch 82: val_loss did not improve from 0.00506
#
# Epoch 83: val_loss did not improve from 0.00506
#
# Epoch 84: val_loss did not improve from 0.00506
#
# Epoch 85: val_loss did not improve from 0.00506
#
# Epoch 86: val_loss did not improve from 0.00506
#
# Epoch 87: val_loss did not improve from 0.00506
#
# Epoch 88: val_loss did not improve from 0.00506
#
# Epoch 89: val_loss did not improve from 0.00506
#
# Epoch 90: val_loss did not improve from 0.00506
#
# Epoch 91: val_loss did not improve from 0.00506
#
# Epoch 92: val_loss did not improve from 0.00506
#
# Epoch 93: val_loss did not improve from 0.00506
#
# Epoch 94: val_loss did not improve from 0.00506
#
# Epoch 95: val_loss did not improve from 0.00506
#
# Epoch 96: val_loss did not improve from 0.00506
#
# Epoch 97: val_loss did not improve from 0.00506
#
# Epoch 98: val_loss did not improve from 0.00506
#
# Epoch 99: val_loss did not improve from 0.00506
#
# Epoch 100: val_loss did not improve from 0.00506
#
# Epoch 101: val_loss did not improve from 0.00506
#
# Epoch 102: val_loss did not improve from 0.00506
#
# Epoch 103: val_loss did not improve from 0.00506
#
# Epoch 104: val_loss did not improve from 0.00506
#
# Epoch 105: val_loss did not improve from 0.00506
#
# Epoch 106: val_loss did not improve from 0.00506
#
# Epoch 107: val_loss did not improve from 0.00506
#
# Epoch 108: val_loss did not improve from 0.00506
#
# Epoch 109: val_loss did not improve from 0.00506
#
# Epoch 110: val_loss did not improve from 0.00506
#
# Epoch 111: val_loss did not improve from 0.00506
#
# Epoch 112: val_loss did not improve from 0.00506
#
# Epoch 113: val_loss did not improve from 0.00506
#
# Epoch 114: val_loss did not improve from 0.00506
#
# Epoch 115: val_loss did not improve from 0.00506
#
# Epoch 116: val_loss did not improve from 0.00506
#
# Epoch 117: val_loss did not improve from 0.00506
#
# Epoch 118: val_loss did not improve from 0.00506
#
# Epoch 119: val_loss did not improve from 0.00506
#
# Epoch 120: val_loss did not improve from 0.00506
#
# Epoch 121: val_loss did not improve from 0.00506
#
# Epoch 122: val_loss did not improve from 0.00506
#
# Epoch 123: val_loss did not improve from 0.00506
#
# Epoch 124: val_loss did not improve from 0.00506
#
# Epoch 125: val_loss did not improve from 0.00506
#
# Epoch 126: val_loss did not improve from 0.00506
#
# Epoch 127: val_loss did not improve from 0.00506
#
# Epoch 128: val_loss did not improve from 0.00506
#
# Epoch 129: val_loss did not improve from 0.00506
#
# Epoch 130: val_loss did not improve from 0.00506
#
# Epoch 131: val_loss did not improve from 0.00506
#
# Epoch 132: val_loss did not improve from 0.00506
#
# Epoch 133: val_loss did not improve from 0.00506
#
# Epoch 134: val_loss did not improve from 0.00506
#
# Epoch 135: val_loss did not improve from 0.00506
#
# Epoch 136: val_loss did not improve from 0.00506
# Epoch 136: early stopping

# %% [markdown]
# ### Bước 6: Đánh giá mô hình và trực quan hóa kết quả

# %% [markdown]
# #### 6.1. Vẽ biểu đồ train_loss và val_loss

# %%
plot_error(train_error, val_error)

# %% [markdown]
# #### 6.2. Đánh giá mô hình trên tập test

# %%
mse, rmse, mape, r2, true, predicted = evaluate_model_3(model, test, timesteps)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step

# %%
print('MSE = {}'.format(mse))
print('RMSE = {}'.format(rmse))
print('MAPE = {}'.format(mape))
print('R-Squared Score = {}'.format(r2))
# Out:
# MSE = 0.011491188687233096
# RMSE = 0.10719696211755768
# MAPE = 0.05958831968890106
# R-Squared Score = 0.8617326787452297

# %% [markdown]
# #### 6.3. Vẽ đồ thị dự đoán vs thực tế

# %%
plot_data_3(true, predicted)

# %%
# Save a model
model.save('10VAR-hpg-gru.keras')

# %%
del model

# %% [markdown]
# # Model 3: Multivariate-3-LSTM

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Import các thư viện cần thiết

# %%
import os
os.environ['PYTHONHASHSEED'] = '0' # đảm bảo rằng các giá trị băm của đối tượng bất biến (dict, set, chuỗi, tuple...) luôn giống nhau giữa các lần chạy

import random as rn
import numpy as np
np.random.seed(1)
rn.seed(3)
import tensorflow as tf
tf.random.set_seed(2)
# Out:
# 2025-06-02 14:45:45.424172: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748875545.658327      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748875545.729589      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras import optimizers

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from math import sqrt
import datetime as dt
import time

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### Hàm callback

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')  
checkpoint = ModelCheckpoint(
    filepath="10Var_hpg_lstm.h5",   # Tên file lưu mô hình
    monitor="val_loss",         # Theo dõi val_loss
    save_best_only=True,        # Chỉ lưu khi tốt hơn mô hình trước đó
    mode="min",                 # Giảm min của val_loss là tốt nhất
    verbose=1
)
callbacks_list = [earlystop, checkpoint]

# %% [markdown]
# ### Đọc dữ liệu từ file csv

# %%
url = r"hpg_history.csv"
df = pd.read_csv(url, parse_dates= True, index_col= 0)

# %%
df.head()
# Out:
#             open  high   low  close  volume
# time
# 2007-11-16  2.29  2.29  2.29   2.29  248510
# 2007-11-19  2.17  2.17  2.17   2.17  120480
# 2007-11-20  2.08  2.08  2.08   2.08   58710
# 2007-11-21  1.99  2.16  1.99   2.16  728080
# 2007-11-22  2.16  2.16  2.08   2.16  266040

# %%
df.isnull().sum()
# Out:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %% [markdown]
# ### Tiền xử lí dữ liệu

# %%
# Xóa các dòng có giá trị Volume bằng 0
df.drop(df[df['volume']==0].index, inplace=True)

# %%
# Ma trận tương quan (ở đây là Pearson tương quan tuyến tính)
df.corr()['close']
# Out:
# open      0.999667
# high      0.999857
# low       0.999838
# close     1.000000
# volume    0.799299
# Name: close, dtype: float64

# %%
print(df.describe().volume) 
df['volume'].hist(bins= 10)
# Out:
# count    4.320000e+03
# mean     7.877410e+06
# std      1.133795e+07
# min      5.000000e+01
# 25%      4.646300e+05
# 50%      2.422785e+06
# 75%      1.233620e+07
# max      9.967998e+07
# Name: volume, dtype: float64
# <Axes: >

# %%
# Bổ sung các chỉ báo kĩ thuật

# Tính CMA10
df['CMA10'] = df['close'].rolling(window=10, center=True).mean()
# Tính SMA10
df['SMA10'] = df['close'].rolling(window=10).mean()
# Tính SMA50
df['SMA50'] = df['close'].rolling(window=50).mean()
# Tính EMA12 và EMA26
df['EMA12'] = df['close'].ewm(span=12, adjust=False).mean()
df['EMA26'] = df['close'].ewm(span=26, adjust=False).mean()
# Tính MACD
df['MACD'] = df['EMA12'] - df['EMA26']
#Tính RSI
# Tính giá tăng/giảm
delta = df['close'].diff()

# Tính giá tăng
gain = delta.where(delta > 0, 0)

# Tính giá giảm
loss = -delta.where(delta < 0, 0)

# Tính trung bình động
avg_gain = gain.rolling(window=14).mean()
avg_loss = loss.rolling(window=14).mean()

# Tính RS và RSI
rs = avg_gain / avg_loss
df['RSI'] = 100 - (100 / (1 + rs))

#Tính CCI
# Tính giá trung bình
typical_price = (df['high'] + df['low'] + df['close']) / 3

# Tính SMA của giá trung bình
sma_typical_price = typical_price.rolling(window=20).mean()

# Tính độ lệch chuẩn
mean_deviation = typical_price.rolling(window=20).apply(lambda x: np.mean(np.abs(x - x.mean())))

# Tính CCI
df['CCI'] = (typical_price - sma_typical_price) / (0.015 * mean_deviation)
# Tính %K và %D
low_min = df['low'].rolling(window=14).min()
high_max = df['high'].rolling(window=14).max()

df['%K'] = 100 * (df['close'] - low_min) / (high_max - low_min)
df['%D'] = df['%K'].rolling(window=3).mean()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py:73: RuntimeWarning: invalid value encountered in greater
#   return op(a, b)
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py:73: RuntimeWarning: invalid value encountered in less
#   return op(a, b)

# %%
print(df.head())
df.shape
# Out:
#             open  high   low  close  volume  CMA10  SMA10  SMA50     EMA12  \
# time
# 2007-11-16  2.29  2.29  2.29   2.29  248510    NaN    NaN    NaN  2.290000
# 2007-11-19  2.17  2.17  2.17   2.17  120480    NaN    NaN    NaN  2.271538
# 2007-11-20  2.08  2.08  2.08   2.08   58710    NaN    NaN    NaN  2.242071
# 2007-11-21  1.99  2.16  1.99   2.16  728080    NaN    NaN    NaN  2.229445
# 2007-11-22  2.16  2.16  2.08   2.16  266040    NaN    NaN    NaN  2.218761
#
#                EMA26      MACD  RSI  CCI  %K  %D
# time
# 2007-11-16  2.290000  0.000000  NaN  NaN NaN NaN
# 2007-11-19  2.281111 -0.009573  NaN  NaN NaN NaN
# 2007-11-20  2.266214 -0.024143  NaN  NaN NaN NaN
# 2007-11-21  2.258346 -0.028902  NaN  NaN NaN NaN
# 2007-11-22  2.251061 -0.032300  NaN  NaN NaN NaN
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# (4320, 15)

# %% [markdown]
# ## Train model / Hàm **fit_model_4()**

# %%
def fit_model_4(train, val, timesteps, hl, lr, batch, epochs):
    X_train = []
    Y_train = []
    X_val = []
    Y_val = []

    for i in range(timesteps, train.shape[0]):
        X_train.append(train[i-timesteps:i])
        Y_train.append(train[i][0])
    X_train, Y_train = np.array(X_train), np.array(Y_train)

    for i in range(timesteps, val.shape[0]):
        X_val.append(val[i-timesteps:i])
        Y_val.append(val[i][0])
    X_val, Y_val = np.array(X_val), np.array(Y_val)

    # Xây dựng mô hình
    model = Sequential()
    model.add(LSTM(X_train.shape[2], input_shape= (X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences= True))
    for i in range(len(hl)-1):
        model.add(LSTM(hl[i], activation='relu', return_sequences= True))
    model.add(LSTM(hl[-1], activation='relu'))
    model.add(Dense(1))

    # Biên dịch
    model.compile(optimizer= optimizers.Adam(learning_rate= lr), loss= 'mean_squared_error')

    # Huấn luyện mô hình
    history = model.fit(X_train, Y_train, batch_size= batch, epochs= epochs, validation_data= (X_val, Y_val), verbose= 0, shuffle= False, callbacks= callbacks_list)

    # Đặt lại trạng thái
    for layer in model.layers:
        if isinstance(layer, LSTM):
            layer.reset_state()

    return model, history.history['loss'], history.history['val_loss']

# %% [markdown]
# ## Hàm **Evaluate_model_4()**

# %%
def evaluate_model_4(model, test, timesteps):
    X_test = []
    Y_test = []

    for i in range(timesteps, test.shape[0]):
        X_test.append(test[i-timesteps:i])
        Y_test.append(test[i][0])
    X_test, Y_test = np.array(X_test), np.array(Y_test)

    # Các chỉ số
    Y_hat = model.predict(X_test)
    mse = mean_squared_error(Y_test, Y_hat)
    rmse = sqrt(mse)
    mape = mean_absolute_percentage_error(Y_test, Y_hat)
    r2 = r2_score(Y_test, Y_hat)

    return mse, rmse, mape, r2, Y_test, Y_hat

# %% [markdown]
# ## **Grid Search**: Tìm kiếm siêu tham số tối ưu

# %%
param_grid = {
    'timesteps': [30, 40, 50],  # Số giá trị trước đó để dự đoán
    'hl': [ [40, 35]], # Cấu trúc lớp ẩn
    'lr': [1e-3, 1e-4],  # Tốc độ học
    'batch_size': [32, 64],  # Kích thước batch
    'num_epochs': [200, 250],  # Số epoch
}

# %%
from itertools import product
import pandas as pd

# Hàm Grid Search
def grid_search_rnn(train, val, test, param_grid):
    results = []  # Lưu kết quả của từng tổ hợp tham số
    best_score = float('inf')  # Lưu RMSE tốt nhất
    best_params = None  # Lưu bộ tham số tốt nhất

    # Tạo tất cả các tổ hợp tham số
    all_combinations = list(product(*param_grid.values()))
    param_names = list(param_grid.keys())

    for combination in all_combinations:
        # Gán giá trị tham số hiện tại
        params = dict(zip(param_names, combination))
        timesteps = params['timesteps']
        hl = params['hl']
        lr = params['lr']
        batch_size = params['batch_size']
        num_epochs = params['num_epochs']

        print(f"Training with params: {params}")

        # Huấn luyện mô hình
        model, train_loss, val_loss = fit_model_4(
            train, val, timesteps, hl, lr, batch_size, num_epochs
        )

        # Đánh giá mô hình
        mse, rmse, mape, r2, _, _ = evaluate_model_4(model, test, timesteps)

        # Lưu kết quả
        results.append({
            'timesteps': timesteps,
            'hl': hl,
            'lr': lr,
            'batch_size': batch_size,
            'num_epochs': num_epochs,
            'MSE': mse,
            'RMSE': rmse,
            'MAPE': mape,
            'R²': r2
        })

        # Cập nhật tham số tốt nhất nếu RMSE cải thiện
        if rmse < best_score:
            best_score = rmse
            best_params = params

    # Trả về kết quả
    results_df = pd.DataFrame(results)
    return best_params, best_score, results_df

# %% [markdown]
# ## Plot chart (vẽ biểu đồ)

# %%
# Plotting the predictions
def plot_data_4(Y_test, Y_hat):
    plt.plot(Y_test, c = 'r')
    plt.plot(Y_hat, c = 'y')
    plt.xlabel('Day')
    plt.ylabel('Price')
    plt.title('Stock Prediction Graph using Multivariate-LSTM model')
    plt.legend(['Actual', 'Predicted'], loc = 'lower right')
    plt.show()

# %%
# Plotting the training errors: trực quan loss qua các epoch -> thấy qtr học mô hình, xem có overfitting ko
def plot_error(train_loss, val_loss):
    plt.plot(train_loss, c = 'r')
    plt.plot(val_loss, c = 'b')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.title('Train Loss and Validation Loss Curve')
    plt.legend(['train', 'val'], loc = 'upper right')
    plt.show()

# %% [markdown]
# ## **Model building**: Xây dựng mô hình

# %% [markdown]
# ### Bước 1: Trích xuất và trực quan hóa dữ liệu

# %%
# Extracting the series
series = df[['close', 'high', 'low', 'CMA10', 'SMA10', 'SMA50', 'EMA12', 'RSI', 'CCI', '%K', '%D', 'MACD']]
# Drop rows with NaN values
series = series.dropna()

# Display the shape and the tail of the cleaned series
print(series.shape)
series.describe()
# Out:
# (4267, 12)
#              close         high          low        CMA10       SMA10  \
# count  4267.000000  4267.000000  4267.000000  4267.000000  4267.00000
# mean     10.025397    10.160349     9.903063    10.022310     9.99800
# std      10.126221    10.264080    10.012208    10.118056    10.10649
# min       0.680000     0.690000     0.680000     0.710000     0.71000
# 25%       1.780000     1.800000     1.760000     1.778000     1.77800
# 50%       5.680000     5.780000     5.610000     5.725000     5.70500
# 75%      15.415000    15.655000    15.275000    15.376000    15.21950
# max      39.900000    40.180000    39.560000    39.285000    39.28500
#
#              SMA50        EMA12          RSI          CCI           %K  \
# count  4267.000000  4267.000000  4267.000000  4267.000000  4267.000000
# mean      9.880565     9.992086    52.254060    12.008518    53.007353
# std      10.019039    10.097556    17.992688   112.438235    30.851704
# min       0.793800     0.726093     0.000000  -486.486486     0.000000
# 25%       1.760400     1.776499    38.724730   -76.041990    25.730277
# 50%       5.174200     5.719069    52.577320    21.806854    55.445545
# 75%      15.065600    15.178271    66.146301   101.156626    80.702355
# max      37.489200    39.090578   100.000000   364.285714   100.000000
#
#                 %D         MACD
# count  4267.000000  4267.000000
# mean     53.000609     0.041366
# std      29.031483     0.373255
# min       0.000000    -1.739242
# 25%      26.681097    -0.045488
# 50%      55.238095     0.020672
# 75%      79.987975     0.119916
# max     100.000000     2.247325

# %% [markdown]
# ### Bước 2: Chia dữ liệu thành các tập Train, Validation, Test

# %%
series.shape
# Out:
# (4267, 12)

# %%
n = series.shape[0]
val_size =  test_size = int(n * 0.15)
train_size = n - val_size - test_size # Để tránh sai số làm mất dữ liệu

# Chia tập dữ liệu theo thứ tự thời gian
train_data = series.iloc[:train_size].values
val_data = series.iloc[train_size:train_size + val_size].values
test_data = series.iloc[(train_size + val_size):].values
# Kiểm tra kích thước của từng tập
print(train_data.shape, val_data.shape, test_data.shape)
# Out:
# (2987, 12) (640, 12) (640, 12)

# %% [markdown]
# ### Bước 3: Chuẩn hóa dữ liệu bằng MinMaxScaler

# %%
np.random.seed(1)
tf.random.set_seed(2)

sc = MinMaxScaler()
train = sc.fit_transform(train_data)
val = sc.transform(val_data)
test = sc.transform(test_data)

print(train.shape, val.shape, test.shape)
# Out:
# (2987, 12) (640, 12) (640, 12)

# %% [markdown]
# ### Bước 4: Tìm siêu tham số tốt nhất bằng Grid Search

# %%
best_params, best_score, results_df = grid_search_rnn(train, val, test, param_grid)

print(results_df)
print("Best parameters:", best_params)
print("Best RMSE score:", best_score)
# Out:
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.001, 'batch_size': 32, 'num_epochs': 200}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss improved from inf to 0.15308, saving model to 10Var_hpg_lstm.h5
#
# Epoch 2: val_loss did not improve from 0.15308
#
# Epoch 3: val_loss did not improve from 0.15308
#
# Epoch 4: val_loss improved from 0.15308 to 0.10063, saving model to 10Var_hpg_lstm.h5
#
# Epoch 5: val_loss did not improve from 0.10063
#
# Epoch 6: val_loss did not improve from 0.10063
#
# Epoch 7: val_loss did not improve from 0.10063
#
# Epoch 8: val_loss did not improve from 0.10063
#
# Epoch 9: val_loss did not improve from 0.10063
#
# Epoch 10: val_loss did not improve from 0.10063
#
# Epoch 11: val_loss did not improve from 0.10063
#
# Epoch 12: val_loss did not improve from 0.10063
#
# Epoch 13: val_loss did not improve from 0.10063
#
# Epoch 14: val_loss did not improve from 0.10063
#
# Epoch 15: val_loss did not improve from 0.10063
#
# Epoch 16: val_loss did not improve from 0.10063
#
# Epoch 17: val_loss did not improve from 0.10063
#
# Epoch 18: val_loss did not improve from 0.10063
#
# Epoch 19: val_loss did not improve from 0.10063
#
# Epoch 20: val_loss did not improve from 0.10063
#
# Epoch 21: val_loss did not improve from 0.10063
#
# Epoch 22: val_loss did not improve from 0.10063
#
# Epoch 23: val_loss did not improve from 0.10063
#
# Epoch 24: val_loss did not improve from 0.10063
#
# Epoch 25: val_loss did not improve from 0.10063
#
# Epoch 26: val_loss did not improve from 0.10063
#
# Epoch 27: val_loss did not improve from 0.10063
#
# Epoch 28: val_loss did not improve from 0.10063
#
# Epoch 29: val_loss did not improve from 0.10063
#
# Epoch 30: val_loss did not improve from 0.10063
#
# Epoch 31: val_loss did not improve from 0.10063
#
# Epoch 32: val_loss did not improve from 0.10063
#
# Epoch 33: val_loss did not improve from 0.10063
#
# Epoch 34: val_loss did not improve from 0.10063
#
# Epoch 35: val_loss did not improve from 0.10063
#
# Epoch 36: val_loss did not improve from 0.10063
#
# Epoch 37: val_loss did not improve from 0.10063
#
# Epoch 38: val_loss did not improve from 0.10063
#
# Epoch 39: val_loss did not improve from 0.10063
#
# Epoch 40: val_loss did not improve from 0.10063
#
# Epoch 41: val_loss did not improve from 0.10063
#
# Epoch 42: val_loss did not improve from 0.10063
#
# Epoch 43: val_loss did not improve from 0.10063
#
# Epoch 44: val_loss did not improve from 0.10063
#
# Epoch 45: val_loss did not improve from 0.10063
#
# Epoch 46: val_loss did not improve from 0.10063
#
# Epoch 47: val_loss did not improve from 0.10063
#
# Epoch 48: val_loss did not improve from 0.10063
#
# Epoch 49: val_loss did not improve from 0.10063
#
# Epoch 50: val_loss did not improve from 0.10063
#
# Epoch 51: val_loss did not improve from 0.10063
#
# Epoch 52: val_loss did not improve from 0.10063
#
# Epoch 53: val_loss did not improve from 0.10063
#
# Epoch 54: val_loss did not improve from 0.10063
#
# Epoch 55: val_loss did not improve from 0.10063
#
# Epoch 56: val_loss did not improve from 0.10063
#
# Epoch 57: val_loss did not improve from 0.10063
#
# Epoch 58: val_loss did not improve from 0.10063
#
# Epoch 59: val_loss did not improve from 0.10063
#
# Epoch 60: val_loss did not improve from 0.10063
#
# Epoch 61: val_loss did not improve from 0.10063
#
# Epoch 62: val_loss did not improve from 0.10063
#
# Epoch 63: val_loss did not improve from 0.10063
#
# Epoch 64: val_loss did not improve from 0.10063
#
# Epoch 65: val_loss did not improve from 0.10063
#
# Epoch 66: val_loss did not improve from 0.10063
#
# Epoch 67: val_loss did not improve from 0.10063
#
# Epoch 68: val_loss did not improve from 0.10063
#
# Epoch 69: val_loss did not improve from 0.10063
#
# Epoch 70: val_loss did not improve from 0.10063
#
# Epoch 71: val_loss did not improve from 0.10063
#
# Epoch 72: val_loss did not improve from 0.10063
#
# Epoch 73: val_loss did not improve from 0.10063
#
# Epoch 74: val_loss did not improve from 0.10063
#
# Epoch 75: val_loss did not improve from 0.10063
#
# Epoch 76: val_loss did not improve from 0.10063
#
# Epoch 77: val_loss did not improve from 0.10063
#
# Epoch 78: val_loss did not improve from 0.10063
#
# Epoch 79: val_loss did not improve from 0.10063
#
# Epoch 80: val_loss did not improve from 0.10063
#
# Epoch 81: val_loss did not improve from 0.10063
#
# Epoch 82: val_loss did not improve from 0.10063
#
# Epoch 83: val_loss did not improve from 0.10063
#
# Epoch 84: val_loss did not improve from 0.10063
# Epoch 84: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.001, 'batch_size': 32, 'num_epochs': 250}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.10063
#
# Epoch 2: val_loss did not improve from 0.10063
#
# Epoch 3: val_loss improved from 0.10063 to 0.07421, saving model to 10Var_hpg_lstm.h5
#
# Epoch 4: val_loss did not improve from 0.07421
#
# Epoch 5: val_loss did not improve from 0.07421
#
# Epoch 6: val_loss did not improve from 0.07421
#
# Epoch 7: val_loss did not improve from 0.07421
#
# Epoch 8: val_loss did not improve from 0.07421
#
# Epoch 9: val_loss did not improve from 0.07421
#
# Epoch 10: val_loss did not improve from 0.07421
#
# Epoch 11: val_loss did not improve from 0.07421
#
# Epoch 12: val_loss did not improve from 0.07421
#
# Epoch 13: val_loss did not improve from 0.07421
#
# Epoch 14: val_loss did not improve from 0.07421
#
# Epoch 15: val_loss did not improve from 0.07421
#
# Epoch 16: val_loss did not improve from 0.07421
#
# Epoch 17: val_loss did not improve from 0.07421
#
# Epoch 18: val_loss did not improve from 0.07421
#
# Epoch 19: val_loss did not improve from 0.07421
#
# Epoch 20: val_loss did not improve from 0.07421
#
# Epoch 21: val_loss did not improve from 0.07421
#
# Epoch 22: val_loss did not improve from 0.07421
#
# Epoch 23: val_loss did not improve from 0.07421
#
# Epoch 24: val_loss did not improve from 0.07421
#
# Epoch 25: val_loss improved from 0.07421 to 0.02260, saving model to 10Var_hpg_lstm.h5
#
# Epoch 26: val_loss did not improve from 0.02260
#
# Epoch 27: val_loss did not improve from 0.02260
#
# Epoch 28: val_loss did not improve from 0.02260
#
# Epoch 29: val_loss did not improve from 0.02260
#
# Epoch 30: val_loss did not improve from 0.02260
#
# Epoch 31: val_loss did not improve from 0.02260
#
# Epoch 32: val_loss did not improve from 0.02260
#
# Epoch 33: val_loss did not improve from 0.02260
#
# Epoch 34: val_loss did not improve from 0.02260
#
# Epoch 35: val_loss improved from 0.02260 to 0.00901, saving model to 10Var_hpg_lstm.h5
#
# Epoch 36: val_loss improved from 0.00901 to 0.00808, saving model to 10Var_hpg_lstm.h5
#
# Epoch 37: val_loss did not improve from 0.00808
#
# Epoch 38: val_loss did not improve from 0.00808
#
# Epoch 39: val_loss did not improve from 0.00808
#
# Epoch 40: val_loss did not improve from 0.00808
#
# Epoch 41: val_loss did not improve from 0.00808
#
# Epoch 42: val_loss did not improve from 0.00808
#
# Epoch 43: val_loss did not improve from 0.00808
#
# Epoch 44: val_loss did not improve from 0.00808
#
# Epoch 45: val_loss did not improve from 0.00808
#
# Epoch 46: val_loss did not improve from 0.00808
#
# Epoch 47: val_loss did not improve from 0.00808
#
# Epoch 48: val_loss did not improve from 0.00808
#
# Epoch 49: val_loss did not improve from 0.00808
#
# Epoch 50: val_loss did not improve from 0.00808
#
# Epoch 51: val_loss did not improve from 0.00808
#
# Epoch 52: val_loss did not improve from 0.00808
#
# Epoch 53: val_loss did not improve from 0.00808
#
# Epoch 54: val_loss did not improve from 0.00808
#
# Epoch 55: val_loss did not improve from 0.00808
#
# Epoch 56: val_loss did not improve from 0.00808
#
# Epoch 57: val_loss did not improve from 0.00808
#
# Epoch 58: val_loss did not improve from 0.00808
#
# Epoch 59: val_loss did not improve from 0.00808
#
# Epoch 60: val_loss did not improve from 0.00808
#
# Epoch 61: val_loss did not improve from 0.00808
#
# Epoch 62: val_loss did not improve from 0.00808
#
# Epoch 63: val_loss did not improve from 0.00808
#
# Epoch 64: val_loss did not improve from 0.00808
#
# Epoch 65: val_loss did not improve from 0.00808
#
# Epoch 66: val_loss did not improve from 0.00808
#
# Epoch 67: val_loss did not improve from 0.00808
#
# Epoch 68: val_loss did not improve from 0.00808
#
# Epoch 69: val_loss did not improve from 0.00808
#
# Epoch 70: val_loss did not improve from 0.00808
#
# Epoch 71: val_loss did not improve from 0.00808
#
# Epoch 72: val_loss did not improve from 0.00808
#
# Epoch 73: val_loss did not improve from 0.00808
#
# Epoch 74: val_loss did not improve from 0.00808
#
# Epoch 75: val_loss did not improve from 0.00808
#
# Epoch 76: val_loss did not improve from 0.00808
#
# Epoch 77: val_loss did not improve from 0.00808
#
# Epoch 78: val_loss did not improve from 0.00808
#
# Epoch 79: val_loss did not improve from 0.00808
#
# Epoch 80: val_loss did not improve from 0.00808
#
# Epoch 81: val_loss did not improve from 0.00808
#
# Epoch 82: val_loss did not improve from 0.00808
#
# Epoch 83: val_loss did not improve from 0.00808
#
# Epoch 84: val_loss did not improve from 0.00808
#
# Epoch 85: val_loss did not improve from 0.00808
#
# Epoch 86: val_loss did not improve from 0.00808
#
# Epoch 87: val_loss did not improve from 0.00808
#
# Epoch 88: val_loss did not improve from 0.00808
#
# Epoch 89: val_loss did not improve from 0.00808
#
# Epoch 90: val_loss did not improve from 0.00808
#
# Epoch 91: val_loss did not improve from 0.00808
#
# Epoch 92: val_loss did not improve from 0.00808
#
# Epoch 93: val_loss did not improve from 0.00808
#
# Epoch 94: val_loss did not improve from 0.00808
#
# Epoch 95: val_loss did not improve from 0.00808
#
# Epoch 96: val_loss did not improve from 0.00808
#
# Epoch 97: val_loss did not improve from 0.00808
#
# Epoch 98: val_loss did not improve from 0.00808
#
# Epoch 99: val_loss did not improve from 0.00808
#
# Epoch 100: val_loss did not improve from 0.00808
#
# Epoch 101: val_loss did not improve from 0.00808
#
# Epoch 102: val_loss did not improve from 0.00808
#
# Epoch 103: val_loss did not improve from 0.00808
#
# Epoch 104: val_loss did not improve from 0.00808
#
# Epoch 105: val_loss did not improve from 0.00808
#
# Epoch 106: val_loss did not improve from 0.00808
#
# Epoch 107: val_loss did not improve from 0.00808
#
# Epoch 108: val_loss did not improve from 0.00808
#
# Epoch 109: val_loss did not improve from 0.00808
#
# Epoch 110: val_loss did not improve from 0.00808
#
# Epoch 111: val_loss did not improve from 0.00808
#
# Epoch 112: val_loss did not improve from 0.00808
#
# Epoch 113: val_loss did not improve from 0.00808
#
# Epoch 114: val_loss did not improve from 0.00808
#
# Epoch 115: val_loss did not improve from 0.00808
#
# Epoch 116: val_loss did not improve from 0.00808
# Epoch 116: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.001, 'batch_size': 64, 'num_epochs': 200}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00808
#
# Epoch 2: val_loss did not improve from 0.00808
#
# Epoch 3: val_loss did not improve from 0.00808
#
# Epoch 4: val_loss did not improve from 0.00808
#
# Epoch 5: val_loss did not improve from 0.00808
#
# Epoch 6: val_loss did not improve from 0.00808
#
# Epoch 7: val_loss did not improve from 0.00808
#
# Epoch 8: val_loss did not improve from 0.00808
#
# Epoch 9: val_loss did not improve from 0.00808
#
# Epoch 10: val_loss did not improve from 0.00808
#
# Epoch 11: val_loss did not improve from 0.00808
#
# Epoch 12: val_loss did not improve from 0.00808
#
# Epoch 13: val_loss did not improve from 0.00808
#
# Epoch 14: val_loss did not improve from 0.00808
#
# Epoch 15: val_loss did not improve from 0.00808
#
# Epoch 16: val_loss did not improve from 0.00808
#
# Epoch 17: val_loss did not improve from 0.00808
#
# Epoch 18: val_loss did not improve from 0.00808
#
# Epoch 19: val_loss did not improve from 0.00808
#
# Epoch 20: val_loss did not improve from 0.00808
#
# Epoch 21: val_loss did not improve from 0.00808
#
# Epoch 22: val_loss did not improve from 0.00808
#
# Epoch 23: val_loss did not improve from 0.00808
#
# Epoch 24: val_loss did not improve from 0.00808
#
# Epoch 25: val_loss did not improve from 0.00808
#
# Epoch 26: val_loss did not improve from 0.00808
#
# Epoch 27: val_loss did not improve from 0.00808
#
# Epoch 28: val_loss did not improve from 0.00808
#
# Epoch 29: val_loss did not improve from 0.00808
#
# Epoch 30: val_loss did not improve from 0.00808
#
# Epoch 31: val_loss did not improve from 0.00808
#
# Epoch 32: val_loss did not improve from 0.00808
#
# Epoch 33: val_loss did not improve from 0.00808
#
# Epoch 34: val_loss did not improve from 0.00808
#
# Epoch 35: val_loss did not improve from 0.00808
#
# Epoch 36: val_loss did not improve from 0.00808
#
# Epoch 37: val_loss did not improve from 0.00808
#
# Epoch 38: val_loss did not improve from 0.00808
#
# Epoch 39: val_loss did not improve from 0.00808
#
# Epoch 40: val_loss did not improve from 0.00808
#
# Epoch 41: val_loss did not improve from 0.00808
#
# Epoch 42: val_loss did not improve from 0.00808
#
# Epoch 43: val_loss did not improve from 0.00808
#
# Epoch 44: val_loss did not improve from 0.00808
#
# Epoch 45: val_loss did not improve from 0.00808
#
# Epoch 46: val_loss did not improve from 0.00808
#
# Epoch 47: val_loss did not improve from 0.00808
#
# Epoch 48: val_loss did not improve from 0.00808
#
# Epoch 49: val_loss did not improve from 0.00808
#
# Epoch 50: val_loss did not improve from 0.00808
#
# Epoch 51: val_loss did not improve from 0.00808
#
# Epoch 52: val_loss did not improve from 0.00808
#
# Epoch 53: val_loss did not improve from 0.00808
#
# Epoch 54: val_loss did not improve from 0.00808
#
# Epoch 55: val_loss did not improve from 0.00808
#
# Epoch 56: val_loss did not improve from 0.00808
#
# Epoch 57: val_loss did not improve from 0.00808
#
# Epoch 58: val_loss did not improve from 0.00808
#
# Epoch 59: val_loss did not improve from 0.00808
#
# Epoch 60: val_loss did not improve from 0.00808
#
# Epoch 61: val_loss did not improve from 0.00808
#
# Epoch 62: val_loss did not improve from 0.00808
#
# Epoch 63: val_loss did not improve from 0.00808
#
# Epoch 64: val_loss did not improve from 0.00808
#
# Epoch 65: val_loss did not improve from 0.00808
#
# Epoch 66: val_loss did not improve from 0.00808
#
# Epoch 67: val_loss did not improve from 0.00808
#
# Epoch 68: val_loss did not improve from 0.00808
#
# Epoch 69: val_loss did not improve from 0.00808
#
# Epoch 70: val_loss did not improve from 0.00808
#
# Epoch 71: val_loss did not improve from 0.00808
#
# Epoch 72: val_loss did not improve from 0.00808
#
# Epoch 73: val_loss did not improve from 0.00808
#
# Epoch 74: val_loss did not improve from 0.00808
#
# Epoch 75: val_loss did not improve from 0.00808
#
# Epoch 76: val_loss did not improve from 0.00808
#
# Epoch 77: val_loss did not improve from 0.00808
#
# Epoch 78: val_loss did not improve from 0.00808
#
# Epoch 79: val_loss did not improve from 0.00808
#
# Epoch 80: val_loss did not improve from 0.00808
#
# Epoch 81: val_loss did not improve from 0.00808
#
# Epoch 82: val_loss did not improve from 0.00808
#
# Epoch 83: val_loss did not improve from 0.00808
#
# Epoch 84: val_loss did not improve from 0.00808
#
# Epoch 85: val_loss did not improve from 0.00808
#
# Epoch 86: val_loss did not improve from 0.00808
#
# Epoch 87: val_loss did not improve from 0.00808
#
# Epoch 88: val_loss did not improve from 0.00808
#
# Epoch 89: val_loss did not improve from 0.00808
#
# Epoch 90: val_loss did not improve from 0.00808
#
# Epoch 91: val_loss did not improve from 0.00808
#
# Epoch 92: val_loss did not improve from 0.00808
#
# Epoch 93: val_loss did not improve from 0.00808
#
# Epoch 94: val_loss did not improve from 0.00808
#
# Epoch 95: val_loss did not improve from 0.00808
#
# Epoch 96: val_loss did not improve from 0.00808
#
# Epoch 97: val_loss did not improve from 0.00808
#
# Epoch 98: val_loss did not improve from 0.00808
#
# Epoch 99: val_loss did not improve from 0.00808
#
# Epoch 100: val_loss did not improve from 0.00808
#
# Epoch 101: val_loss did not improve from 0.00808
#
# Epoch 102: val_loss did not improve from 0.00808
#
# Epoch 103: val_loss did not improve from 0.00808
#
# Epoch 104: val_loss did not improve from 0.00808
#
# Epoch 105: val_loss did not improve from 0.00808
#
# Epoch 106: val_loss did not improve from 0.00808
#
# Epoch 107: val_loss did not improve from 0.00808
#
# Epoch 108: val_loss did not improve from 0.00808
#
# Epoch 109: val_loss did not improve from 0.00808
#
# Epoch 110: val_loss did not improve from 0.00808
#
# Epoch 111: val_loss did not improve from 0.00808
#
# Epoch 112: val_loss did not improve from 0.00808
#
# Epoch 113: val_loss did not improve from 0.00808
#
# Epoch 114: val_loss did not improve from 0.00808
#
# Epoch 115: val_loss did not improve from 0.00808
#
# Epoch 116: val_loss did not improve from 0.00808
#
# Epoch 117: val_loss did not improve from 0.00808
#
# Epoch 118: val_loss did not improve from 0.00808
#
# Epoch 119: val_loss did not improve from 0.00808
#
# Epoch 120: val_loss did not improve from 0.00808
#
# Epoch 121: val_loss did not improve from 0.00808
#
# Epoch 122: val_loss did not improve from 0.00808
#
# Epoch 123: val_loss did not improve from 0.00808
#
# Epoch 124: val_loss did not improve from 0.00808
#
# Epoch 125: val_loss did not improve from 0.00808
#
# Epoch 126: val_loss did not improve from 0.00808
#
# Epoch 127: val_loss did not improve from 0.00808
#
# Epoch 128: val_loss did not improve from 0.00808
#
# Epoch 129: val_loss did not improve from 0.00808
#
# Epoch 130: val_loss did not improve from 0.00808
#
# Epoch 131: val_loss did not improve from 0.00808
#
# Epoch 132: val_loss did not improve from 0.00808
#
# Epoch 133: val_loss did not improve from 0.00808
#
# Epoch 134: val_loss did not improve from 0.00808
#
# Epoch 135: val_loss did not improve from 0.00808
#
# Epoch 136: val_loss did not improve from 0.00808
#
# Epoch 137: val_loss did not improve from 0.00808
#
# Epoch 138: val_loss did not improve from 0.00808
#
# Epoch 139: val_loss did not improve from 0.00808
#
# Epoch 140: val_loss did not improve from 0.00808
#
# Epoch 141: val_loss did not improve from 0.00808
#
# Epoch 142: val_loss did not improve from 0.00808
#
# Epoch 143: val_loss did not improve from 0.00808
#
# Epoch 144: val_loss did not improve from 0.00808
#
# Epoch 145: val_loss did not improve from 0.00808
#
# Epoch 146: val_loss did not improve from 0.00808
#
# Epoch 147: val_loss did not improve from 0.00808
#
# Epoch 148: val_loss did not improve from 0.00808
#
# Epoch 149: val_loss did not improve from 0.00808
#
# Epoch 150: val_loss did not improve from 0.00808
#
# Epoch 151: val_loss did not improve from 0.00808
#
# Epoch 152: val_loss did not improve from 0.00808
#
# Epoch 153: val_loss did not improve from 0.00808
#
# Epoch 154: val_loss did not improve from 0.00808
#
# Epoch 155: val_loss did not improve from 0.00808
#
# Epoch 156: val_loss did not improve from 0.00808
#
# Epoch 157: val_loss did not improve from 0.00808
#
# Epoch 158: val_loss did not improve from 0.00808
#
# Epoch 159: val_loss did not improve from 0.00808
#
# Epoch 160: val_loss did not improve from 0.00808
#
# Epoch 161: val_loss did not improve from 0.00808
#
# Epoch 162: val_loss did not improve from 0.00808
#
# Epoch 163: val_loss did not improve from 0.00808
#
# Epoch 164: val_loss did not improve from 0.00808
#
# Epoch 165: val_loss did not improve from 0.00808
#
# Epoch 166: val_loss did not improve from 0.00808
#
# Epoch 167: val_loss did not improve from 0.00808
#
# Epoch 168: val_loss did not improve from 0.00808
#
# Epoch 169: val_loss did not improve from 0.00808
#
# Epoch 170: val_loss did not improve from 0.00808
#
# Epoch 171: val_loss did not improve from 0.00808
#
# Epoch 172: val_loss did not improve from 0.00808
#
# Epoch 173: val_loss did not improve from 0.00808
#
# Epoch 174: val_loss did not improve from 0.00808
#
# Epoch 175: val_loss did not improve from 0.00808
#
# Epoch 176: val_loss did not improve from 0.00808
#
# Epoch 177: val_loss did not improve from 0.00808
#
# Epoch 178: val_loss did not improve from 0.00808
#
# Epoch 179: val_loss did not improve from 0.00808
#
# Epoch 180: val_loss did not improve from 0.00808
#
# Epoch 181: val_loss did not improve from 0.00808
# Epoch 181: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.001, 'batch_size': 64, 'num_epochs': 250}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00808
#
# Epoch 2: val_loss did not improve from 0.00808
#
# Epoch 3: val_loss did not improve from 0.00808
#
# Epoch 4: val_loss did not improve from 0.00808
#
# Epoch 5: val_loss did not improve from 0.00808
#
# Epoch 6: val_loss did not improve from 0.00808
#
# Epoch 7: val_loss did not improve from 0.00808
#
# Epoch 8: val_loss did not improve from 0.00808
#
# Epoch 9: val_loss did not improve from 0.00808
#
# Epoch 10: val_loss did not improve from 0.00808
#
# Epoch 11: val_loss did not improve from 0.00808
#
# Epoch 12: val_loss did not improve from 0.00808
#
# Epoch 13: val_loss did not improve from 0.00808
#
# Epoch 14: val_loss did not improve from 0.00808
#
# Epoch 15: val_loss did not improve from 0.00808
#
# Epoch 16: val_loss did not improve from 0.00808
#
# Epoch 17: val_loss did not improve from 0.00808
#
# Epoch 18: val_loss did not improve from 0.00808
#
# Epoch 19: val_loss did not improve from 0.00808
#
# Epoch 20: val_loss did not improve from 0.00808
#
# Epoch 21: val_loss did not improve from 0.00808
#
# Epoch 22: val_loss did not improve from 0.00808
#
# Epoch 23: val_loss did not improve from 0.00808
#
# Epoch 24: val_loss did not improve from 0.00808
#
# Epoch 25: val_loss did not improve from 0.00808
#
# Epoch 26: val_loss did not improve from 0.00808
#
# Epoch 27: val_loss did not improve from 0.00808
#
# Epoch 28: val_loss did not improve from 0.00808
#
# Epoch 29: val_loss did not improve from 0.00808
#
# Epoch 30: val_loss did not improve from 0.00808
#
# Epoch 31: val_loss did not improve from 0.00808
#
# Epoch 32: val_loss did not improve from 0.00808
#
# Epoch 33: val_loss did not improve from 0.00808
#
# Epoch 34: val_loss did not improve from 0.00808
#
# Epoch 35: val_loss did not improve from 0.00808
#
# Epoch 36: val_loss did not improve from 0.00808
#
# Epoch 37: val_loss did not improve from 0.00808
#
# Epoch 38: val_loss did not improve from 0.00808
#
# Epoch 39: val_loss did not improve from 0.00808
#
# Epoch 40: val_loss did not improve from 0.00808
#
# Epoch 41: val_loss did not improve from 0.00808
#
# Epoch 42: val_loss did not improve from 0.00808
#
# Epoch 43: val_loss did not improve from 0.00808
#
# Epoch 44: val_loss did not improve from 0.00808
#
# Epoch 45: val_loss did not improve from 0.00808
#
# Epoch 46: val_loss did not improve from 0.00808
#
# Epoch 47: val_loss did not improve from 0.00808
#
# Epoch 48: val_loss did not improve from 0.00808
#
# Epoch 49: val_loss did not improve from 0.00808
#
# Epoch 50: val_loss did not improve from 0.00808
#
# Epoch 51: val_loss did not improve from 0.00808
#
# Epoch 52: val_loss did not improve from 0.00808
#
# Epoch 53: val_loss did not improve from 0.00808
#
# Epoch 54: val_loss did not improve from 0.00808
#
# Epoch 55: val_loss did not improve from 0.00808
#
# Epoch 56: val_loss did not improve from 0.00808
#
# Epoch 57: val_loss did not improve from 0.00808
#
# Epoch 58: val_loss did not improve from 0.00808
#
# Epoch 59: val_loss did not improve from 0.00808
#
# Epoch 60: val_loss did not improve from 0.00808
#
# Epoch 61: val_loss did not improve from 0.00808
#
# Epoch 62: val_loss did not improve from 0.00808
#
# Epoch 63: val_loss did not improve from 0.00808
#
# Epoch 64: val_loss did not improve from 0.00808
#
# Epoch 65: val_loss did not improve from 0.00808
#
# Epoch 66: val_loss did not improve from 0.00808
#
# Epoch 67: val_loss did not improve from 0.00808
#
# Epoch 68: val_loss did not improve from 0.00808
#
# Epoch 69: val_loss did not improve from 0.00808
#
# Epoch 70: val_loss did not improve from 0.00808
#
# Epoch 71: val_loss did not improve from 0.00808
#
# Epoch 72: val_loss did not improve from 0.00808
#
# Epoch 73: val_loss did not improve from 0.00808
#
# Epoch 74: val_loss did not improve from 0.00808
#
# Epoch 75: val_loss did not improve from 0.00808
#
# Epoch 76: val_loss did not improve from 0.00808
#
# Epoch 77: val_loss did not improve from 0.00808
#
# Epoch 78: val_loss did not improve from 0.00808
#
# Epoch 79: val_loss did not improve from 0.00808
#
# Epoch 80: val_loss did not improve from 0.00808
#
# Epoch 81: val_loss did not improve from 0.00808
#
# Epoch 82: val_loss did not improve from 0.00808
#
# Epoch 83: val_loss did not improve from 0.00808
#
# Epoch 84: val_loss did not improve from 0.00808
#
# Epoch 85: val_loss did not improve from 0.00808
#
# Epoch 86: val_loss did not improve from 0.00808
#
# Epoch 87: val_loss did not improve from 0.00808
#
# Epoch 88: val_loss did not improve from 0.00808
#
# Epoch 89: val_loss did not improve from 0.00808
#
# Epoch 90: val_loss did not improve from 0.00808
#
# Epoch 91: val_loss did not improve from 0.00808
#
# Epoch 92: val_loss did not improve from 0.00808
#
# Epoch 93: val_loss did not improve from 0.00808
#
# Epoch 94: val_loss did not improve from 0.00808
#
# Epoch 95: val_loss did not improve from 0.00808
#
# Epoch 96: val_loss did not improve from 0.00808
#
# Epoch 97: val_loss did not improve from 0.00808
#
# Epoch 98: val_loss did not improve from 0.00808
#
# Epoch 99: val_loss did not improve from 0.00808
#
# Epoch 100: val_loss did not improve from 0.00808
#
# Epoch 101: val_loss did not improve from 0.00808
#
# Epoch 102: val_loss did not improve from 0.00808
#
# Epoch 103: val_loss did not improve from 0.00808
#
# Epoch 104: val_loss did not improve from 0.00808
#
# Epoch 105: val_loss did not improve from 0.00808
#
# Epoch 106: val_loss did not improve from 0.00808
#
# Epoch 107: val_loss did not improve from 0.00808
#
# Epoch 108: val_loss did not improve from 0.00808
#
# Epoch 109: val_loss did not improve from 0.00808
#
# Epoch 110: val_loss did not improve from 0.00808
#
# Epoch 111: val_loss did not improve from 0.00808
#
# Epoch 112: val_loss did not improve from 0.00808
#
# Epoch 113: val_loss did not improve from 0.00808
#
# Epoch 114: val_loss did not improve from 0.00808
#
# Epoch 115: val_loss did not improve from 0.00808
#
# Epoch 116: val_loss did not improve from 0.00808
#
# Epoch 117: val_loss did not improve from 0.00808
#
# Epoch 118: val_loss did not improve from 0.00808
#
# Epoch 119: val_loss did not improve from 0.00808
#
# Epoch 120: val_loss did not improve from 0.00808
#
# Epoch 121: val_loss did not improve from 0.00808
#
# Epoch 122: val_loss did not improve from 0.00808
#
# Epoch 123: val_loss did not improve from 0.00808
#
# Epoch 124: val_loss did not improve from 0.00808
#
# Epoch 125: val_loss did not improve from 0.00808
#
# Epoch 126: val_loss did not improve from 0.00808
#
# Epoch 127: val_loss did not improve from 0.00808
#
# Epoch 128: val_loss did not improve from 0.00808
#
# Epoch 129: val_loss did not improve from 0.00808
#
# Epoch 130: val_loss did not improve from 0.00808
#
# Epoch 131: val_loss did not improve from 0.00808
#
# Epoch 132: val_loss did not improve from 0.00808
#
# Epoch 133: val_loss did not improve from 0.00808
#
# Epoch 134: val_loss did not improve from 0.00808
#
# Epoch 135: val_loss did not improve from 0.00808
#
# Epoch 136: val_loss did not improve from 0.00808
#
# Epoch 137: val_loss did not improve from 0.00808
#
# Epoch 138: val_loss did not improve from 0.00808
#
# Epoch 139: val_loss did not improve from 0.00808
#
# Epoch 140: val_loss did not improve from 0.00808
#
# Epoch 141: val_loss did not improve from 0.00808
#
# Epoch 142: val_loss did not improve from 0.00808
#
# Epoch 143: val_loss did not improve from 0.00808
#
# Epoch 144: val_loss did not improve from 0.00808
#
# Epoch 145: val_loss did not improve from 0.00808
#
# Epoch 146: val_loss did not improve from 0.00808
#
# Epoch 147: val_loss did not improve from 0.00808
#
# Epoch 148: val_loss did not improve from 0.00808
#
# Epoch 149: val_loss did not improve from 0.00808
#
# Epoch 150: val_loss did not improve from 0.00808
#
# Epoch 151: val_loss did not improve from 0.00808
#
# Epoch 152: val_loss did not improve from 0.00808
#
# Epoch 153: val_loss did not improve from 0.00808
#
# Epoch 154: val_loss did not improve from 0.00808
#
# Epoch 155: val_loss did not improve from 0.00808
#
# Epoch 156: val_loss did not improve from 0.00808
#
# Epoch 157: val_loss did not improve from 0.00808
#
# Epoch 158: val_loss did not improve from 0.00808
#
# Epoch 159: val_loss did not improve from 0.00808
#
# Epoch 160: val_loss did not improve from 0.00808
#
# Epoch 161: val_loss did not improve from 0.00808
#
# Epoch 162: val_loss did not improve from 0.00808
#
# Epoch 163: val_loss did not improve from 0.00808
#
# Epoch 164: val_loss did not improve from 0.00808
#
# Epoch 165: val_loss did not improve from 0.00808
#
# Epoch 166: val_loss did not improve from 0.00808
#
# Epoch 167: val_loss did not improve from 0.00808
#
# Epoch 168: val_loss did not improve from 0.00808
#
# Epoch 169: val_loss did not improve from 0.00808
#
# Epoch 170: val_loss did not improve from 0.00808
#
# Epoch 171: val_loss did not improve from 0.00808
#
# Epoch 172: val_loss did not improve from 0.00808
#
# Epoch 173: val_loss did not improve from 0.00808
#
# Epoch 174: val_loss did not improve from 0.00808
#
# Epoch 175: val_loss did not improve from 0.00808
#
# Epoch 176: val_loss did not improve from 0.00808
#
# Epoch 177: val_loss did not improve from 0.00808
#
# Epoch 178: val_loss did not improve from 0.00808
#
# Epoch 179: val_loss did not improve from 0.00808
#
# Epoch 180: val_loss did not improve from 0.00808
#
# Epoch 181: val_loss did not improve from 0.00808
#
# Epoch 182: val_loss did not improve from 0.00808
#
# Epoch 183: val_loss did not improve from 0.00808
#
# Epoch 184: val_loss did not improve from 0.00808
#
# Epoch 185: val_loss did not improve from 0.00808
#
# Epoch 186: val_loss did not improve from 0.00808
#
# Epoch 187: val_loss did not improve from 0.00808
#
# Epoch 188: val_loss did not improve from 0.00808
#
# Epoch 189: val_loss did not improve from 0.00808
#
# Epoch 190: val_loss did not improve from 0.00808
#
# Epoch 191: val_loss did not improve from 0.00808
#
# Epoch 192: val_loss did not improve from 0.00808
#
# Epoch 193: val_loss did not improve from 0.00808
#
# Epoch 194: val_loss did not improve from 0.00808
#
# Epoch 195: val_loss did not improve from 0.00808
#
# Epoch 196: val_loss did not improve from 0.00808
#
# Epoch 197: val_loss did not improve from 0.00808
#
# Epoch 198: val_loss did not improve from 0.00808
#
# Epoch 199: val_loss did not improve from 0.00808
#
# Epoch 200: val_loss did not improve from 0.00808
#
# Epoch 201: val_loss did not improve from 0.00808
#
# Epoch 202: val_loss did not improve from 0.00808
#
# Epoch 203: val_loss did not improve from 0.00808
#
# Epoch 204: val_loss did not improve from 0.00808
#
# Epoch 205: val_loss did not improve from 0.00808
#
# Epoch 206: val_loss did not improve from 0.00808
#
# Epoch 207: val_loss did not improve from 0.00808
#
# Epoch 208: val_loss did not improve from 0.00808
# Epoch 208: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 32, 'num_epochs': 200}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00808
#
# Epoch 2: val_loss did not improve from 0.00808
#
# Epoch 3: val_loss did not improve from 0.00808
#
# Epoch 4: val_loss did not improve from 0.00808
#
# Epoch 5: val_loss did not improve from 0.00808
#
# Epoch 6: val_loss did not improve from 0.00808
#
# Epoch 7: val_loss did not improve from 0.00808
#
# Epoch 8: val_loss did not improve from 0.00808
#
# Epoch 9: val_loss did not improve from 0.00808
#
# Epoch 10: val_loss did not improve from 0.00808
#
# Epoch 11: val_loss did not improve from 0.00808
#
# Epoch 12: val_loss did not improve from 0.00808
#
# Epoch 13: val_loss did not improve from 0.00808
#
# Epoch 14: val_loss did not improve from 0.00808
#
# Epoch 15: val_loss did not improve from 0.00808
#
# Epoch 16: val_loss did not improve from 0.00808
#
# Epoch 17: val_loss did not improve from 0.00808
#
# Epoch 18: val_loss did not improve from 0.00808
#
# Epoch 19: val_loss did not improve from 0.00808
#
# Epoch 20: val_loss did not improve from 0.00808
#
# Epoch 21: val_loss did not improve from 0.00808
#
# Epoch 22: val_loss did not improve from 0.00808
#
# Epoch 23: val_loss did not improve from 0.00808
#
# Epoch 24: val_loss did not improve from 0.00808
#
# Epoch 25: val_loss did not improve from 0.00808
#
# Epoch 26: val_loss did not improve from 0.00808
#
# Epoch 27: val_loss did not improve from 0.00808
#
# Epoch 28: val_loss did not improve from 0.00808
#
# Epoch 29: val_loss did not improve from 0.00808
#
# Epoch 30: val_loss did not improve from 0.00808
#
# Epoch 31: val_loss did not improve from 0.00808
#
# Epoch 32: val_loss did not improve from 0.00808
#
# Epoch 33: val_loss did not improve from 0.00808
#
# Epoch 34: val_loss did not improve from 0.00808
#
# Epoch 35: val_loss did not improve from 0.00808
#
# Epoch 36: val_loss did not improve from 0.00808
#
# Epoch 37: val_loss did not improve from 0.00808
#
# Epoch 38: val_loss did not improve from 0.00808
#
# Epoch 39: val_loss did not improve from 0.00808
#
# Epoch 40: val_loss did not improve from 0.00808
#
# Epoch 41: val_loss did not improve from 0.00808
#
# Epoch 42: val_loss did not improve from 0.00808
#
# Epoch 43: val_loss did not improve from 0.00808
#
# Epoch 44: val_loss did not improve from 0.00808
#
# Epoch 45: val_loss did not improve from 0.00808
#
# Epoch 46: val_loss did not improve from 0.00808
#
# Epoch 47: val_loss did not improve from 0.00808
#
# Epoch 48: val_loss did not improve from 0.00808
#
# Epoch 49: val_loss did not improve from 0.00808
#
# Epoch 50: val_loss did not improve from 0.00808
#
# Epoch 51: val_loss did not improve from 0.00808
#
# Epoch 52: val_loss did not improve from 0.00808
#
# Epoch 53: val_loss did not improve from 0.00808
#
# Epoch 54: val_loss did not improve from 0.00808
#
# Epoch 55: val_loss did not improve from 0.00808
#
# Epoch 56: val_loss did not improve from 0.00808
#
# Epoch 57: val_loss did not improve from 0.00808
#
# Epoch 58: val_loss did not improve from 0.00808
#
# Epoch 59: val_loss did not improve from 0.00808
#
# Epoch 60: val_loss did not improve from 0.00808
#
# Epoch 61: val_loss did not improve from 0.00808
#
# Epoch 62: val_loss did not improve from 0.00808
#
# Epoch 63: val_loss did not improve from 0.00808
#
# Epoch 64: val_loss did not improve from 0.00808
#
# Epoch 65: val_loss did not improve from 0.00808
#
# Epoch 66: val_loss did not improve from 0.00808
#
# Epoch 67: val_loss did not improve from 0.00808
#
# Epoch 68: val_loss did not improve from 0.00808
#
# Epoch 69: val_loss did not improve from 0.00808
#
# Epoch 70: val_loss did not improve from 0.00808
#
# Epoch 71: val_loss did not improve from 0.00808
#
# Epoch 72: val_loss did not improve from 0.00808
#
# Epoch 73: val_loss did not improve from 0.00808
#
# Epoch 74: val_loss did not improve from 0.00808
#
# Epoch 75: val_loss did not improve from 0.00808
#
# Epoch 76: val_loss did not improve from 0.00808
#
# Epoch 77: val_loss did not improve from 0.00808
#
# Epoch 78: val_loss did not improve from 0.00808
#
# Epoch 79: val_loss did not improve from 0.00808
#
# Epoch 80: val_loss did not improve from 0.00808
#
# Epoch 81: val_loss did not improve from 0.00808
#
# Epoch 82: val_loss did not improve from 0.00808
#
# Epoch 83: val_loss did not improve from 0.00808
#
# Epoch 84: val_loss did not improve from 0.00808
#
# Epoch 85: val_loss did not improve from 0.00808
#
# Epoch 86: val_loss did not improve from 0.00808
#
# Epoch 87: val_loss did not improve from 0.00808
#
# Epoch 88: val_loss did not improve from 0.00808
#
# Epoch 89: val_loss did not improve from 0.00808
#
# Epoch 90: val_loss did not improve from 0.00808
#
# Epoch 91: val_loss did not improve from 0.00808
#
# Epoch 92: val_loss did not improve from 0.00808
#
# Epoch 93: val_loss did not improve from 0.00808
#
# Epoch 94: val_loss did not improve from 0.00808
#
# Epoch 95: val_loss did not improve from 0.00808
#
# Epoch 96: val_loss did not improve from 0.00808
#
# Epoch 97: val_loss did not improve from 0.00808
#
# Epoch 98: val_loss did not improve from 0.00808
#
# Epoch 99: val_loss did not improve from 0.00808
#
# Epoch 100: val_loss did not improve from 0.00808
#
# Epoch 101: val_loss did not improve from 0.00808
#
# Epoch 102: val_loss did not improve from 0.00808
#
# Epoch 103: val_loss did not improve from 0.00808
#
# Epoch 104: val_loss did not improve from 0.00808
#
# Epoch 105: val_loss did not improve from 0.00808
#
# Epoch 106: val_loss did not improve from 0.00808
#
# Epoch 107: val_loss did not improve from 0.00808
#
# Epoch 108: val_loss did not improve from 0.00808
#
# Epoch 109: val_loss did not improve from 0.00808
#
# Epoch 110: val_loss did not improve from 0.00808
#
# Epoch 111: val_loss did not improve from 0.00808
#
# Epoch 112: val_loss did not improve from 0.00808
#
# Epoch 113: val_loss did not improve from 0.00808
#
# Epoch 114: val_loss did not improve from 0.00808
#
# Epoch 115: val_loss did not improve from 0.00808
#
# Epoch 116: val_loss did not improve from 0.00808
#
# Epoch 117: val_loss did not improve from 0.00808
#
# Epoch 118: val_loss did not improve from 0.00808
#
# Epoch 119: val_loss did not improve from 0.00808
#
# Epoch 120: val_loss did not improve from 0.00808
#
# Epoch 121: val_loss did not improve from 0.00808
#
# Epoch 122: val_loss did not improve from 0.00808
#
# Epoch 123: val_loss did not improve from 0.00808
#
# Epoch 124: val_loss did not improve from 0.00808
#
# Epoch 125: val_loss did not improve from 0.00808
#
# Epoch 126: val_loss did not improve from 0.00808
#
# Epoch 127: val_loss did not improve from 0.00808
#
# Epoch 128: val_loss did not improve from 0.00808
#
# Epoch 129: val_loss did not improve from 0.00808
#
# Epoch 130: val_loss did not improve from 0.00808
#
# Epoch 131: val_loss did not improve from 0.00808
#
# Epoch 132: val_loss did not improve from 0.00808
#
# Epoch 133: val_loss did not improve from 0.00808
#
# Epoch 134: val_loss did not improve from 0.00808
#
# Epoch 135: val_loss did not improve from 0.00808
#
# Epoch 136: val_loss did not improve from 0.00808
#
# Epoch 137: val_loss did not improve from 0.00808
#
# Epoch 138: val_loss did not improve from 0.00808
#
# Epoch 139: val_loss did not improve from 0.00808
#
# Epoch 140: val_loss did not improve from 0.00808
#
# Epoch 141: val_loss did not improve from 0.00808
#
# Epoch 142: val_loss did not improve from 0.00808
#
# Epoch 143: val_loss did not improve from 0.00808
#
# Epoch 144: val_loss did not improve from 0.00808
#
# Epoch 145: val_loss did not improve from 0.00808
#
# Epoch 146: val_loss did not improve from 0.00808
#
# Epoch 147: val_loss did not improve from 0.00808
#
# Epoch 148: val_loss did not improve from 0.00808
#
# Epoch 149: val_loss did not improve from 0.00808
#
# Epoch 150: val_loss did not improve from 0.00808
#
# Epoch 151: val_loss did not improve from 0.00808
#
# Epoch 152: val_loss did not improve from 0.00808
#
# Epoch 153: val_loss did not improve from 0.00808
#
# Epoch 154: val_loss did not improve from 0.00808
#
# Epoch 155: val_loss did not improve from 0.00808
#
# Epoch 156: val_loss did not improve from 0.00808
#
# Epoch 157: val_loss did not improve from 0.00808
#
# Epoch 158: val_loss did not improve from 0.00808
#
# Epoch 159: val_loss did not improve from 0.00808
#
# Epoch 160: val_loss did not improve from 0.00808
#
# Epoch 161: val_loss did not improve from 0.00808
# Epoch 161: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 32, 'num_epochs': 250}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00808
#
# Epoch 2: val_loss did not improve from 0.00808
#
# Epoch 3: val_loss did not improve from 0.00808
#
# Epoch 4: val_loss did not improve from 0.00808
#
# Epoch 5: val_loss did not improve from 0.00808
#
# Epoch 6: val_loss did not improve from 0.00808
#
# Epoch 7: val_loss did not improve from 0.00808
#
# Epoch 8: val_loss did not improve from 0.00808
#
# Epoch 9: val_loss did not improve from 0.00808
#
# Epoch 10: val_loss did not improve from 0.00808
#
# Epoch 11: val_loss did not improve from 0.00808
#
# Epoch 12: val_loss did not improve from 0.00808
#
# Epoch 13: val_loss did not improve from 0.00808
#
# Epoch 14: val_loss did not improve from 0.00808
#
# Epoch 15: val_loss did not improve from 0.00808
#
# Epoch 16: val_loss did not improve from 0.00808
#
# Epoch 17: val_loss did not improve from 0.00808
#
# Epoch 18: val_loss did not improve from 0.00808
#
# Epoch 19: val_loss did not improve from 0.00808
#
# Epoch 20: val_loss did not improve from 0.00808
#
# Epoch 21: val_loss did not improve from 0.00808
#
# Epoch 22: val_loss did not improve from 0.00808
#
# Epoch 23: val_loss did not improve from 0.00808
#
# Epoch 24: val_loss did not improve from 0.00808
#
# Epoch 25: val_loss did not improve from 0.00808
#
# Epoch 26: val_loss did not improve from 0.00808
#
# Epoch 27: val_loss did not improve from 0.00808
#
# Epoch 28: val_loss did not improve from 0.00808
#
# Epoch 29: val_loss did not improve from 0.00808
#
# Epoch 30: val_loss did not improve from 0.00808
#
# Epoch 31: val_loss did not improve from 0.00808
#
# Epoch 32: val_loss did not improve from 0.00808
#
# Epoch 33: val_loss did not improve from 0.00808
#
# Epoch 34: val_loss did not improve from 0.00808
#
# Epoch 35: val_loss did not improve from 0.00808
#
# Epoch 36: val_loss did not improve from 0.00808
#
# Epoch 37: val_loss did not improve from 0.00808
#
# Epoch 38: val_loss did not improve from 0.00808
#
# Epoch 39: val_loss did not improve from 0.00808
#
# Epoch 40: val_loss did not improve from 0.00808
#
# Epoch 41: val_loss did not improve from 0.00808
#
# Epoch 42: val_loss did not improve from 0.00808
#
# Epoch 43: val_loss did not improve from 0.00808
#
# Epoch 44: val_loss did not improve from 0.00808
#
# Epoch 45: val_loss did not improve from 0.00808
#
# Epoch 46: val_loss did not improve from 0.00808
#
# Epoch 47: val_loss did not improve from 0.00808
#
# Epoch 48: val_loss did not improve from 0.00808
#
# Epoch 49: val_loss did not improve from 0.00808
#
# Epoch 50: val_loss did not improve from 0.00808
#
# Epoch 51: val_loss did not improve from 0.00808
#
# Epoch 52: val_loss did not improve from 0.00808
#
# Epoch 53: val_loss did not improve from 0.00808
#
# Epoch 54: val_loss did not improve from 0.00808
#
# Epoch 55: val_loss did not improve from 0.00808
#
# Epoch 56: val_loss did not improve from 0.00808
#
# Epoch 57: val_loss did not improve from 0.00808
#
# Epoch 58: val_loss did not improve from 0.00808
#
# Epoch 59: val_loss did not improve from 0.00808
#
# Epoch 60: val_loss did not improve from 0.00808
#
# Epoch 61: val_loss did not improve from 0.00808
#
# Epoch 62: val_loss did not improve from 0.00808
#
# Epoch 63: val_loss did not improve from 0.00808
#
# Epoch 64: val_loss did not improve from 0.00808
#
# Epoch 65: val_loss did not improve from 0.00808
#
# Epoch 66: val_loss did not improve from 0.00808
#
# Epoch 67: val_loss did not improve from 0.00808
#
# Epoch 68: val_loss did not improve from 0.00808
#
# Epoch 69: val_loss did not improve from 0.00808
#
# Epoch 70: val_loss did not improve from 0.00808
#
# Epoch 71: val_loss did not improve from 0.00808
#
# Epoch 72: val_loss did not improve from 0.00808
#
# Epoch 73: val_loss did not improve from 0.00808
#
# Epoch 74: val_loss did not improve from 0.00808
#
# Epoch 75: val_loss did not improve from 0.00808
#
# Epoch 76: val_loss did not improve from 0.00808
#
# Epoch 77: val_loss did not improve from 0.00808
#
# Epoch 78: val_loss did not improve from 0.00808
#
# Epoch 79: val_loss did not improve from 0.00808
#
# Epoch 80: val_loss did not improve from 0.00808
#
# Epoch 81: val_loss did not improve from 0.00808
#
# Epoch 82: val_loss did not improve from 0.00808
#
# Epoch 83: val_loss did not improve from 0.00808
#
# Epoch 84: val_loss did not improve from 0.00808
#
# Epoch 85: val_loss did not improve from 0.00808
# Epoch 85: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step
# Training with params: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 64, 'num_epochs': 200}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00808
#
# Epoch 2: val_loss did not improve from 0.00808
#
# Epoch 3: val_loss did not improve from 0.00808
#
# Epoch 4: val_loss did not improve from 0.00808
#
# Epoch 5: val_loss did not improve from 0.00808
#
# Epoch 6: val_loss did not improve from 0.00808
#
# Epoch 7: val_loss did not improve from 0.00808
#
# Epoch 8: val_loss did not improve from 0.00808
#
# Epoch 9: val_loss did not improve from 0.00808
#
# Epoch 10: val_loss did not improve from 0.00808
#
# Epoch 11: val_loss did not improve from 0.00808
#
# Epoch 12: val_loss did not improve from 0.00808
#
# Epoch 13: val_loss did not improve from 0.00808
#
# Epoch 14: val_loss did not improve from 0.00808
#
# Epoch 15: val_loss did not improve from 0.00808
#
# Epoch 16: val_loss did not improve from 0.00808
#
# Epoch 17: val_loss did not improve from 0.00808
#
# Epoch 18: val_loss did not improve from 0.00808
#
# Epoch 19: val_loss did not improve from 0.00808
#
# Epoch 20: val_loss did not improve from 0.00808
#
# Epoch 21: val_loss did not improve from 0.00808
#
# Epoch 22: val_loss did not improve from 0.00808
#
# Epoch 23: val_loss did not improve from 0.00808
#
# Epoch 24: val_loss did not improve from 0.00808
#
# Epoch 25: val_loss did not improve from 0.00808
#
# Epoch 26: val_loss did not improve from 0.00808
#
# Epoch 27: val_loss did not improve from 0.00808
#
# Epoch 28: val_loss did not improve from 0.00808
#
# Epoch 29: val_loss did not improve from 0.00808
#
# Epoch 30: val_loss did not improve from 0.00808
#
# Epoch 31: val_loss did not improve from 0.00808
#
# Epoch 32: val_loss did not improve from 0.00808
#
# Epoch 33: val_loss did not improve from 0.00808
#
# Epoch 34: val_loss did not improve from 0.00808
#
# Epoch 35: val_loss did not improve from 0.00808
#
# Epoch 36: val_loss did not improve from 0.00808
#
# Epoch 37: val_loss did not improve from 0.00808
#
# Epoch 38: val_loss did not improve from 0.00808
#
# Epoch 39: val_loss did not improve from 0.00808
#
# Epoch 40: val_loss did not improve from 0.00808
#
# Epoch 41: val_loss did not improve from 0.00808
#
# Epoch 42: val_loss did not improve from 0.00808
#
# Epoch 43: val_loss did not improve from 0.00808
#
# Epoch 44: val_loss did not improve from 0.00808
#
# Epoch 45: val_loss did not improve from 0.00808
#
# Epoch 46: val_loss did not improve from 0.00808
#
# Epoch 47: val_loss did not improve from 0.00808
#
# Epoch 48: val_loss did not improve from 0.00808
#
# Epoch 49: val_loss did not improve from 0.00808
#
# Epoch 50: val_loss did not improve from 0.00808
#
# Epoch 51: val_loss did not improve from 0.00808
#
# Epoch 52: val_loss did not improve from 0.00808
#
# Epoch 53: val_loss did not improve from 0.00808
#
# Epoch 54: val_loss did not improve from 0.00808
#
# Epoch 55: val_loss did not improve from 0.00808
#
# Epoch 56: val_loss did not improve from 0.00808
#
# Epoch 57: val_loss did not improve from 0.00808
#
# Epoch 58: val_loss did not improve from 0.00808
#
# Epoch 59: val_loss did not improve from 0.00808
#
# Epoch 60: val_loss did not improve from 0.00808
#
# Epoch 61: val_loss did not improve from 0.00808
#
# Epoch 62: val_loss did not improve from 0.00808
#
# Epoch 63: val_loss did not improve from 0.00808
#
# Epoch 64: val_loss did not improve from 0.00808
#
# Epoch 65: val_loss did not improve from 0.00808
#
# Epoch 66: val_loss did not improve from 0.00808
#
# Epoch 67: val_loss did not improve from 0.00808
#
# Epoch 68: val_loss did not improve from 0.00808
#
# Epoch 69: val_loss did not improve from 0.00808
#
# Epoch 70: val_loss did not improve from 0.00808
#
# Epoch 71: val_loss did not improve from 0.00808
#
# ...
#
# Epoch 24: val_loss did not improve from 0.00337
#
# Epoch 25: val_loss did not improve from 0.00337
#
# Epoch 26: val_loss did not improve from 0.00337
#
# Epoch 27: val_loss did not improve from 0.00337
#
# Epoch 28: val_loss did not improve from 0.00337
#
# Epoch 29: val_loss did not improve from 0.00337
#
# Epoch 30: val_loss did not improve from 0.00337
#
# Epoch 31: val_loss did not improve from 0.00337
#
# Epoch 32: val_loss did not improve from 0.00337
#
# Epoch 33: val_loss did not improve from 0.00337
#
# Epoch 34: val_loss did not improve from 0.00337
#
# Epoch 35: val_loss did not improve from 0.00337
#
# Epoch 36: val_loss did not improve from 0.00337
#
# Epoch 37: val_loss did not improve from 0.00337
#
# Epoch 38: val_loss did not improve from 0.00337
#
# Epoch 39: val_loss did not improve from 0.00337
#
# Epoch 40: val_loss did not improve from 0.00337
#
# Epoch 41: val_loss did not improve from 0.00337
#
# Epoch 42: val_loss did not improve from 0.00337
#
# Epoch 43: val_loss did not improve from 0.00337
#
# Epoch 44: val_loss did not improve from 0.00337
#
# Epoch 45: val_loss did not improve from 0.00337
#
# Epoch 46: val_loss did not improve from 0.00337
#
# Epoch 47: val_loss did not improve from 0.00337
#
# Epoch 48: val_loss did not improve from 0.00337
#
# Epoch 49: val_loss did not improve from 0.00337
#
# Epoch 50: val_loss did not improve from 0.00337
#
# Epoch 51: val_loss did not improve from 0.00337
#
# Epoch 52: val_loss did not improve from 0.00337
#
# Epoch 53: val_loss did not improve from 0.00337
#
# Epoch 54: val_loss did not improve from 0.00337
#
# Epoch 55: val_loss did not improve from 0.00337
#
# Epoch 56: val_loss did not improve from 0.00337
#
# Epoch 57: val_loss did not improve from 0.00337
#
# Epoch 58: val_loss did not improve from 0.00337
#
# Epoch 59: val_loss did not improve from 0.00337
#
# Epoch 60: val_loss did not improve from 0.00337
#
# Epoch 61: val_loss did not improve from 0.00337
#
# Epoch 62: val_loss did not improve from 0.00337
#
# Epoch 63: val_loss did not improve from 0.00337
#
# Epoch 64: val_loss did not improve from 0.00337
#
# Epoch 65: val_loss did not improve from 0.00337
#
# Epoch 66: val_loss did not improve from 0.00337
#
# Epoch 67: val_loss did not improve from 0.00337
#
# Epoch 68: val_loss did not improve from 0.00337
#
# Epoch 69: val_loss did not improve from 0.00337
#
# Epoch 70: val_loss did not improve from 0.00337
#
# Epoch 71: val_loss did not improve from 0.00337
#
# Epoch 72: val_loss did not improve from 0.00337
#
# Epoch 73: val_loss did not improve from 0.00337
#
# Epoch 74: val_loss did not improve from 0.00337
#
# Epoch 75: val_loss did not improve from 0.00337
#
# Epoch 76: val_loss did not improve from 0.00337
#
# Epoch 77: val_loss did not improve from 0.00337
#
# Epoch 78: val_loss did not improve from 0.00337
#
# Epoch 79: val_loss did not improve from 0.00337
#
# Epoch 80: val_loss did not improve from 0.00337
#
# Epoch 81: val_loss did not improve from 0.00337
#
# Epoch 82: val_loss did not improve from 0.00337
#
# Epoch 83: val_loss did not improve from 0.00337
#
# Epoch 84: val_loss did not improve from 0.00337
# Epoch 84: early stopping
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step
# Training with params: {'timesteps': 50, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 64, 'num_epochs': 200}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00337
#
# Epoch 2: val_loss did not improve from 0.00337
#
# Epoch 3: val_loss did not improve from 0.00337
#
# Epoch 4: val_loss did not improve from 0.00337
#
# Epoch 5: val_loss did not improve from 0.00337
#
# Epoch 6: val_loss did not improve from 0.00337
#
# Epoch 7: val_loss did not improve from 0.00337
#
# Epoch 8: val_loss did not improve from 0.00337
#
# Epoch 9: val_loss did not improve from 0.00337
#
# Epoch 10: val_loss did not improve from 0.00337
#
# Epoch 11: val_loss did not improve from 0.00337
#
# Epoch 12: val_loss did not improve from 0.00337
#
# Epoch 13: val_loss did not improve from 0.00337
#
# Epoch 14: val_loss did not improve from 0.00337
#
# Epoch 15: val_loss did not improve from 0.00337
#
# Epoch 16: val_loss did not improve from 0.00337
#
# Epoch 17: val_loss did not improve from 0.00337
#
# Epoch 18: val_loss did not improve from 0.00337
#
# Epoch 19: val_loss did not improve from 0.00337
#
# Epoch 20: val_loss did not improve from 0.00337
#
# Epoch 21: val_loss did not improve from 0.00337
#
# Epoch 22: val_loss did not improve from 0.00337
#
# Epoch 23: val_loss did not improve from 0.00337
#
# Epoch 24: val_loss did not improve from 0.00337
#
# Epoch 25: val_loss did not improve from 0.00337
#
# Epoch 26: val_loss did not improve from 0.00337
#
# Epoch 27: val_loss did not improve from 0.00337
#
# Epoch 28: val_loss did not improve from 0.00337
#
# Epoch 29: val_loss did not improve from 0.00337
#
# Epoch 30: val_loss did not improve from 0.00337
#
# Epoch 31: val_loss did not improve from 0.00337
#
# Epoch 32: val_loss did not improve from 0.00337
#
# Epoch 33: val_loss did not improve from 0.00337
#
# Epoch 34: val_loss did not improve from 0.00337
#
# Epoch 35: val_loss did not improve from 0.00337
#
# Epoch 36: val_loss did not improve from 0.00337
#
# Epoch 37: val_loss did not improve from 0.00337
#
# Epoch 38: val_loss did not improve from 0.00337
#
# Epoch 39: val_loss did not improve from 0.00337
#
# Epoch 40: val_loss did not improve from 0.00337
#
# Epoch 41: val_loss did not improve from 0.00337
#
# Epoch 42: val_loss did not improve from 0.00337
#
# Epoch 43: val_loss did not improve from 0.00337
#
# Epoch 44: val_loss did not improve from 0.00337
#
# Epoch 45: val_loss did not improve from 0.00337
#
# Epoch 46: val_loss did not improve from 0.00337
#
# Epoch 47: val_loss did not improve from 0.00337
#
# Epoch 48: val_loss did not improve from 0.00337
#
# Epoch 49: val_loss did not improve from 0.00337
#
# Epoch 50: val_loss did not improve from 0.00337
#
# Epoch 51: val_loss did not improve from 0.00337
#
# Epoch 52: val_loss did not improve from 0.00337
#
# Epoch 53: val_loss did not improve from 0.00337
#
# Epoch 54: val_loss did not improve from 0.00337
#
# Epoch 55: val_loss did not improve from 0.00337
#
# Epoch 56: val_loss did not improve from 0.00337
#
# Epoch 57: val_loss did not improve from 0.00337
#
# Epoch 58: val_loss did not improve from 0.00337
#
# Epoch 59: val_loss did not improve from 0.00337
#
# Epoch 60: val_loss did not improve from 0.00337
#
# Epoch 61: val_loss did not improve from 0.00337
#
# Epoch 62: val_loss did not improve from 0.00337
#
# Epoch 63: val_loss did not improve from 0.00337
#
# Epoch 64: val_loss did not improve from 0.00337
#
# Epoch 65: val_loss did not improve from 0.00337
#
# Epoch 66: val_loss did not improve from 0.00337
#
# Epoch 67: val_loss did not improve from 0.00337
#
# Epoch 68: val_loss did not improve from 0.00337
#
# Epoch 69: val_loss did not improve from 0.00337
#
# Epoch 70: val_loss did not improve from 0.00337
#
# Epoch 71: val_loss did not improve from 0.00337
#
# Epoch 72: val_loss did not improve from 0.00337
#
# Epoch 73: val_loss did not improve from 0.00337
#
# Epoch 74: val_loss did not improve from 0.00337
#
# Epoch 75: val_loss did not improve from 0.00337
#
# Epoch 76: val_loss did not improve from 0.00337
#
# Epoch 77: val_loss did not improve from 0.00337
#
# Epoch 78: val_loss did not improve from 0.00337
#
# Epoch 79: val_loss did not improve from 0.00337
#
# Epoch 80: val_loss did not improve from 0.00337
#
# Epoch 81: val_loss did not improve from 0.00337
# Epoch 81: early stopping
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step
# Training with params: {'timesteps': 50, 'hl': [40, 35], 'lr': 0.0001, 'batch_size': 64, 'num_epochs': 250}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss did not improve from 0.00337
#
# Epoch 2: val_loss did not improve from 0.00337
#
# Epoch 3: val_loss did not improve from 0.00337
#
# Epoch 4: val_loss did not improve from 0.00337
#
# Epoch 5: val_loss did not improve from 0.00337
#
# Epoch 6: val_loss did not improve from 0.00337
#
# Epoch 7: val_loss did not improve from 0.00337
#
# Epoch 8: val_loss did not improve from 0.00337
#
# Epoch 9: val_loss did not improve from 0.00337
#
# Epoch 10: val_loss did not improve from 0.00337
#
# Epoch 11: val_loss did not improve from 0.00337
#
# Epoch 12: val_loss did not improve from 0.00337
#
# Epoch 13: val_loss did not improve from 0.00337
#
# Epoch 14: val_loss did not improve from 0.00337
#
# Epoch 15: val_loss did not improve from 0.00337
#
# Epoch 16: val_loss did not improve from 0.00337
#
# Epoch 17: val_loss did not improve from 0.00337
#
# Epoch 18: val_loss did not improve from 0.00337
#
# Epoch 19: val_loss did not improve from 0.00337
#
# Epoch 20: val_loss did not improve from 0.00337
#
# Epoch 21: val_loss did not improve from 0.00337
#
# Epoch 22: val_loss did not improve from 0.00337
#
# Epoch 23: val_loss did not improve from 0.00337
#
# Epoch 24: val_loss did not improve from 0.00337
#
# Epoch 25: val_loss did not improve from 0.00337
#
# Epoch 26: val_loss did not improve from 0.00337
#
# Epoch 27: val_loss did not improve from 0.00337
#
# Epoch 28: val_loss did not improve from 0.00337
#
# Epoch 29: val_loss did not improve from 0.00337
#
# Epoch 30: val_loss did not improve from 0.00337
#
# Epoch 31: val_loss did not improve from 0.00337
#
# Epoch 32: val_loss did not improve from 0.00337
#
# Epoch 33: val_loss did not improve from 0.00337
#
# Epoch 34: val_loss did not improve from 0.00337
#
# Epoch 35: val_loss did not improve from 0.00337
#
# Epoch 36: val_loss did not improve from 0.00337
#
# Epoch 37: val_loss did not improve from 0.00337
#
# Epoch 38: val_loss did not improve from 0.00337
#
# Epoch 39: val_loss did not improve from 0.00337
#
# Epoch 40: val_loss did not improve from 0.00337
#
# Epoch 41: val_loss did not improve from 0.00337
#
# Epoch 42: val_loss did not improve from 0.00337
#
# Epoch 43: val_loss did not improve from 0.00337
#
# Epoch 44: val_loss did not improve from 0.00337
#
# Epoch 45: val_loss did not improve from 0.00337
#
# Epoch 46: val_loss did not improve from 0.00337
#
# Epoch 47: val_loss did not improve from 0.00337
#
# Epoch 48: val_loss did not improve from 0.00337
#
# Epoch 49: val_loss did not improve from 0.00337
#
# Epoch 50: val_loss did not improve from 0.00337
#
# Epoch 51: val_loss did not improve from 0.00337
#
# Epoch 52: val_loss did not improve from 0.00337
#
# Epoch 53: val_loss did not improve from 0.00337
#
# Epoch 54: val_loss did not improve from 0.00337
#
# Epoch 55: val_loss did not improve from 0.00337
#
# Epoch 56: val_loss did not improve from 0.00337
#
# Epoch 57: val_loss did not improve from 0.00337
#
# Epoch 58: val_loss did not improve from 0.00337
#
# Epoch 59: val_loss did not improve from 0.00337
#
# Epoch 60: val_loss did not improve from 0.00337
#
# Epoch 61: val_loss did not improve from 0.00337
#
# Epoch 62: val_loss did not improve from 0.00337
#
# Epoch 63: val_loss did not improve from 0.00337
#
# Epoch 64: val_loss did not improve from 0.00337
#
# Epoch 65: val_loss did not improve from 0.00337
#
# Epoch 66: val_loss did not improve from 0.00337
#
# Epoch 67: val_loss did not improve from 0.00337
#
# Epoch 68: val_loss did not improve from 0.00337
#
# Epoch 69: val_loss did not improve from 0.00337
#
# Epoch 70: val_loss did not improve from 0.00337
#
# Epoch 71: val_loss did not improve from 0.00337
#
# Epoch 72: val_loss did not improve from 0.00337
#
# Epoch 73: val_loss did not improve from 0.00337
#
# Epoch 74: val_loss did not improve from 0.00337
#
# Epoch 75: val_loss did not improve from 0.00337
#
# Epoch 76: val_loss did not improve from 0.00337
#
# Epoch 77: val_loss did not improve from 0.00337
#
# Epoch 78: val_loss did not improve from 0.00337
#
# Epoch 79: val_loss did not improve from 0.00337
#
# Epoch 80: val_loss did not improve from 0.00337
#
# Epoch 81: val_loss did not improve from 0.00337
#
# Epoch 82: val_loss did not improve from 0.00337
#
# Epoch 83: val_loss did not improve from 0.00337
#
# Epoch 84: val_loss did not improve from 0.00337
#
# Epoch 85: val_loss did not improve from 0.00337
#
# Epoch 86: val_loss did not improve from 0.00337
#
# Epoch 87: val_loss did not improve from 0.00337
#
# Epoch 88: val_loss did not improve from 0.00337
#
# Epoch 89: val_loss did not improve from 0.00337
#
# Epoch 90: val_loss did not improve from 0.00337
#
# Epoch 91: val_loss did not improve from 0.00337
#
# Epoch 92: val_loss did not improve from 0.00337
#
# Epoch 93: val_loss did not improve from 0.00337
#
# Epoch 94: val_loss did not improve from 0.00337
#
# Epoch 95: val_loss did not improve from 0.00337
#
# Epoch 96: val_loss did not improve from 0.00337
#
# Epoch 97: val_loss did not improve from 0.00337
#
# Epoch 98: val_loss did not improve from 0.00337
#
# Epoch 99: val_loss did not improve from 0.00337
#
# Epoch 100: val_loss did not improve from 0.00337
#
# Epoch 101: val_loss did not improve from 0.00337
# Epoch 101: early stopping
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step
#     timesteps        hl      lr  batch_size  num_epochs           MSE  \
# 0          30  [40, 35]  0.0010          32         200  3.865275e+00
# 1          30  [40, 35]  0.0010          32         250  8.579862e-03
# 2          30  [40, 35]  0.0010          64         200  2.883024e-01
# 3          30  [40, 35]  0.0010          64         250  1.545669e-01
# 4          30  [40, 35]  0.0001          32         200  9.267127e+00
# 5          30  [40, 35]  0.0001          32         250  5.374375e-02
# 6          30  [40, 35]  0.0001          64         200  2.841804e-01
# 7          30  [40, 35]  0.0001          64         250  1.223547e-01
# 8          40  [40, 35]  0.0010          32         200  6.822988e-01
# 9          40  [40, 35]  0.0010          32         250  1.914952e-01
# 10         40  [40, 35]  0.0010          64         200  4.843174e-01
# 11         40  [40, 35]  0.0010          64         250  6.056782e+00
# 12         40  [40, 35]  0.0001          32         200  8.414017e+02
# 13         40  [40, 35]  0.0001          32         250  9.735492e-01
# 14         40  [40, 35]  0.0001          64         200  1.880137e+02
# 15         40  [40, 35]  0.0001          64         250  3.374975e+03
# 16         50  [40, 35]  0.0010          32         200  3.569857e-02
# 17         50  [40, 35]  0.0010          32         250  1.951921e-01
# 18         50  [40, 35]  0.0010          64         200  2.524426e-01
# 19         50  [40, 35]  0.0010          64         250  8.226433e-02
# 20         50  [40, 35]  0.0001          32         200  8.370348e+03
# 21         50  [40, 35]  0.0001          32         250  2.360857e+08
# 22         50  [40, 35]  0.0001          64         200  6.547658e+04
# 23         50  [40, 35]  0.0001          64         250  5.873721e+03
#
#             RMSE         MAPE            R²
# 0       1.966030     0.770138 -4.550879e+01
# 1       0.092628     0.046311  8.967631e-01
# 2       0.536938     0.264479 -2.468988e+00
# 3       0.393150     0.213577 -8.598207e-01
# 4       3.044196     1.280915 -1.105064e+02
# 5       0.231827     0.116689  3.533302e-01
# 6       0.533086     0.279634 -2.419391e+00
# 7       0.349792     0.159915 -4.722291e-01
# 8       0.826014     0.368265 -7.447087e+00
# 9       0.437602     0.215677 -1.370774e+00
# 10      0.695929     0.384338 -4.996011e+00
# 11      2.461053     1.179035 -7.398499e+01
# 12     29.006924     8.837264 -1.041583e+04
# 13      0.986686     0.292328 -1.105286e+01
# 14     13.711809     4.751822 -2.326673e+03
# 15     58.094531    22.682649 -4.178231e+04
# 16      0.188941     0.094807  5.342844e-01
# 17      0.441805     0.231511 -1.546432e+00
# 18      0.502437     0.202219 -2.293310e+00
# 19      0.286818     0.150308 -7.320235e-02
# 20     91.489608    33.201600 -1.091967e+05
# 21  15365.080184  5892.353435 -3.079922e+09
# 22    255.883915    87.588087 -8.541920e+05
# 23     76.640206    26.311044 -7.662627e+04
# Best parameters: {'timesteps': 30, 'hl': [40, 35], 'lr': 0.001, 'batch_size': 32, 'num_epochs': 250}
# Best RMSE score: 0.09262754346601251

# %% [markdown]
# ### Bước 5: Huấn luyện mô hình với bộ tham số tối ưu

# %%
timesteps = 30
hl = [40, 35]
lr = 1e-3
batch_size = 32
num_epochs = 250

model, train_error, val_error = fit_model_4(train, val, timesteps, hl, lr, batch_size, num_epochs)
# Out:
# I0000 00:00:1748875697.991404      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1748875697.992209      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748875704.794576     103 service.cc:148] XLA service 0x33abdcb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748875704.795209     103 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748875704.795228     103 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748875705.447489     103 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1748875707.416880     103 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 10.37471, saving model to 10Var_hpg_lstm.h5
#
# Epoch 2: val_loss improved from 10.37471 to 6.72120, saving model to 10Var_hpg_lstm.h5
#
# Epoch 3: val_loss improved from 6.72120 to 2.36633, saving model to 10Var_hpg_lstm.h5
#
# Epoch 4: val_loss did not improve from 2.36633
#
# Epoch 5: val_loss improved from 2.36633 to 0.79946, saving model to 10Var_hpg_lstm.h5
#
# Epoch 6: val_loss improved from 0.79946 to 0.60904, saving model to 10Var_hpg_lstm.h5
#
# Epoch 7: val_loss did not improve from 0.60904
#
# Epoch 8: val_loss did not improve from 0.60904
#
# Epoch 9: val_loss did not improve from 0.60904
#
# Epoch 10: val_loss did not improve from 0.60904
#
# Epoch 11: val_loss did not improve from 0.60904
#
# Epoch 12: val_loss did not improve from 0.60904
#
# Epoch 13: val_loss did not improve from 0.60904
#
# Epoch 14: val_loss did not improve from 0.60904
#
# Epoch 15: val_loss did not improve from 0.60904
#
# Epoch 16: val_loss did not improve from 0.60904
#
# Epoch 17: val_loss did not improve from 0.60904
#
# Epoch 18: val_loss did not improve from 0.60904
#
# Epoch 19: val_loss did not improve from 0.60904
#
# Epoch 20: val_loss did not improve from 0.60904
#
# Epoch 21: val_loss did not improve from 0.60904
#
# Epoch 22: val_loss did not improve from 0.60904
#
# Epoch 23: val_loss did not improve from 0.60904
#
# Epoch 24: val_loss did not improve from 0.60904
#
# Epoch 25: val_loss did not improve from 0.60904
#
# Epoch 26: val_loss did not improve from 0.60904
#
# Epoch 27: val_loss did not improve from 0.60904
#
# Epoch 28: val_loss did not improve from 0.60904
#
# Epoch 29: val_loss did not improve from 0.60904
#
# Epoch 30: val_loss did not improve from 0.60904
#
# Epoch 31: val_loss did not improve from 0.60904
#
# Epoch 32: val_loss did not improve from 0.60904
#
# Epoch 33: val_loss did not improve from 0.60904
#
# Epoch 34: val_loss did not improve from 0.60904
#
# Epoch 35: val_loss did not improve from 0.60904
#
# Epoch 36: val_loss did not improve from 0.60904
#
# Epoch 37: val_loss did not improve from 0.60904
#
# Epoch 38: val_loss did not improve from 0.60904
#
# Epoch 39: val_loss did not improve from 0.60904
#
# Epoch 40: val_loss did not improve from 0.60904
#
# Epoch 41: val_loss did not improve from 0.60904
#
# Epoch 42: val_loss did not improve from 0.60904
#
# Epoch 43: val_loss did not improve from 0.60904
#
# Epoch 44: val_loss did not improve from 0.60904
#
# Epoch 45: val_loss did not improve from 0.60904
#
# Epoch 46: val_loss did not improve from 0.60904
#
# Epoch 47: val_loss did not improve from 0.60904
#
# Epoch 48: val_loss did not improve from 0.60904
#
# Epoch 49: val_loss did not improve from 0.60904
#
# Epoch 50: val_loss did not improve from 0.60904
#
# Epoch 51: val_loss did not improve from 0.60904
#
# Epoch 52: val_loss did not improve from 0.60904
#
# Epoch 53: val_loss did not improve from 0.60904
#
# Epoch 54: val_loss did not improve from 0.60904
#
# Epoch 55: val_loss did not improve from 0.60904
#
# Epoch 56: val_loss did not improve from 0.60904
#
# Epoch 57: val_loss did not improve from 0.60904
#
# Epoch 58: val_loss did not improve from 0.60904
#
# Epoch 59: val_loss did not improve from 0.60904
#
# Epoch 60: val_loss did not improve from 0.60904
#
# Epoch 61: val_loss did not improve from 0.60904
#
# Epoch 62: val_loss did not improve from 0.60904
#
# Epoch 63: val_loss did not improve from 0.60904
#
# Epoch 64: val_loss did not improve from 0.60904
#
# Epoch 65: val_loss did not improve from 0.60904
#
# Epoch 66: val_loss did not improve from 0.60904
#
# Epoch 67: val_loss did not improve from 0.60904
#
# Epoch 68: val_loss did not improve from 0.60904
#
# Epoch 69: val_loss did not improve from 0.60904
#
# Epoch 70: val_loss did not improve from 0.60904
#
# Epoch 71: val_loss did not improve from 0.60904
#
# Epoch 72: val_loss did not improve from 0.60904
#
# Epoch 73: val_loss did not improve from 0.60904
#
# Epoch 74: val_loss did not improve from 0.60904
#
# Epoch 75: val_loss did not improve from 0.60904
#
# Epoch 76: val_loss did not improve from 0.60904
#
# Epoch 77: val_loss did not improve from 0.60904
#
# Epoch 78: val_loss did not improve from 0.60904
#
# Epoch 79: val_loss did not improve from 0.60904
#
# Epoch 80: val_loss did not improve from 0.60904
#
# Epoch 81: val_loss did not improve from 0.60904
#
# Epoch 82: val_loss did not improve from 0.60904
#
# Epoch 83: val_loss did not improve from 0.60904
#
# Epoch 84: val_loss did not improve from 0.60904
#
# Epoch 85: val_loss improved from 0.60904 to 0.05242, saving model to 10Var_hpg_lstm.h5
#
# Epoch 86: val_loss did not improve from 0.05242
#
# Epoch 87: val_loss did not improve from 0.05242
#
# Epoch 88: val_loss did not improve from 0.05242
#
# Epoch 89: val_loss did not improve from 0.05242
#
# Epoch 90: val_loss did not improve from 0.05242
#
# Epoch 91: val_loss did not improve from 0.05242
#
# Epoch 92: val_loss did not improve from 0.05242
#
# Epoch 93: val_loss did not improve from 0.05242
#
# Epoch 94: val_loss did not improve from 0.05242
#
# Epoch 95: val_loss did not improve from 0.05242
#
# Epoch 96: val_loss did not improve from 0.05242
#
# Epoch 97: val_loss did not improve from 0.05242
#
# Epoch 98: val_loss did not improve from 0.05242
#
# Epoch 99: val_loss did not improve from 0.05242
#
# Epoch 100: val_loss did not improve from 0.05242
#
# Epoch 101: val_loss did not improve from 0.05242
#
# Epoch 102: val_loss did not improve from 0.05242
#
# Epoch 103: val_loss did not improve from 0.05242
#
# Epoch 104: val_loss did not improve from 0.05242
#
# Epoch 105: val_loss improved from 0.05242 to 0.01645, saving model to 10Var_hpg_lstm.h5
#
# Epoch 106: val_loss improved from 0.01645 to 0.01390, saving model to 10Var_hpg_lstm.h5
#
# Epoch 107: val_loss did not improve from 0.01390
#
# Epoch 108: val_loss did not improve from 0.01390
#
# Epoch 109: val_loss did not improve from 0.01390
#
# Epoch 110: val_loss did not improve from 0.01390
#
# Epoch 111: val_loss did not improve from 0.01390
#
# Epoch 112: val_loss did not improve from 0.01390
#
# Epoch 113: val_loss did not improve from 0.01390
#
# Epoch 114: val_loss did not improve from 0.01390
#
# Epoch 115: val_loss did not improve from 0.01390
#
# Epoch 116: val_loss did not improve from 0.01390
#
# Epoch 117: val_loss did not improve from 0.01390
#
# Epoch 118: val_loss did not improve from 0.01390
#
# Epoch 119: val_loss did not improve from 0.01390
#
# Epoch 120: val_loss did not improve from 0.01390
#
# Epoch 121: val_loss improved from 0.01390 to 0.00724, saving model to 10Var_hpg_lstm.h5
#
# Epoch 122: val_loss did not improve from 0.00724
#
# Epoch 123: val_loss did not improve from 0.00724
#
# Epoch 124: val_loss did not improve from 0.00724
#
# Epoch 125: val_loss did not improve from 0.00724
#
# Epoch 126: val_loss did not improve from 0.00724
#
# Epoch 127: val_loss did not improve from 0.00724
#
# Epoch 128: val_loss did not improve from 0.00724
#
# Epoch 129: val_loss did not improve from 0.00724
#
# Epoch 130: val_loss did not improve from 0.00724
#
# Epoch 131: val_loss did not improve from 0.00724
#
# Epoch 132: val_loss did not improve from 0.00724
#
# Epoch 133: val_loss did not improve from 0.00724
#
# Epoch 134: val_loss did not improve from 0.00724
#
# Epoch 135: val_loss did not improve from 0.00724
#
# Epoch 136: val_loss did not improve from 0.00724
#
# Epoch 137: val_loss did not improve from 0.00724
#
# Epoch 138: val_loss did not improve from 0.00724
#
# Epoch 139: val_loss did not improve from 0.00724
#
# Epoch 140: val_loss did not improve from 0.00724
#
# Epoch 141: val_loss did not improve from 0.00724
#
# Epoch 142: val_loss did not improve from 0.00724
#
# Epoch 143: val_loss did not improve from 0.00724
#
# Epoch 144: val_loss improved from 0.00724 to 0.00559, saving model to 10Var_hpg_lstm.h5
#
# Epoch 145: val_loss did not improve from 0.00559
#
# Epoch 146: val_loss did not improve from 0.00559
#
# Epoch 147: val_loss did not improve from 0.00559
#
# Epoch 148: val_loss did not improve from 0.00559
#
# Epoch 149: val_loss did not improve from 0.00559
#
# Epoch 150: val_loss did not improve from 0.00559
#
# Epoch 151: val_loss did not improve from 0.00559
#
# Epoch 152: val_loss did not improve from 0.00559
#
# Epoch 153: val_loss did not improve from 0.00559
#
# Epoch 154: val_loss did not improve from 0.00559
#
# Epoch 155: val_loss did not improve from 0.00559
#
# Epoch 156: val_loss did not improve from 0.00559
#
# Epoch 157: val_loss did not improve from 0.00559
#
# Epoch 158: val_loss did not improve from 0.00559
#
# Epoch 159: val_loss did not improve from 0.00559
#
# Epoch 160: val_loss did not improve from 0.00559
#
# Epoch 161: val_loss did not improve from 0.00559
#
# Epoch 162: val_loss did not improve from 0.00559
#
# Epoch 163: val_loss did not improve from 0.00559
#
# Epoch 164: val_loss did not improve from 0.00559
#
# Epoch 165: val_loss did not improve from 0.00559
#
# Epoch 166: val_loss did not improve from 0.00559
#
# Epoch 167: val_loss did not improve from 0.00559
#
# Epoch 168: val_loss did not improve from 0.00559
#
# Epoch 169: val_loss did not improve from 0.00559
#
# Epoch 170: val_loss did not improve from 0.00559
#
# Epoch 171: val_loss did not improve from 0.00559
#
# Epoch 172: val_loss did not improve from 0.00559
#
# Epoch 173: val_loss did not improve from 0.00559
#
# Epoch 174: val_loss did not improve from 0.00559
#
# Epoch 175: val_loss did not improve from 0.00559
#
# Epoch 176: val_loss did not improve from 0.00559
#
# Epoch 177: val_loss did not improve from 0.00559
#
# Epoch 178: val_loss did not improve from 0.00559
#
# Epoch 179: val_loss did not improve from 0.00559
#
# Epoch 180: val_loss did not improve from 0.00559
#
# Epoch 181: val_loss did not improve from 0.00559
#
# Epoch 182: val_loss did not improve from 0.00559
#
# Epoch 183: val_loss did not improve from 0.00559
#
# Epoch 184: val_loss did not improve from 0.00559
#
# Epoch 185: val_loss did not improve from 0.00559
#
# Epoch 186: val_loss did not improve from 0.00559
#
# Epoch 187: val_loss did not improve from 0.00559
#
# Epoch 188: val_loss did not improve from 0.00559
#
# Epoch 189: val_loss did not improve from 0.00559
#
# Epoch 190: val_loss did not improve from 0.00559
#
# Epoch 191: val_loss did not improve from 0.00559
#
# Epoch 192: val_loss did not improve from 0.00559
#
# Epoch 193: val_loss did not improve from 0.00559
#
# Epoch 194: val_loss did not improve from 0.00559
#
# Epoch 195: val_loss did not improve from 0.00559
#
# Epoch 196: val_loss did not improve from 0.00559
#
# Epoch 197: val_loss did not improve from 0.00559
#
# Epoch 198: val_loss did not improve from 0.00559
#
# Epoch 199: val_loss did not improve from 0.00559
#
# Epoch 200: val_loss did not improve from 0.00559
#
# Epoch 201: val_loss did not improve from 0.00559
#
# Epoch 202: val_loss did not improve from 0.00559
#
# Epoch 203: val_loss did not improve from 0.00559
#
# Epoch 204: val_loss did not improve from 0.00559
#
# Epoch 205: val_loss did not improve from 0.00559
#
# Epoch 206: val_loss did not improve from 0.00559
#
# Epoch 207: val_loss did not improve from 0.00559
#
# Epoch 208: val_loss did not improve from 0.00559
#
# Epoch 209: val_loss did not improve from 0.00559
#
# Epoch 210: val_loss did not improve from 0.00559
#
# Epoch 211: val_loss did not improve from 0.00559
#
# Epoch 212: val_loss did not improve from 0.00559
#
# Epoch 213: val_loss did not improve from 0.00559
#
# Epoch 214: val_loss did not improve from 0.00559
#
# Epoch 215: val_loss did not improve from 0.00559
#
# Epoch 216: val_loss did not improve from 0.00559
#
# Epoch 217: val_loss did not improve from 0.00559
#
# Epoch 218: val_loss did not improve from 0.00559
#
# Epoch 219: val_loss did not improve from 0.00559
#
# Epoch 220: val_loss did not improve from 0.00559
#
# Epoch 221: val_loss did not improve from 0.00559
#
# Epoch 222: val_loss did not improve from 0.00559
#
# Epoch 223: val_loss did not improve from 0.00559
#
# Epoch 224: val_loss did not improve from 0.00559
# Epoch 224: early stopping

# %% [markdown]
# ### Bước 6: Đánh giá mô hình và trực quan hóa kết quả

# %% [markdown]
# #### 6.1. Vẽ biểu đồ train_loss và val_loss

# %%
plot_error(train_error, val_error)

# %% [markdown]
# #### 6.2. Đánh giá mô hình trên tập test

# %%
mse, rmse, mape, r2, true, predicted = evaluate_model_4(model, test, timesteps)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step

# %%
print('MSE = {}'.format(mse))
print('RMSE = {}'.format(rmse))
print('MAPE = {}'.format(mape))
print('R-Squared Score = {}'.format(r2))
# Out:
# MSE = 0.007231684411910562
# RMSE = 0.08503931097974961
# MAPE = 0.043395404908493314
# R-Squared Score = 0.9129850132122829

# %% [markdown]
# #### 6.3. Vẽ đồ thị dự đoán vs thực tế

# %%
plot_data_4(true, predicted)

# %%
# Save a model
model.save('10VAR-hpg-lstm.keras')

# %%
del model
